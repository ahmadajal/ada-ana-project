# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

file_name = "data/output_tweets/sentiment_scored_english_tweets.csv"
print("Reading " + file_name + "\n");
data = pd.read_csv(file_name)
del data['Unnamed: 0']
print("Data shape : ")
print(data.shape)

print("Reading locations' mapping\n");
loc_to_canton = pd.read_csv('data/location_to_canton.csv')
del loc_to_canton['Unnamed: 0']
loc_to_canton.columns = [['canton','source_location']]
print(loc_to_canton.shape[0])
loc_to_canton.head()
# Out:
# Reading data/output_tweets/sentiment_scored_english_tweets.csv
#
# Data shape :
# (263884, 7)
# Reading locations' mapping
#
# 84
#   canton     source_location
# 0     ZH  Affoltern am Albis
# 1     ZH             Zuerich
# 2     ZH              Zurigo
# 3     ZH               Uster
# 4     ZH          Winterthur

# %%
print("Percentage of unrepresented cantons in the data :");
not_represented_cantons = loc_to_canton[loc_to_canton.source_location.isnull()]
print(not_represented_cantons.shape[0]/loc_to_canton.shape[0])
not_represented_cantons
# Out:
# Percentage of unrepresented cantons in the data :
# 0.023809523809523808
#    canton source_location
# 32     GL             NaN
# 33     ZG             NaN

# %%
data.head()
# Out:
#   lang                                               main  \
# 0   en  @ZHA_News https://youtu.be/UxQmxIm4q1s  Rest i...
# 1   en  Come and join me at our testing Roadshow on Ap...
# 2   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 3   en  Number crunching for the past week - 1 new unf...
# 4   en  Just posted a photo @ Langnau im Emmental http...
#
#               published sentiment source_location  clean_main_polarity  \
# 0  2016-04-01T02:35:56Z  POSITIVE         Lucerna             0.071428
# 1  2016-04-01T14:42:21Z  POSITIVE     Ennetbürgen             0.071428
# 2  2016-04-01T21:50:50Z  NEGATIVE           Suica            -0.249994
# 3  2016-04-01T11:43:27Z   NEUTRAL            Arth            -0.090908
# 4  2016-04-01T06:31:13Z   NEUTRAL         Langnau             0.000000
#
#    vader_polarity
# 0          0.8856
# 1          0.7644
# 2         -0.5848
# 3          0.0772
# 4          0.0000

# %%
data_new = pd.merge(data, loc_to_canton, on='source_location', how='left')
data_new.head()
# Out:
#   lang                                               main  \
# 0   en  @ZHA_News https://youtu.be/UxQmxIm4q1s  Rest i...
# 1   en  Come and join me at our testing Roadshow on Ap...
# 2   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 3   en  Number crunching for the past week - 1 new unf...
# 4   en  Just posted a photo @ Langnau im Emmental http...
#
#               published sentiment source_location  clean_main_polarity  \
# 0  2016-04-01T02:35:56Z  POSITIVE         Lucerna             0.071428
# 1  2016-04-01T14:42:21Z  POSITIVE     Ennetbürgen             0.071428
# 2  2016-04-01T21:50:50Z  NEGATIVE           Suica            -0.249994
# 3  2016-04-01T11:43:27Z   NEUTRAL            Arth            -0.090908
# 4  2016-04-01T06:31:13Z   NEUTRAL         Langnau             0.000000
#
#    vader_polarity canton
# 0          0.8856     LU
# 1          0.7644     NW
# 2         -0.5848    NaN
# 3          0.0772     SZ
# 4          0.0000     BE

# %%
not_mapped_data = data_new[(data_new.canton).isnull()]
percentage_not_mapped = not_mapped_data.shape[0] / data_new.shape[0]
print("Size of unmapped data : ")
print(not_mapped_data.shape[0])
print("Percentage of unmapped data : ")
print(percentage_not_mapped)
not_mapped_data.head()
# Out:
# Size of unmapped data :
# 171740
# Percentage of unmapped data :
# 0.6508162677540131
#    lang                                               main  \
# 2    en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 16   en  @detravoir Might this confirm the prophecy? pi...
# 17   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 18   en  Did some #GreenDay #acoustic. 21 Guns. #rock #...
# 20   en  @BlizzHeroes @DustinBrowder http://imgur.com/y...
#
#                published sentiment          source_location  \
# 2   2016-04-01T21:50:50Z  NEGATIVE                    Suica
# 16  2016-04-01T17:49:36Z   NEUTRAL  Confoederatio Helvetica
# 17  2016-04-01T20:51:10Z  NEGATIVE                    Suica
# 18  2016-04-01T20:27:24Z  POSITIVE  Confoederatio Helvetica
# 20  2016-04-01T00:23:23Z  NEGATIVE  Confoederatio Helvetica
#
#     clean_main_polarity  vader_polarity canton
# 2             -0.249994         -0.5848    NaN
# 16             0.000000          0.0000    NaN
# 17            -0.249994         -0.5848    NaN
# 18             0.000000          0.0000    NaN
# 20            -0.142855         -0.4939    NaN

# %%
# drop unmapped data
mapped_data = data_new.dropna(subset= ['canton'], how='all')
# take only relevent features
data_sent_canton = mapped_data[['canton','sentiment','clean_main_polarity','vader_polarity','published']]
print("Final data size : ")
print(data_sent_canton.shape[0])
data_sent_canton.head()
# Out:
# Final data size :
# 92144
#   canton sentiment  clean_main_polarity  vader_polarity             published
# 0     LU  POSITIVE             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW  POSITIVE             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ   NEUTRAL            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE   NEUTRAL             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR   NEUTRAL            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
def sentiment_value(name):
    if name == 'NEUTRAL':
        val = 0
    elif name == 'POSITIVE':
        val = 1
    elif name == 'NEGATIVE':
        val = -1
    else :
        val = np.NaN
    return val

# %%
data_sent_canton['sentiment'] = [sentiment_value(a) for a in data_sent_canton['sentiment']]
# Out:
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_sent_canton = data_sent_canton.dropna()

# %%
print(data_sent_canton.shape[0])
data_sent_canton.head()
# Out:
# 92144
#   canton  sentiment  clean_main_polarity  vader_polarity             published
# 0     LU          1             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW          1             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ          0            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE          0             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR          0            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
data_sent_canton['published'] = [a.split('T')[0] for a in data_sent_canton['published']]

# %%
data_sent_canton=data_sent_canton.rename(columns = {'published':'day'})
data_sent_canton.head()
# Out:
#   canton  sentiment  clean_main_polarity  vader_polarity         day
# 0     LU          1             0.071428          0.8856  2016-04-01
# 1     NW          1             0.071428          0.7644  2016-04-01
# 3     SZ          0            -0.090908          0.0772  2016-04-01
# 4     BE          0             0.000000          0.0000  2016-04-01
# 5     GR          0            -0.181817          0.0000  2016-04-01

# %%
data_day = data_sent_canton.groupby(['day'])
for name, group in data_day:
        print(name)
        #print(group)
data_day.describe()
# Out:
# 2016-04-01
# 2016-04-02
# 2016-04-03
# 2016-04-04
# 2016-04-05
# 2016-04-06
# 2016-04-07
# 2016-04-08
# 2016-04-09
# 2016-04-10
# 2016-04-11
# 2016-04-12
# 2016-04-13
# 2016-04-14
# 2016-04-15
# 2016-04-16
# 2016-04-17
# 2016-04-18
# 2016-04-19
# 2016-04-20
# 2016-04-21
# 2016-04-22
# 2016-04-23
# 2016-04-24
# 2016-04-25
# 2016-04-26
# 2016-04-27
# 2016-04-28
# 2016-04-29
# 2016-04-30
#                   clean_main_polarity    sentiment  vader_polarity
# day
# 2016-04-01 count          3484.000000  3484.000000     3484.000000
#            mean              0.018253     0.185132        0.137028
#            std               0.129140     0.698135        0.380699
#            min              -0.999975    -1.000000       -0.953100
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               1.000000     1.000000        0.967000
# 2016-04-02 count          2401.000000  2401.000000     2401.000000
#            mean              0.015171     0.197418        0.134885
#            std               0.139209     0.713099        0.386179
#            min              -0.999967    -1.000000       -0.957800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               1.000000     1.000000        0.967800
# 2016-04-03 count          2433.000000  2433.000000     2433.000000
#            mean              0.018682     0.233046        0.154358
#            std               0.122236     0.705029        0.378086
#            min              -0.999967    -1.000000       -0.938200
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.050000     1.000000        0.458800
#            max               0.999967     1.000000        0.956700
# 2016-04-04 count          3098.000000  3098.000000     3098.000000
#            mean              0.017900     0.178502        0.129564
#            std               0.122522     0.683371        0.371818
#            min              -0.999900    -1.000000       -0.943800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
# ...                               ...          ...             ...
# 2016-04-27 std               0.131341     0.684380        0.369380
#            min              -0.749981    -1.000000       -0.950100
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.419900
#            max               1.000000     1.000000        0.956700
# 2016-04-28 count          4048.000000  4048.000000     4048.000000
#            mean              0.000373     0.180830        0.126821
#            std               0.134162     0.682955        0.379579
#            min              -0.749981    -1.000000       -0.938700
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.439100
#            max               1.000000     1.000000        0.971600
# 2016-04-29 count          3835.000000  3835.000000     3835.000000
#            mean              0.005242     0.164016        0.126948
#            std               0.134586     0.687437        0.375966
#            min              -1.000000    -1.000000       -0.933700
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.421500
#            max               1.000000     1.000000        0.971200
# 2016-04-30 count          2780.000000  2780.000000     2780.000000
#            mean              0.001839     0.172302        0.121312
#            std               0.142230     0.695554        0.384220
#            min              -1.000000    -1.000000       -0.984300
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.421500
#            max               1.000000     1.000000        0.959200
#
# [240 rows x 3 columns]

# %%
# Statistical test : day 1
data_single_day = data_day.get_group('2016-04-01')
data_single_day_gp = data_single_day.groupby('canton')
# p_values
data_single_day_p_values = pd.DataFrame(columns = ['canton','sentiment_pv','vader_pv','main_pv'])
for i,group in enumerate( data_single_day_gp.groups):
    
    data_c = data_single_day_gp.get_group(group)
    pv_sentiment = stats.ttest_ind(a = data_c.sentiment, b= data_single_day.sentiment, equal_var=False)[1]
    pv_vader = (stats.ttest_ind(a = data_c.vader_polarity, b= data_single_day.vader_polarity, equal_var=False))[1]
    pv_main = (stats.ttest_ind(a = data_c.clean_main_polarity, b= data_single_day.clean_main_polarity, equal_var=False))[1]
    data_single_day_p_values.loc[i] = [group, pv_sentiment, pv_vader, pv_main]
data_single_day_p_values = data_single_day_p_values.set_index('canton')
# mean
data_single_day_mean = data_single_day_gp.mean()
data_single_day_mean.columns = ['main_mean','sentiment_mean','vader_mean']
# std
data_single_day_std = data_single_day_gp.std()
data_single_day_std.columns = ['main_std','sentiment_std','vader_std']
# count
data_single_day_count = pd.DataFrame(data_single_day_gp.count()['sentiment'])
data_single_day_count.columns = ['count']
# concatenation
data_single_day = pd.concat([data_single_day_mean, data_single_day_std, data_single_day_p_values, data_single_day_count], axis = 1, join = 'inner')
data_single_day = data_single_day.reset_index()
data_single_day
# Out:
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
#    canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0      BE   0.018348        0.158416    0.122261  0.122501       0.634539
# 1      NE   0.017424        0.600000    0.255290  0.036777       0.516398
# 2      SZ  -0.050505       -0.250000   -0.090800  0.058898       0.500000
# 3      GE   0.003031        0.069523    0.067172  0.115370       0.726309
# 4      AR   0.148861        0.250000    0.490125  0.235173       0.957427
# 5      FR   0.025523        0.240000    0.111044  0.096528       0.597216
# 6      JU   0.000000        0.000000    0.000000       NaN            NaN
# 7      SH   0.000000        0.200000    0.100900  0.000000       0.447214
# 8      LU   0.031344        0.277778    0.282889  0.187061       0.741085
# 9      TG  -0.142855        0.000000    0.000000       NaN            NaN
# 10     TI  -0.021981       -0.042254    0.058837  0.091972       0.619599
# 11     AG   0.012049        0.000000    0.071470  0.190006       0.794719
# 12     BL   0.099999        1.000000    0.624900       NaN            NaN
# 13     NW   0.071428        1.000000    0.764400       NaN            NaN
# 14     VS   0.073245        0.375000    0.300394  0.270653       0.718795
# 15     BS   0.016574        0.197080    0.141170  0.113134       0.673440
# 16     ZH   0.031659        0.283429    0.192572  0.138383       0.674884
# 17     VD   0.019018        0.164062    0.124496  0.124472       0.696191
# 18     SG  -0.000404        0.500000    0.257986  0.070234       0.518875
# 19     GR  -0.032342        0.125000    0.040450  0.066123       0.640870
#
#     vader_std  sentiment_pv      vader_pv       main_pv  count
# 0    0.368261      0.563529  5.807815e-01  9.914944e-01    202
# 1    0.281344      0.031782  2.172487e-01  9.455813e-01     10
# 2    0.235891      0.180085  1.488004e-01  1.013397e-01      4
# 3    0.392874      0.000001  6.796775e-08  1.160781e-04   1237
# 4    0.248201      0.900814  6.515640e-02  3.477159e-01      4
# 5    0.353070      0.651610  7.171860e-01  7.114765e-01     25
# 6         NaN           NaN           NaN           NaN      1
# 7    0.475233      0.944383  8.733116e-01  1.032093e-16      5
# 8    0.366652      0.460162  2.310068e-02  6.778433e-01     36
# 9         NaN           NaN           NaN           NaN      1
# 10   0.326736      0.003151  5.038518e-02  5.398094e-04     71
# 11   0.406203      0.311509  4.802272e-01  8.855866e-01     20
# 12        NaN           NaN           NaN           NaN      1
# 13        NaN           NaN           NaN           NaN      1
# 14   0.337603      0.308288  7.251963e-02  4.292952e-01     16
# 15   0.383024      0.839092  9.013450e-01  8.656810e-01    137
# 16   0.365167      0.000002  8.637006e-07  1.177114e-03   1563
# 17   0.397402      0.737204  7.261960e-01  9.457314e-01    128
# 18   0.360035      0.041181  2.316480e-01  3.410676e-01     14
# 19   0.220555      0.798583  2.563935e-01  6.745865e-02      8

# %%
def day_preprocess(day):
    data_single_day = data_day.get_group(day)
    data_single_day_gp = data_single_day.groupby('canton')
    # p_values
    data_single_day_p_values = pd.DataFrame(columns = ['canton','sentiment_pv','vader_pv','main_pv'])
    for i,group in enumerate( data_single_day_gp.groups):
        data_c = data_single_day_gp.get_group(group)
        pv_sentiment = stats.ttest_ind(a = data_c.sentiment, b= data_single_day.sentiment, equal_var=False)[1]
        pv_vader = (stats.ttest_ind(a = data_c.vader_polarity, b= data_single_day.vader_polarity, equal_var=False))[1]
        pv_main = (stats.ttest_ind(a = data_c.clean_main_polarity, b= data_single_day.clean_main_polarity, equal_var=False))[1]
        data_single_day_p_values.loc[i] = [group, pv_sentiment, pv_vader, pv_main]
    data_single_day_p_values = data_single_day_p_values.set_index('canton')
    # mean
    data_single_day_mean = data_single_day_gp.mean()
    data_single_day_mean.columns = ['main_mean','sentiment_mean','vader_mean']
    # std
    data_single_day_std = data_single_day_gp.std()
    data_single_day_std.columns = ['main_std','sentiment_std','vader_std']
    # count
    data_single_day_count = pd.DataFrame(data_single_day_gp.count()['sentiment'])
    data_single_day_count.columns = ['count']
    # concatenation
    data_single_day = pd.concat([data_single_day_mean, data_single_day_std, data_single_day_p_values, data_single_day_count], axis = 1, join = 'inner')
    data_single_day = data_single_day.reset_index()
    return data_single_day

# %%
prefix="viz-data/__harvest3r_twitter_data_"
postfix = "-04_0.json"
for i in np.arange(30):
    if (i<9):
        day = '2016-04-0' + str(i+1)
    else : 
        day = '2016-04-' + str(i+1)
    print("Pre-processing " + day + "\n");
    data_sd = day_preprocess(day)
    print(data_sd.head())
    print("write json file " + day + "\n");
    if (i<9):
        day = '0' + str(i+1)
    else : 
        day = str(i+1)
    file_name = prefix + day + postfix
    print(file_name)
    data_sd.to_json(file_name)
# Out:
# Pre-processing 2016-04-01
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.018348        0.158416    0.122261  0.122501       0.634539
# 1     NE   0.017424        0.600000    0.255290  0.036777       0.516398
# 2     SZ  -0.050505       -0.250000   -0.090800  0.058898       0.500000
# 3     GE   0.003031        0.069523    0.067172  0.115370       0.726309
# 4     AR   0.148861        0.250000    0.490125  0.235173       0.957427
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.368261      0.563529  5.807815e-01  0.991494    202
# 1   0.281344      0.031782  2.172487e-01  0.945581     10
# 2   0.235891      0.180085  1.488004e-01  0.101340      4
# 3   0.392874      0.000001  6.796775e-08  0.000116   1237
# 4   0.248201      0.900814  6.515640e-02  0.347716      4
# write json file 2016-04-01
#
# viz-data/__harvest3r_twitter_data_01-04_0.json
# Pre-processing 2016-04-02
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.014467        0.225434    0.173821  0.103649       0.682881
# 1     NE  -0.032221        0.100000    0.212750  0.116936       0.737865
# 2     TG   0.000000        0.000000    0.000000  0.000000       0.000000
# 3     SO   0.000000        0.500000    0.000000  0.000000       0.707107
# 4     OW   0.000000        0.000000    0.000000  0.000000       0.000000
#
#    vader_std  sentiment_pv      vader_pv       main_pv  count
# 0   0.374669  6.039275e-01  1.892224e-01  9.331105e-01    173
# 1   0.419893  6.865901e-01  5.725755e-01  2.329168e-01     10
# 2   0.000000  1.912593e-40  4.768422e-62  1.017400e-07      4
# 3   0.000000  6.535277e-01  4.768422e-62  1.017400e-07      2
# 4   0.000000  1.912593e-40  4.768422e-62  1.017400e-07      2
# write json file 2016-04-02
#
# viz-data/__harvest3r_twitter_data_02-04_0.json
# Pre-processing 2016-04-03
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.018687        0.182353    0.121654  0.117797       0.667713
# 1     NE   0.019231        0.500000    0.412850  0.027196       0.707107
# 2     VS   0.056251        0.400000    0.272680  0.109930       0.699206
# 3     SO   0.034285        0.000000    0.265440  0.048022       1.000000
# 4     GE   0.026009        0.179671    0.152202  0.120938       0.720823
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.351822      0.341543  0.245072  0.999556    170
# 1   0.583858      0.687790  0.643865  0.981863      2
# 2   0.349670      0.470241  0.313288  0.308808     10
# 3   0.430713      0.629928  0.595238  0.509385      5
# 4   0.390350      0.049565  0.883147  0.111335    974
# write json file 2016-04-03
#
# viz-data/__harvest3r_twitter_data_03-04_0.json
# Pre-processing 2016-04-04
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.017711        0.153846    0.137911  0.123922       0.670557
# 1     NE  -0.038461        0.000000   -0.296250  0.076922       0.816497
# 2     VS   0.037950        0.181818    0.156764  0.137902       0.404520
# 3     SO   0.000000        0.000000    0.113333  0.000000       0.000000
# 4     SG   0.028739        0.388889    0.239478  0.080412       0.777544
#
#    vader_std  sentiment_pv  vader_pv       main_pv  count
# 0   0.352683  6.086228e-01  0.742252  9.829444e-01    208
# 1   0.408875  6.915786e-01  0.128594  2.390821e-01      4
# 2   0.220420  9.789414e-01  0.692265  6.404404e-01     11
# 3   0.196299  2.241688e-46  0.899339  6.051168e-16      3
# 4   0.476782  2.677739e-01  0.342491  5.772279e-01     18
# write json file 2016-04-04
#
# viz-data/__harvest3r_twitter_data_04-04_0.json
# Pre-processing 2016-04-05
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.002734        0.056769    0.081271  0.135664       0.593318
# 1     NE   0.083331        0.666667    0.345500  0.144334       0.577350
# 2     VS  -0.015542       -0.083333    0.136800  0.143858       0.668558
# 3     SO  -0.199996       -1.000000   -0.542300       NaN            NaN
# 4     SZ   0.000000        1.000000    0.000000       NaN            NaN
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.343299      0.015679  0.183801  0.302176    229
# 1   0.305061      0.265558  0.317298  0.483545      3
# 2   0.357609      0.240202  0.820899  0.517581     12
# 3        NaN           NaN       NaN       NaN      1
# 4        NaN           NaN       NaN       NaN      1
# write json file 2016-04-05
#
# viz-data/__harvest3r_twitter_data_05-04_0.json
# Pre-processing 2016-04-06
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.001656        0.161074    0.140510  0.116414       0.593514
# 1     ZH   0.016947        0.230435    0.130674  0.118278       0.675272
# 2     VS   0.031658        0.400000    0.282733  0.107512       0.632456
# 3     SG   0.085276        0.133333    0.225320  0.263836       0.743223
# 4     AR   0.142855        1.000000    0.440400       NaN            NaN
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.311443      0.864618  0.235923  0.396531    149
# 1   0.368948      0.001146  0.097659  0.091945   1150
# 2   0.383092      0.152784  0.101358  0.449074     15
# 3   0.418513      0.922166  0.300582  0.287858     15
# 4        NaN           NaN       NaN       NaN      1
# write json file 2016-04-06
#
# viz-data/__harvest3r_twitter_data_06-04_0.json
# Pre-processing 2016-04-07
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.017310        0.152466    0.107852  0.120035       0.639595
# 1     NE   0.118129        0.714286    0.429129  0.280092       0.487950
# 2     TG  -0.018899        0.500000    0.301000  0.063309       0.577350
# 3     SO   0.029129        0.285714    0.296414  0.086796       0.951190
# 4     GE   0.007265        0.104697    0.092604  0.104174       0.727114
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.339887      0.765939  0.902136  0.593183    223
# 1   0.322816      0.024768  0.040153  0.358516      7
# 2   0.202559      0.330820  0.156804  0.389901      4
# 3   0.294942      0.750086  0.147170  0.638232      7
# 4   0.412423      0.018423  0.212458  0.149305   1022
# write json file 2016-04-07
#
# viz-data/__harvest3r_twitter_data_07-04_0.json
# Pre-processing 2016-04-08
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.022582        0.203125    0.146477  0.113978       0.635256
# 1     NE   0.000000        0.142857    0.128314  0.000000       0.377964
# 2     TG   0.000000        0.000000    0.000000       NaN            NaN
# 3     VS   0.000071        0.157895    0.249295  0.134461       0.764719
# 4     GE   0.012335        0.068337    0.076443  0.118181       0.718751
#
#    vader_std  sentiment_pv  vader_pv       main_pv  count
# 0   0.348525      0.377938  0.243220  4.513926e-01    192
# 1   0.219717      0.901624  0.887969  3.844220e-15      7
# 2        NaN           NaN       NaN           NaN      1
# 3   0.405245      0.984638  0.169847  6.084707e-01     19
# 4   0.408046      0.000054  0.002300  3.169866e-01   1317
# write json file 2016-04-08
#
# viz-data/__harvest3r_twitter_data_08-04_0.json
# Pre-processing 2016-04-09
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.016336        0.193548    0.139019  0.143652       0.610858
# 1     NE   0.058471        0.583333    0.342850  0.145482       0.514929
# 2     VS  -0.025690        0.400000    0.178210  0.267009       0.598243
# 3     SO  -0.052727        0.250000    0.172425  0.062031       0.500000
# 4     SG   0.003023        0.117647   -0.004265  0.026554       0.600245
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.343320      0.889350  0.636633  0.685070    186
# 1   0.315379      0.025868  0.037040  0.292212     12
# 2   0.385543      0.153183  0.557726  0.536202     20
# 3   0.247153      0.854636  0.735596  0.128039      4
# 4   0.312787      0.580648  0.105042  0.207472     17
# write json file 2016-04-09
#
# viz-data/__harvest3r_twitter_data_09-04_0.json
# Pre-processing 2016-04-10
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.012665        0.159236    0.127359  0.097045       0.615083
# 1     TG   0.000000        0.000000    0.075550  0.000000       0.000000
# 2     SO   0.048092        0.200000    0.083050  0.198024       0.632456
# 3     SG  -0.040877        0.062500    0.012406  0.269170       0.680074
# 4     OW  -0.111110       -1.000000    0.000000       NaN            NaN
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.366940  7.236124e-01  0.582313  0.991846    157
# 1   0.106844  1.433120e-32  0.723537  0.000004      2
# 2   0.283846  9.126559e-01  0.766803  0.584811     10
# 3   0.335393  5.109080e-01  0.261750  0.439669     16
# 4        NaN           NaN       NaN       NaN      1
# write json file 2016-04-10
#
# viz-data/__harvest3r_twitter_data_10-04_0.json
# Pre-processing 2016-04-11
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010190        0.118721    0.123760  0.145897       0.631415
# 1     NE  -0.057864        0.000000    0.019967  0.077363       0.500000
# 2     VS   0.085208        0.187500    0.012037  0.266978       0.655108
# 3     SO  -0.027777       -0.250000   -0.023000  0.055555       0.957427
# 4     GE   0.006123        0.106756    0.104631  0.119599       0.689980
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.355731      0.501713  0.731146  0.988575    219
# 1   0.438527      0.399805  0.533324  0.030100      9
# 2   0.385052      0.815437  0.301724  0.278027     16
# 3   0.366672      0.466287  0.505861  0.266715      4
# 4   0.394118      0.071456  0.419778  0.342122   1199
# write json file 2016-04-11
#
# viz-data/__harvest3r_twitter_data_11-04_0.json
# Pre-processing 2016-04-12
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.016415        0.163701    0.154464  0.150435       0.604949
# 1     ZH   0.007782        0.191808    0.121747  0.144435       0.686527
# 2     TG   0.000000       -0.500000    0.000000  0.000000       0.707107
# 3     SO   0.000000        0.000000    0.000000  0.000000       0.000000
# 4     SG   0.012529        0.052632    0.038763  0.095062       0.705036
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.326297  6.366694e-01  2.367658e-02  0.252813    281
# 1   0.369439  2.739427e-02  2.242355e-01  0.648837   1538
# 2   0.000000  4.193299e-01  2.207749e-67  0.009346      2
# 3   0.000000  2.756193e-37  2.207749e-67  0.009346      3
# 4   0.419304  5.725064e-01  4.810798e-01  0.762988     19
# write json file 2016-04-12
#
# viz-data/__harvest3r_twitter_data_12-04_0.json
# Pre-processing 2016-04-13
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.012186        0.192157    0.144538  0.153676       0.656837
# 1     NE  -0.053946        0.000000    0.158200  0.178957       0.577350
# 2     SZ   0.000000        0.000000    0.000000       NaN            NaN
# 3     SO   0.000000        0.000000    0.000000  0.000000       0.000000
# 4     GE  -0.006502        0.044224    0.087865  0.122880       0.707958
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.360244  3.709886e-01  2.569077e-01  0.343857    255
# 1   0.200275  5.078767e-01  6.146885e-01  0.433625      7
# 2        NaN           NaN           NaN       NaN      1
# 3   0.000000  5.486589e-37  2.229784e-73  0.200323      4
# 4   0.390021  7.557952e-06  2.425353e-02  0.030206   1108
# write json file 2016-04-13
#
# viz-data/__harvest3r_twitter_data_13-04_0.json
# Pre-processing 2016-04-14
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.001248        0.186813    0.172777  0.127576       0.695237
# 1     NE   0.032460        0.230769    0.336077  0.129512       0.599145
# 2     SZ  -0.083333        0.000000   -0.421500       NaN            NaN
# 3     SO   0.000000        0.000000    0.000000  0.000000       0.000000
# 4     OW   0.000000        0.000000    0.000000       NaN            NaN
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.370634  6.049857e-01  4.284366e-02  0.958646    273
# 1   0.364455  6.964549e-01  5.945724e-02  0.396553     13
# 2        NaN           NaN           NaN       NaN      1
# 3   0.000000  1.885611e-44  2.304392e-85  0.692866      2
# 4        NaN           NaN           NaN       NaN      1
# write json file 2016-04-14
#
# viz-data/__harvest3r_twitter_data_14-04_0.json
# Pre-processing 2016-04-15
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.000820        0.187500    0.110241  0.130638       0.576541
# 1     NE   0.015919        0.400000    0.299590  0.059023       0.516398
# 2     TG   0.000000        0.000000   -0.118825  0.000000       0.816497
# 3     SO   0.014286        0.285714    0.230700  0.037796       0.487950
# 4     SG   0.006470        0.062500    0.145094  0.058101       0.771902
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.357958      0.861170  0.696120  0.419631    224
# 1   0.341532      0.240750  0.130894  0.625974     10
# 2   0.237650      0.666335  0.137959  0.002725      4
# 3   0.330783      0.639118  0.410059  0.606132      7
# 4   0.382256      0.504944  0.796165  0.998798     16
# write json file 2016-04-15
#
# viz-data/__harvest3r_twitter_data_15-04_0.json
# Pre-processing 2016-04-16
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     SG   0.009226        0.100000    0.083820  0.040962       0.567646
# 1     NE   0.004545        0.272727    0.145036  0.049492       0.467099
# 2     SZ   0.004167        0.000000    0.188387  0.061108       0.755929
# 3     SO   0.065972        0.125000    0.121987  0.418353       0.834523
# 4     GE  -0.003102        0.078271    0.086128  0.129263       0.731701
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.247359      0.669725  0.678513  0.473700     10
# 1   0.237126      0.524082  0.709279  0.738690     11
# 2   0.367154      0.524150  0.602306  0.830938      8
# 3   0.478835      0.859212  0.979450  0.666038      8
# 4   0.397105      0.000459  0.045329  0.643367    856
# write json file 2016-04-16
#
# viz-data/__harvest3r_twitter_data_16-04_0.json
# Pre-processing 2016-04-17
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.003839        0.218750    0.217434  0.132398       0.663295
# 1     NE   0.000000        0.000000    0.200150  0.000000       0.000000
# 2     VS   0.000000       -0.250000    0.074100  0.136080       0.500000
# 3     SO  -0.499992       -0.333333   -0.305700  0.500000       0.577350
# 4     SG  -0.014167        0.600000    0.168760  0.071903       0.547723
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.367910  8.533561e-01  0.014486  0.420273    128
# 1   0.283055  2.650646e-32  0.795492  0.092871      2
# 2   0.497587  1.645551e-01  0.826651  0.934742      4
# 3   0.265365  2.459842e-01  0.102598  0.221681      3
# 4   0.397169  1.844417e-01  0.852643  0.565071      5
# write json file 2016-04-17
#
# viz-data/__harvest3r_twitter_data_17-04_0.json
# Pre-processing 2016-04-18
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.012298        0.090361    0.074637  0.171314       0.621067
# 1     NE  -0.074208        0.000000    0.097700  0.096444       0.707107
# 2     SZ  -0.083332        0.000000   -0.120750  0.117849       0.000000
# 3     SO   0.015143        0.400000    0.214170  0.165687       0.516398
# 4     GE   0.001364        0.112661    0.086492  0.113586       0.727820
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.333106  1.115043e-01  0.123908  0.610638    166
# 1   0.404762  6.188892e-01  0.923547  0.138730      5
# 2   0.170766  4.532431e-36  0.299069  0.479946      2
# 3   0.302688  1.941252e-01  0.333866  0.856625     10
# 4   0.409449  3.502137e-02  0.052776  0.372442    932
# write json file 2016-04-18
#
# viz-data/__harvest3r_twitter_data_18-04_0.json
# Pre-processing 2016-04-19
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.006763        0.212903    0.163364  0.116169       0.634374
# 1     NE  -0.041724        0.153846    0.204746  0.137962       0.800641
# 2     VS   0.022780        0.142857    0.139500  0.084199       0.770329
# 3     SO  -0.033333        0.000000   -0.051833  0.057734       1.000000
# 4     SG   0.028313        0.111111    0.258500  0.103715       0.832352
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.356449      0.660461  0.227353  0.807150    155
# 1   0.383581      0.874170  0.483709  0.209297     13
# 2   0.358101      0.823392  0.904185  0.555978     14
# 3   0.307346      0.773579  0.418110  0.330699      3
# 4   0.338924      0.693809  0.120972  0.444880     18
# write json file 2016-04-19
#
# viz-data/__harvest3r_twitter_data_19-04_0.json
# Pre-processing 2016-04-20
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.015794        0.211982    0.201417  0.153497       0.639187
# 1     NE   0.147736        0.142857    0.173671  0.379784       0.899735
# 2     VS  -0.047992        0.058824    0.073447  0.110409       0.658653
# 3     SO   0.229670        0.600000    0.098780  0.432226       0.547723
# 4     SZ   0.000000        0.000000    0.000000       NaN            NaN
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.352981      0.351743  0.007642  0.452002    217
# 1   0.371938      0.938843  0.792053  0.367228      7
# 2   0.396634      0.497177  0.532807  0.054191     17
# 3   0.220879      0.154117  0.733567  0.314985      5
# 4        NaN           NaN       NaN       NaN      1
# write json file 2016-04-20
#
# viz-data/__harvest3r_twitter_data_20-04_0.json
# Pre-processing 2016-04-21
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.013332        0.235808    0.121336  0.131517       0.625715
# 1     ZH   0.003189        0.225352    0.135951  0.129732       0.692375
# 2     VS  -0.000923        0.357143    0.206464  0.048508       0.497245
# 3     SO   0.035398        0.428571    0.201829  0.119672       0.534522
# 4     SG  -0.003011        0.045455    0.040123  0.129945       0.722250
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.365377      0.127008  0.879929  0.209411    229
# 1   0.374055      0.009551  0.110768  0.774854   1491
# 2   0.310281      0.183955  0.304303  0.825892     14
# 3   0.461618      0.248418  0.646410  0.488884      7
# 4   0.299056      0.428455  0.239913  0.857860     22
# write json file 2016-04-21
#
# viz-data/__harvest3r_twitter_data_21-04_0.json
# Pre-processing 2016-04-22
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.003754        0.148936    0.122786  0.138286       0.653374
# 1     NE   0.008547        0.307692    0.201454  0.030816       0.480384
# 2     TG   0.000000        0.000000    0.000000  0.000000       0.000000
# 3     SO   0.055554        0.333333    0.215317  0.136078       0.516398
# 4     SG   0.016540        0.368421    0.287463  0.084478       0.760886
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.350563  8.153977e-01  9.258674e-01  0.663228    188
# 1   0.271835  2.921680e-01  3.044653e-01  0.975279     13
# 2   0.000000  2.777147e-40  4.655668e-74  0.000384      2
# 3   0.362914  4.498718e-01  5.499349e-01  0.433779      6
# 4   0.458411  2.498176e-01  1.299651e-01  0.676578     19
# write json file 2016-04-22
#
# viz-data/__harvest3r_twitter_data_22-04_0.json
# Pre-processing 2016-04-23
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.001762        0.192053    0.171395  0.153352       0.670475
# 1     NE  -0.030000        0.000000    0.133320  0.041499       0.707107
# 2     VS   0.053866        0.230769    0.133600  0.155880       0.438529
# 3     SO   0.099998        0.500000    0.329400  0.141419       0.707107
# 4     SG   0.018276       -0.333333   -0.275833  0.096454       0.816497
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.395997      0.993990  0.168488  0.500674    151
# 1   0.298113      0.575906  0.954815  0.117619      5
# 2   0.273742      0.760063  0.914935  0.299548     13
# 3   0.465842      0.648943  0.646798  0.522651      2
# 4   0.231536      0.175659  0.007985  0.784681      6
# write json file 2016-04-23
#
# viz-data/__harvest3r_twitter_data_23-04_0.json
# Pre-processing 2016-04-24
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.015572        0.180180    0.258968  0.133735        0.66330
# 1     NE   0.000000        0.000000    0.292950  0.000000        0.00000
# 2     VS  -0.026988       -0.125000   -0.014900  0.050796        0.64087
# 3     SO   0.000000        1.000000    0.658800       NaN            NaN
# 4     GE   0.001855        0.060976    0.060783  0.127642        0.71451
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.351135  9.704916e-01  0.000109  0.494721    111
# 1   0.414294  4.685590e-30  0.662820  0.024290      2
# 2   0.437739  2.173604e-01  0.408023  0.104873      8
# 3        NaN           NaN       NaN       NaN      1
# 4   0.388735  7.691009e-05  0.000282  0.387849    738
# write json file 2016-04-24
#
# viz-data/__harvest3r_twitter_data_24-04_0.json
# Pre-processing 2016-04-25
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010000        0.221591    0.157969  0.161364       0.643019
# 1     ZH   0.004128        0.212295    0.135679  0.139555       0.698067
# 2     TG   0.074999        0.750000    0.205850  0.095741       0.500000
# 3     SO   0.000000        0.000000    0.000000       NaN            NaN
# 4     SG   0.031151        0.357143    0.174493  0.060104       0.744946
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.342294      0.256348  0.079524  0.559591    176
# 1   0.360090      0.044350  0.045795  0.768153   1220
# 2   0.237830      0.100870  0.483302  0.228397      4
# 3        NaN           NaN       NaN       NaN      1
# 4   0.384562      0.351771  0.547609  0.102945     14
# write json file 2016-04-25
#
# viz-data/__harvest3r_twitter_data_25-04_0.json
# Pre-processing 2016-04-26
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.001776        0.096916    0.091571  0.124233       0.664750
# 1     NE  -0.002274        0.066667    0.267287  0.096793       0.798809
# 2     TG   0.000000        0.000000    0.000000  0.000000       0.000000
# 3     SO   0.000000        0.000000    0.296000       NaN            NaN
# 4     SG  -0.011765        0.100000    0.141775  0.040932       0.447214
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.362601  1.640392e-01  2.299607e-01  0.558901    227
# 1   0.311221  6.570807e-01  9.140206e-02  0.830577     15
# 2   0.000000  6.248449e-48  1.156272e-91  0.110698      5
# 3        NaN           NaN           NaN       NaN      1
# 4   0.258980  5.555386e-01  7.296553e-01  0.125475     20
# write json file 2016-04-26
#
# viz-data/__harvest3r_twitter_data_26-04_0.json
# Pre-processing 2016-04-27
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.012475        0.142857    0.154390  0.135532       0.663240
# 1     NE   0.047747        0.312500    0.242869  0.139087       0.478714
# 2     TG   0.055526        0.600000    0.003020  0.056963       0.547723
# 3     SO  -0.001099       -0.200000    0.039680  0.052471       0.447214
# 4     SG   0.003206        0.062500    0.103444  0.044324       0.573730
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.366550      0.568759  0.149571  0.438090    203
# 1   0.299793      0.254157  0.112584  0.237641     16
# 2   0.621950      0.154142  0.704788  0.117857      5
# 3   0.088727      0.137913  0.125821  0.810856      5
# 4   0.265621      0.465779  0.849997  0.881258     16
# write json file 2016-04-27
#
# viz-data/__harvest3r_twitter_data_27-04_0.json
# Pre-processing 2016-04-28
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.012121        0.156863    0.133954  0.131195       0.629512
# 1     NE   0.003218        0.181818    0.214500  0.073102       0.501081
# 2     VS   0.012740        0.214286    0.175614  0.153420       0.801784
# 3     SO  -0.001831        0.000000    0.120400  0.074192       1.000000
# 4     SG   0.012716        0.388889    0.214100  0.046785       0.607685
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.376935      0.645548  0.818604  0.249619    153
# 1   0.306722      0.992742  0.195856  0.858097     22
# 2   0.300812      0.878471  0.555315  0.767985     14
# 3   0.208539      0.783786  0.962343  0.963660      3
# 4   0.325875      0.165463  0.272798  0.285889     18
# write json file 2016-04-28
#
# viz-data/__harvest3r_twitter_data_28-04_0.json
# Pre-processing 2016-04-29
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.005557        0.204082    0.168667  0.115521       0.658475
# 1     ZH   0.008687        0.230059    0.165302  0.137176       0.688537
# 2     VS  -0.050355        0.277778    0.062206  0.194710       0.669113
# 3     SO  -0.187497        0.000000    0.012900  0.441935       0.000000
# 4     SG   0.032079        0.117647    0.168424  0.115134       0.781213
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.369537  3.579087e-01  0.088123  0.161527    245
# 1   0.363912  1.573712e-03  0.000585  0.405170   1517
# 2   0.301550  4.814826e-01  0.376606  0.242736     18
# 3   0.018243  4.344540e-48  0.033355  0.648164      2
# 4   0.372043  8.100779e-01  0.652624  0.352060     17
# write json file 2016-04-29
#
# viz-data/__harvest3r_twitter_data_29-04_0.json
# Pre-processing 2016-04-30
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE  -0.000160        0.177419    0.149697  0.162837       0.662286
# 1     NE   0.020833        0.333333    0.100700  0.051030       0.516398
# 2     TG   0.011905        0.000000   -0.098667  0.066282       1.000000
# 3     SO   0.000000        0.000000    0.000000       NaN            NaN
# 4     GE  -0.009627        0.086911    0.065186  0.118408       0.712119
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.362326      0.919098  0.303987  0.870451    186
# 1   0.168289      0.479995  0.777194  0.406065      6
# 2   0.170896      0.793547  0.154842  0.817369      3
# 3        NaN           NaN       NaN       NaN      1
# 4   0.402972      0.001326  0.000178  0.014493    955
# write json file 2016-04-30
#
# viz-data/__harvest3r_twitter_data_30-04_0.json
