# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

file_name = "data/output_tweets/sentiment_scored_english_tweets.csv"
print("Reading " + file_name + "\n");
data = pd.read_csv(file_name)
del data['Unnamed: 0']
print("Data shape : ")
print(data.shape)

print("Reading locations' mapping\n");
loc_to_canton = pd.read_csv('data/location_to_canton.csv')
del loc_to_canton['Unnamed: 0']
loc_to_canton.columns = [['canton','source_location']]
print(loc_to_canton.shape[0])
loc_to_canton.head()
# Out:
# Reading data/output_tweets/sentiment_scored_english_tweets.csv
#
# Data shape :
# (85405, 9)
# Reading locations' mapping
#
# 84
#   canton     source_location
# 0     ZH  Affoltern am Albis
# 1     ZH             Zuerich
# 2     ZH              Zurigo
# 3     ZH               Uster
# 4     ZH          Winterthur

# %%
print("Percentage of unrepresented cantons in the data :");
not_represented_cantons = loc_to_canton[loc_to_canton.source_location.isnull()]
print(not_represented_cantons.shape[0]/loc_to_canton.shape[0])
not_represented_cantons
# Out:
# Percentage of unrepresented cantons in the data :
# 0.023809523809523808
#    canton source_location
# 32     GL             NaN
# 33     ZG             NaN

# %%
data.head()
# Out:
#   lang                                               main  \
# 0   en  @ZHA_News https://youtu.be/UxQmxIm4q1s  Rest i...
# 1   en  Come and join me at our testing Roadshow on Ap...
# 2   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 3   en  Number crunching for the past week - 1 new unf...
# 4   en  Just posted a photo @ Langnau im Emmental http...
#
#               published sentiment source_location  \
# 0  2016-04-01T02:35:56Z  POSITIVE         Lucerna
# 1  2016-04-01T14:42:21Z  POSITIVE     Ennetbürgen
# 2  2016-04-01T21:50:50Z  NEGATIVE           Suica
# 3  2016-04-01T11:43:27Z   NEUTRAL            Arth
# 4  2016-04-01T06:31:13Z   NEUTRAL         Langnau
#
#                                              main_tk  \
# 0  ['https://youtu.be/UxQmxIm4q1s', 'Rest', 'in',...
# 1  ['Come', 'and', 'join', 'me', 'at', 'our', 'te...
# 2  ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 3  ['Number', 'crunching', 'for', 'the', 'past', ...
# 4  ['Just', 'posted', 'a', 'photo', '@', 'Langnau...
#
#                                      meaningful_main  clean_main_polarity  \
# 0  ['https://youtu.be/uxqmxim4q1s', 'rest', 'peac...             0.071428
# 1  ['com', 'join', 'test', 'roadshow', 'april', '...             0.071428
# 2  ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 3  ['numb', 'crunch', 'past', 'week', '-', '1', '...            -0.090908
# 4  ['just', 'post', 'photo', '@', 'langnau', 'im'...             0.000000
#
#    vader_polarity
# 0          0.8856
# 1          0.7644
# 2         -0.5848
# 3          0.0772
# 4          0.0000

# %%
data_new = pd.merge(data, loc_to_canton, on='source_location', how='left')
data_new.head()
# Out:
#   lang                                               main  \
# 0   en  @ZHA_News https://youtu.be/UxQmxIm4q1s  Rest i...
# 1   en  Come and join me at our testing Roadshow on Ap...
# 2   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 3   en  Number crunching for the past week - 1 new unf...
# 4   en  Just posted a photo @ Langnau im Emmental http...
#
#               published sentiment source_location  \
# 0  2016-04-01T02:35:56Z  POSITIVE         Lucerna
# 1  2016-04-01T14:42:21Z  POSITIVE     Ennetbürgen
# 2  2016-04-01T21:50:50Z  NEGATIVE           Suica
# 3  2016-04-01T11:43:27Z   NEUTRAL            Arth
# 4  2016-04-01T06:31:13Z   NEUTRAL         Langnau
#
#                                              main_tk  \
# 0  ['https://youtu.be/UxQmxIm4q1s', 'Rest', 'in',...
# 1  ['Come', 'and', 'join', 'me', 'at', 'our', 'te...
# 2  ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 3  ['Number', 'crunching', 'for', 'the', 'past', ...
# 4  ['Just', 'posted', 'a', 'photo', '@', 'Langnau...
#
#                                      meaningful_main  clean_main_polarity  \
# 0  ['https://youtu.be/uxqmxim4q1s', 'rest', 'peac...             0.071428
# 1  ['com', 'join', 'test', 'roadshow', 'april', '...             0.071428
# 2  ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 3  ['numb', 'crunch', 'past', 'week', '-', '1', '...            -0.090908
# 4  ['just', 'post', 'photo', '@', 'langnau', 'im'...             0.000000
#
#    vader_polarity canton
# 0          0.8856     LU
# 1          0.7644     NW
# 2         -0.5848    NaN
# 3          0.0772     SZ
# 4          0.0000     BE

# %%
not_mapped_data = data_new[(data_new.canton).isnull()]
percentage_not_mapped = not_mapped_data.shape[0] / data_new.shape[0]
print("Size of unmapped data : ")
print(not_mapped_data.shape[0])
print("Percentage of unmapped data : ")
print(percentage_not_mapped)
not_mapped_data.head()
# Out:
# Size of unmapped data :
# 56476
# Percentage of unmapped data :
# 0.6612727592061355
#    lang                                               main  \
# 2    en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 16   en  @detravoir Might this confirm the prophecy? pi...
# 17   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 18   en  Did some #GreenDay #acoustic. 21 Guns. #rock #...
# 20   en  @BlizzHeroes @DustinBrowder http://imgur.com/y...
#
#                published sentiment          source_location  \
# 2   2016-04-01T21:50:50Z  NEGATIVE                    Suica
# 16  2016-04-01T17:49:36Z   NEUTRAL  Confoederatio Helvetica
# 17  2016-04-01T20:51:10Z  NEGATIVE                    Suica
# 18  2016-04-01T20:27:24Z  POSITIVE  Confoederatio Helvetica
# 20  2016-04-01T00:23:23Z  NEGATIVE  Confoederatio Helvetica
#
#                                               main_tk  \
# 2   ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 16  ['Might', 'this', 'confirm', 'the', 'prophecy'...
# 17  ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 18  ['Did', 'some', '#GreenDay', '#acoustic', '.',...
# 20  ['http://imgur.com/yX89HVR', '...', 'why', '?'...
#
#                                       meaningful_main  clean_main_polarity  \
# 2   ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 16  ['might', 'confirm', 'prophecy', '?', 'pic.twi...             0.000000
# 17  ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 18  ['did', '#greenday', '#acoustic', '21', 'gun',...             0.000000
# 20  ['http://imgur.com/yx89hvr', '...', '?', 'yo',...            -0.142855
#
#     vader_polarity canton
# 2          -0.5848    NaN
# 16          0.0000    NaN
# 17         -0.5848    NaN
# 18          0.0000    NaN
# 20         -0.4939    NaN

# %%
# drop unmapped data
mapped_data = data_new.dropna(subset= ['canton'], how='all')
# take only relevent features
data_sent_canton = mapped_data[['canton','sentiment','clean_main_polarity','vader_polarity','published']]
print("Final data size : ")
print(data_sent_canton.shape[0])
data_sent_canton.head()
# Out:
# Final data size :
# 28929
#   canton sentiment  clean_main_polarity  vader_polarity             published
# 0     LU  POSITIVE             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW  POSITIVE             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ   NEUTRAL            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE   NEUTRAL             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR   NEUTRAL            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
def sentiment_value(name):
    if name == 'NEUTRAL':
        val = 0
    elif name == 'POSITIVE':
        val = 1
    elif name == 'NEGATIVE':
        val = -1
    else :
        val = np.NaN
    return val

# %%
data_sent_canton['sentiment'] = [sentiment_value(a) for a in data_sent_canton['sentiment']]
# Out:
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_sent_canton = data_sent_canton.dropna()

# %%
print(data_sent_canton.shape[0])
data_sent_canton.head()
# Out:
# 28929
#   canton  sentiment  clean_main_polarity  vader_polarity             published
# 0     LU          1             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW          1             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ          0            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE          0             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR          0            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
data_sent_canton['published'] = [a.split('T')[0] for a in data_sent_canton['published']]

# %%
data_sent_canton=data_sent_canton.rename(columns = {'published':'day'})
data_sent_canton.head()
# Out:
#   canton  sentiment  clean_main_polarity  vader_polarity         day
# 0     LU          1             0.071428          0.8856  2016-04-01
# 1     NW          1             0.071428          0.7644  2016-04-01
# 3     SZ          0            -0.090908          0.0772  2016-04-01
# 4     BE          0             0.000000          0.0000  2016-04-01
# 5     GR          0            -0.181817          0.0000  2016-04-01

# %%
data_day = data_sent_canton.groupby(['day'])
for name, group in data_day:
        print(name)
        #print(group)
data_day.describe()
# Out:
# 2016-04-01
# 2016-04-02
# 2016-04-03
# 2016-04-04
# 2016-04-05
# 2016-04-06
# 2016-04-07
# 2016-04-08
# 2016-04-09
# 2016-04-10
#                   clean_main_polarity    sentiment  vader_polarity
# day
# 2016-04-01 count          3484.000000  3484.000000     3484.000000
#            mean              0.008248     0.185132        0.137028
#            std               0.097688     0.698135        0.380699
#            min              -0.999900    -1.000000       -0.953100
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999950     1.000000        0.967000
# 2016-04-02 count          2401.000000  2401.000000     2401.000000
#            mean              0.005107     0.197418        0.134885
#            std               0.102178     0.713099        0.386179
#            min              -0.999900    -1.000000       -0.957800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999950     1.000000        0.967800
# 2016-04-03 count          2433.000000  2433.000000     2433.000000
#            mean              0.013380     0.233046        0.154358
#            std               0.107191     0.705029        0.378086
#            min              -0.999950    -1.000000       -0.938200
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.458800
#            max               0.999900     1.000000        0.956700
# 2016-04-04 count          3098.000000  3098.000000     3098.000000
#            mean              0.009511     0.178502        0.129564
#            std               0.091406     0.683371        0.371818
#            min              -0.999900    -1.000000       -0.943800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
# ...                               ...          ...             ...
# 2016-04-07 std               0.097695     0.705735        0.386876
#            min              -0.999967    -1.000000       -0.946800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.419900
#            max               0.999900     1.000000        0.971400
# 2016-04-08 count          3496.000000  3496.000000     3496.000000
#            mean              0.010809     0.161327        0.116078
#            std               0.094615     0.690216        0.384255
#            min              -0.999900    -1.000000       -0.964100
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.421500
#            max               0.999950     1.000000        0.980600
# 2016-04-09 count          2599.000000  2599.000000     2599.000000
#            mean              0.006973     0.200077        0.126580
#            std               0.098745     0.704096        0.387127
#            min              -0.999900    -1.000000       -0.981000
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999900     1.000000        0.955800
# 2016-04-10 count          2255.000000  2255.000000     2255.000000
#            mean              0.007493     0.177384        0.110590
#            std               0.100760     0.697647        0.393211
#            min              -0.999900    -1.000000       -0.951100
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999900     1.000000        0.997700
#
# [80 rows x 3 columns]

# %%
# Statistical test : day 1
data_single_day = data_day.get_group('2016-04-01')
data_single_day_gp = data_single_day.groupby('canton')
# p_values
data_single_day_p_values = pd.DataFrame(columns = ['canton','sentiment_pv','vader_pv','main_pv'])
for i,group in enumerate( data_single_day_gp.groups):
    
    data_c = data_single_day_gp.get_group(group)
    pv_sentiment = stats.ttest_ind(a = data_c.sentiment, b= data_single_day.sentiment, equal_var=False)[1]
    pv_vader = (stats.ttest_ind(a = data_c.vader_polarity, b= data_single_day.vader_polarity, equal_var=False))[1]
    pv_main = (stats.ttest_ind(a = data_c.clean_main_polarity, b= data_single_day.clean_main_polarity, equal_var=False))[1]
    data_single_day_p_values.loc[i] = [group, pv_sentiment, pv_vader, pv_main]
data_single_day_p_values = data_single_day_p_values.set_index('canton')
# mean
data_single_day_mean = data_single_day_gp.mean()
data_single_day_mean.columns = ['main_mean','sentiment_mean','vader_mean']
# std
data_single_day_std = data_single_day_gp.std()
data_single_day_std.columns = ['main_std','sentiment_std','vader_std']
# count
data_single_day_count = pd.DataFrame(data_single_day_gp.count()['sentiment'])
data_single_day_count.columns = ['count']
# concatenation
data_single_day = pd.concat([data_single_day_mean, data_single_day_std, data_single_day_p_values, data_single_day_count], axis = 1, join = 'inner')
data_single_day = data_single_day.reset_index()
data_single_day.head()
# Out:
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010975        0.158416    0.122261  0.113088       0.634539
# 1     NW   0.071428        1.000000    0.764400       NaN            NaN
# 2     FR   0.025523        0.240000    0.111044  0.096528       0.597216
# 3     VD  -0.001714        0.164062    0.124496  0.081044       0.696191
# 4     GE  -0.001956        0.069523    0.067172  0.097995       0.726309
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.368261      0.563529  5.807815e-01  0.737591    202
# 1        NaN           NaN           NaN       NaN      1
# 2   0.353070      0.651610  7.171860e-01  0.381363     25
# 3   0.397402      0.737204  7.261960e-01  0.177596    128
# 4   0.392874      0.000001  6.796775e-08  0.001662   1237

# %%
def day_preprocess(day):
    data_single_day = data_day.get_group(day)
    data_single_day_gp = data_single_day.groupby('canton')
    # p_values
    data_single_day_p_values = pd.DataFrame(columns = ['canton','sentiment_pv','vader_pv','main_pv'])
    for i,group in enumerate( data_single_day_gp.groups):
        data_c = data_single_day_gp.get_group(group)
        pv_sentiment = stats.ttest_ind(a = data_c.sentiment, b= data_single_day.sentiment, equal_var=False)[1]
        pv_vader = (stats.ttest_ind(a = data_c.vader_polarity, b= data_single_day.vader_polarity, equal_var=False))[1]
        pv_main = (stats.ttest_ind(a = data_c.clean_main_polarity, b= data_single_day.clean_main_polarity, equal_var=False))[1]
        data_single_day_p_values.loc[i] = [group, pv_sentiment, pv_vader, pv_main]
    data_single_day_p_values = data_single_day_p_values.set_index('canton')
    # mean
    data_single_day_mean = data_single_day_gp.mean()
    data_single_day_mean.columns = ['main_mean','sentiment_mean','vader_mean']
    # std
    data_single_day_std = data_single_day_gp.std()
    data_single_day_std.columns = ['main_std','sentiment_std','vader_std']
    # count
    data_single_day_count = pd.DataFrame(data_single_day_gp.count()['sentiment'])
    data_single_day_count.columns = ['count']
    # concatenation
    data_single_day = pd.concat([data_single_day_mean, data_single_day_std, data_single_day_p_values, data_single_day_count], axis = 1, join = 'inner')
    data_single_day = data_single_day.reset_index()
    return data_single_day

# %%
prefix="viz-data/__harvest3r_twitter_data_"
postfix = "-04_0.json"
for i in np.arange(10):
    if (i<9):
        day = '2016-04-0' + str(i+1)
    else : 
        day = '2016-04-' + str(i+1)
    print("Pre-processing " + day + "\n");
    data_sd = day_preprocess(day)
    print(data_sd.head())
    print("write json file " + day + "\n");
    if (i<9):
        day = '0' + str(i+1)
    else : 
        day = str(i+1)
    file_name = prefix + day + postfix
    print(file_name)
    data_sd.to_json(file_name)
# Out:
# Pre-processing 2016-04-01
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010975        0.158416    0.122261  0.113088       0.634539
# 1     NW   0.071428        1.000000    0.764400       NaN            NaN
# 2     FR   0.025523        0.240000    0.111044  0.096528       0.597216
# 3     VD  -0.001714        0.164062    0.124496  0.081044       0.696191
# 4     GE  -0.001956        0.069523    0.067172  0.097995       0.726309
#
#    vader_std  sentiment_pv      vader_pv   main_pv  count
# 0   0.368261      0.563529  5.807815e-01  0.737591    202
# 1        NaN           NaN           NaN       NaN      1
# 2   0.353070      0.651610  7.171860e-01  0.381363     25
# 3   0.397402      0.737204  7.261960e-01  0.177596    128
# 4   0.392874      0.000001  6.796775e-08  0.001662   1237
# write json file 2016-04-01
#
# viz-data/__harvest3r_twitter_data_01-04_0.json
# Pre-processing 2016-04-02
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010145        0.225434    0.173821  0.098628       0.682881
# 1     AG   0.005917        0.461538    0.245038  0.021334       0.660225
# 2     FR  -0.029090        0.100000    0.110670  0.066500       0.567646
# 3     VD   0.028342        0.315217    0.217420  0.106105       0.725203
# 4     TI  -0.014657        0.027778   -0.010394  0.109146       0.691441
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.374669      0.603927  0.189222  0.518153    173
# 1   0.410802      0.175725  0.353655  0.898958     13
# 2   0.243050      0.601521  0.760963  0.139406     10
# 3   0.436952      0.129254  0.077367  0.041664     92
# 4   0.371067      0.043895  0.001623  0.133551     72
# write json file 2016-04-02
#
# viz-data/__harvest3r_twitter_data_02-04_0.json
# Pre-processing 2016-04-03
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.016166        0.182353    0.121654  0.110242       0.667713
# 1     AG   0.029497        0.266667    0.087880  0.075242       0.593617
# 2     FR  -0.002057        0.185185    0.096204  0.226391       0.786278
# 3     VD   0.010482        0.220930    0.163912  0.150516       0.692840
# 4     GE   0.021908        0.179671    0.152202  0.100098       0.720823
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.351822      0.341543  0.245072  0.750003    170
# 1   0.270341      0.830209  0.359475  0.423178     15
# 2   0.360778      0.755317  0.412518  0.726270     27
# 3   0.434796      0.873804  0.841082  0.859926     86
# 4   0.390350      0.049565  0.883147  0.027845    974
# write json file 2016-04-03
#
# viz-data/__harvest3r_twitter_data_03-04_0.json
# Pre-processing 2016-04-04
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010252        0.153846    0.137911  0.099023       0.670557
# 1     AG   0.018269        0.153846    0.132146  0.064269       0.554700
# 2     VD   0.003609        0.142857    0.083637  0.092320       0.604060
# 3     GE   0.012188        0.154891    0.114291  0.083949       0.692214
# 4     BL  -0.066665       -0.333333   -0.329267  0.115468       0.577350
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.352683      0.608623  0.742252  0.916486    208
# 1   0.368570      0.875697  0.980304  0.633322     13
# 2   0.380326      0.596273  0.277530  0.564566     84
# 3   0.386303      0.328994  0.254827  0.374371   1104
# 4   0.299627      0.264342  0.117379  0.371519      3
# write json file 2016-04-04
#
# viz-data/__harvest3r_twitter_data_04-04_0.json
# Pre-processing 2016-04-05
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.012141        0.056769    0.081271  0.097643       0.593318
# 1     AG   0.000570        0.222222    0.128152  0.070195       0.697982
# 2     VS  -0.015542       -0.083333    0.136800  0.143858       0.668558
# 3     VD   0.020796        0.211765    0.135966  0.066726       0.691687
# 4     GE   0.007111        0.109023    0.094487  0.093086       0.705677
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.343299      0.015679  0.183801  0.607861    229
# 1   0.427562      0.630975  0.854077  0.554565     27
# 2   0.357609      0.240202  0.820899  0.571181     12
# 3   0.355994      0.470521  0.556347  0.107304     85
# 4   0.394986      0.055631  0.186529  0.627469   1064
# write json file 2016-04-05
#
# viz-data/__harvest3r_twitter_data_05-04_0.json
# Pre-processing 2016-04-06
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.015656        0.161074    0.140510  0.093089       0.593514
# 1     AG  -0.005367        0.352941    0.187759  0.056543       0.606339
# 2     VS   0.031658        0.400000    0.282733  0.107512       0.632456
# 3     GE  -0.000637        0.073469    0.070750  0.078644       0.726494
# 4     TI  -0.019173        0.039474    0.092955  0.101257       0.575981
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.311443      0.864618  0.235923  0.226807    149
# 1   0.347994      0.193104  0.365789  0.415368     17
# 2   0.383092      0.152784  0.101358  0.374980     15
# 3   0.409036      0.003186  0.010896  0.024611    980
# 4   0.264557      0.097470  0.610054  0.033852     76
# write json file 2016-04-06
#
# viz-data/__harvest3r_twitter_data_06-04_0.json
# Pre-processing 2016-04-07
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.013274        0.152466    0.107852  0.097993       0.639595
# 1     AG   0.012261        0.250000    0.081500  0.096439       0.675664
# 2     FR   0.039811       -0.185185   -0.037000  0.197120       0.622466
# 3     GE   0.005404        0.104697    0.092604  0.089420       0.727114
# 4     GR   0.000000        1.000000    0.458800       NaN            NaN
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.339887      0.765939  0.902136  0.362504    223
# 1   0.393509      0.548765  0.719754  0.795790     24
# 2   0.230920      0.007154  0.002791  0.396702     27
# 3   0.412423      0.018423  0.212458  0.607376   1022
# 4        NaN           NaN       NaN       NaN      1
# write json file 2016-04-07
#
# viz-data/__harvest3r_twitter_data_07-04_0.json
# Pre-processing 2016-04-08
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.019599        0.203125    0.146477  0.108340       0.635256
# 1     TI  -0.025725        0.044118    0.066541  0.110510       0.741797
# 2     VD   0.001139        0.196429    0.166318  0.090219       0.682329
# 3     GE   0.006619        0.068337    0.076443  0.085104       0.718751
# 4     BL   0.166661        0.500000    0.348300  0.235694       0.707107
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.348525      0.377938  0.243220  0.272001    192
# 1   0.399913      0.200606  0.314862  0.008553     68
# 2   0.399008      0.593160  0.191683  0.267156    112
# 3   0.408046      0.000054  0.002300  0.140032   1317
# 4   0.492571      0.620963  0.625626  0.521321      2
# write json file 2016-04-08
#
# viz-data/__harvest3r_twitter_data_08-04_0.json
# Pre-processing 2016-04-09
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     FR   0.087200        0.500000    0.226375  0.126235       0.755929
# 1     BE   0.009269        0.193548    0.139019  0.117689       0.610858
# 2     AG  -0.011937        0.103448    0.063528  0.127886       0.724314
# 3     VS  -0.025690        0.400000    0.178210  0.267009       0.598243
# 4     VD   0.005918        0.203704    0.144883  0.076435       0.710557
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.299139      0.299192  0.377649  0.115419      8
# 1   0.343320      0.889350  0.636633  0.795448    186
# 2   0.374234      0.480612  0.374601  0.433984     29
# 3   0.385543      0.153183  0.557726  0.590879     20
# 4   0.421071      0.970515  0.752705  0.920865     54
# write json file 2016-04-09
#
# viz-data/__harvest3r_twitter_data_09-04_0.json
# Pre-processing 2016-04-10
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     BE   0.010598        0.159236    0.127359  0.090469       0.615083
# 1     AG  -0.012305        0.388889    0.174106  0.042875       0.607685
# 2     FR   0.005573        0.125000    0.133033  0.054308       0.679674
# 3     GE   0.003125        0.080685    0.064985  0.101763       0.712431
# 4     BL  -0.062500       -1.000000    0.700300       NaN            NaN
#
#    vader_std  sentiment_pv  vader_pv   main_pv  count
# 0   0.366940      0.723612  0.582313  0.680408    157
# 1   0.414256      0.159736  0.525410  0.070743     18
# 2   0.264440      0.710674  0.684725  0.866322     24
# 3   0.427016      0.000848  0.007648  0.291903    818
# 4        NaN           NaN       NaN       NaN      1
# write json file 2016-04-10
#
# viz-data/__harvest3r_twitter_data_10-04_0.json

# %%
#statistical significance

import scipy.stats as stats

# day 
data_day1 = data_sent_canton[data_sent_canton.day == '2016-04-01']
#print(data_day1)
data_day2 = data_sent_canton[data_sent_canton.day == '2016-04-02']
#print(data_day2)
data_day3 = data_sent_canton[data_sent_canton.day == '2016-04-03']
#print(data_day3)
data_day4 = data_sent_canton[data_sent_canton.day == '2016-04-04']
#print(data_day4)
data_day5 = data_sent_canton[data_sent_canton.day == '2016-04-05']
#print(data_day5)

stats.friedmanchisquare(data_day1,data_day2,data_day3,data_day4,data_day5)

# %%
# canton
