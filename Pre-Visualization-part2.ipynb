# %%
import pandas as pd
import numpy as np

# %%
file_name = "data/output_tweets/sentiment_scored_english_tweets.csv"
print("Reading " + file_name + "\n");
data = pd.read_csv(file_name)
del data['Unnamed: 0']
print(data.shape)
# Out:
# Reading data/output_tweets/sentiment_scored_english_tweets.csv
#
# (43767, 9)

# %%
loc_to_canton = pd.read_csv('data/location_to_canton.csv')
del loc_to_canton['Unnamed: 0']

# %%
loc_to_canton.columns = [['canton','source_location']]
print(loc_to_canton.shape[0])
loc_to_canton.head()
# Out:
# 74
#   canton     source_location
# 0     ZH  Affoltern am Albis
# 1     ZH             Zuerich
# 2     ZH              Zurigo
# 3     ZH               Uster
# 4     ZH          Winterthur

# %%
not_represented_cantons = loc_to_canton[loc_to_canton.source_location.isnull()]
print(not_represented_cantons.shape[0]/loc_to_canton.shape[0])
not_represented_cantons
# Out:
# 0.04054054054054054
#    canton source_location
# 30     GL             NaN
# 31     ZG             NaN
# 44     AI             NaN

# %%
data.head()
# Out:
#   lang                                               main  \
# 0   en  @ZHA_News https://youtu.be/UxQmxIm4q1s  Rest i...
# 1   en  Come and join me at our testing Roadshow on Ap...
# 2   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 3   en  Number crunching for the past week - 1 new unf...
# 4   en  Just posted a photo @ Langnau im Emmental http...
#
#               published sentiment source_location  \
# 0  2016-04-01T02:35:56Z  POSITIVE         Lucerna
# 1  2016-04-01T14:42:21Z  POSITIVE     Ennetbürgen
# 2  2016-04-01T21:50:50Z  NEGATIVE           Suica
# 3  2016-04-01T11:43:27Z   NEUTRAL            Arth
# 4  2016-04-01T06:31:13Z   NEUTRAL         Langnau
#
#                                              main_tk  \
# 0  ['https://youtu.be/UxQmxIm4q1s', 'Rest', 'in',...
# 1  ['Come', 'and', 'join', 'me', 'at', 'our', 'te...
# 2  ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 3  ['Number', 'crunching', 'for', 'the', 'past', ...
# 4  ['Just', 'posted', 'a', 'photo', '@', 'Langnau...
#
#                                      meaningful_main  clean_main_polarity  \
# 0  ['https://youtu.be/uxqmxim4q1s', 'rest', 'peac...             0.071428
# 1  ['com', 'join', 'test', 'roadshow', 'april', '...             0.071428
# 2  ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 3  ['numb', 'crunch', 'past', 'week', '-', '1', '...            -0.090908
# 4  ['just', 'post', 'photo', '@', 'langnau', 'im'...             0.000000
#
#    vader_polarity
# 0          0.8856
# 1          0.7644
# 2         -0.5848
# 3          0.0772
# 4          0.0000

# %%
data_new = pd.merge(data, loc_to_canton, on='source_location', how='left')
data_new
# Out:
#       lang                                               main  \
# 0       en  @ZHA_News https://youtu.be/UxQmxIm4q1s  Rest i...
# 1       en  Come and join me at our testing Roadshow on Ap...
# 2       en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 3       en  Number crunching for the past week - 1 new unf...
# 4       en  Just posted a photo @ Langnau im Emmental http...
# 5       en  Europe's New Mars Mission Bringing NASA Radios...
# 6       en  I liked a @YouTube video http://youtu.be/LE1WG...
# 7       en  NASA's Spitzer Maps Climate Patterns on a Supe...
# 8       en  Microsoft’s HoloLens now available to develope...
# 9       en  "i will leave tomorrow's problem for tomorrow'...
# 10      en  #Agritech #startup @ecoRobotix provides a very...
# 11      en  .@v_ita1880 sur #Periscope : Before https://ww...
# 12      en  3 Followed, 4 Unfollowed me (monitored by http...
# 13      en  Forget Tolkien, the scientific tale of real-li...
# 14      en  Adrenalin junkie ski’s down from the peak of t...
# 15      en  I just earned the 'Bar Explorer (Level 35)' ba...
# 16      en  @detravoir Might this confirm the prophecy? pi...
# 17      en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 18      en  Did some #GreenDay #acoustic. 21 Guns. #rock #...
# 19      en  Swiss Interim Management - Jobs - Executive Se...
# 20      en  @BlizzHeroes @DustinBrowder http://imgur.com/y...
# 21      en                                @7UP Happy New Year
# 22      en     Today I became cool pic.twitter.com/x62GbeRCix
# 23      en  Tesla’s Model 3 is here—with a 215 mile range,...
# 24      en  Bitcoin could soon use more power than Denmark...
# 25      en  @Timbayens Cool = Goodlife. ;) pic.twitter.com...
# 26      en  Nicolaas Hertzsch, Head IBM Software Group, im...
# 27      en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 28      en  EN DIRECT sur #Periscope : awa https://www.per...
# 29      en  @7UP You don't even follow your No. 1 fan tho....
# ...    ...                                                ...
# 43737   en  ► WilliamHill Sports Bet £10 Get £20 Free Bet ...
# 43738   en                            Ndlozi is such a troll.
# 43739   en                        @ValeBiancoxx la perfection
# 43740   en  How to Fix the Android Play Store When It Cons...
# 43741   en  @JDSmith_Design That was all thanks to my smal...
# 43742   en  Wondering how to grow on twitter? I gained 10 ...
# 43743   en  #snapchat is great. I can now even try to CALL...
# 43744   en  About Those Mystery Droids In Star Wars: The F...
# 43745   en          getting heated in here ngl #RawAfterMania
# 43746   en  I think I was just bitten by a tick while taki...
# 43747   en  @Calamity_vt nope http://www.webcamsdemexico.c...
# 43748   en  @inkingtheirlove @woIvesmoon yesss there's eve...
# 43749   en  After experimenting with a curling wand i now ...
# 43750   en  New Smaller Roku Stick Makes It Easier to Watc...
# 43751   en       I wonder if moderation is a thing on Miitomo
# 43752   en         @MrabetNaddish I thought I'd find you here
# 43753   en  ‘Panama Papers’ bombshell reveals Secom founde...
# 43754   en  Have you ever felt stuck? Would you love to kn...
# 43755   en  #nowplaying Kaleo - (REP) No Good #Kaleo http:...
# 43756   en  Valve will let you watch Dota 2 games in virtu...
# 43757   en  We need to develop IT security talent and move...
# 43758   en  Panel discussion with the crew of "Batman v Su...
# 43759   en                                Math, not even once
# 43760   en  Fund run by David Cameron’s father avoided pay...
# 43761   en  @meaghan_newell lots of #prolife r #progun,sup...
# 43762   en  @mcloughlinseanm dont even know if tgat exists...
# 43763   en            Why doesn't anyone cover Dani Alves ffs
# 43764   en                            @burninghat hein dis :)
# 43765   en  "I am here to tell you why I will use every po...
# 43766   en  Perps of “far-right” hit-and-run on Muslim wom...
#
#                   published sentiment          source_location  \
# 0      2016-04-01T02:35:56Z  POSITIVE                  Lucerna
# 1      2016-04-01T14:42:21Z  POSITIVE              Ennetbürgen
# 2      2016-04-01T21:50:50Z  NEGATIVE                    Suica
# 3      2016-04-01T11:43:27Z   NEUTRAL                     Arth
# 4      2016-04-01T06:31:13Z   NEUTRAL                  Langnau
# 5      2016-04-01T13:42:13Z   NEUTRAL                Poschiavo
# 6      2016-04-01T15:46:19Z  POSITIVE                   Laufen
# 7      2016-04-01T13:40:43Z  POSITIVE                Poschiavo
# 8      2016-04-01T08:08:59Z  POSITIVE                Poschiavo
# 9      2016-04-01T16:15:46Z  NEGATIVE                   Schwyz
# 10     2016-04-01T13:29:36Z  POSITIVE                  Herisau
# 11     2016-04-01T19:30:08Z   NEUTRAL                  Ginevra
# 12     2016-04-01T15:01:05Z   NEUTRAL       Affoltern am Albis
# 13     2016-04-01T10:03:59Z  NEGATIVE                Poschiavo
# 14     2016-04-01T10:00:04Z   NEUTRAL                  Zermatt
# 15     2016-04-01T16:20:48Z   NEUTRAL                   Schwyz
# 16     2016-04-01T17:49:36Z   NEUTRAL  Confoederatio Helvetica
# 17     2016-04-01T20:51:10Z  NEGATIVE                    Suica
# 18     2016-04-01T20:27:24Z  POSITIVE  Confoederatio Helvetica
# 19     2016-04-01T13:51:19Z   NEUTRAL                  Herisau
# 20     2016-04-01T00:23:23Z  NEGATIVE  Confoederatio Helvetica
# 21     2016-04-01T22:32:07Z  POSITIVE  Confoederatio Helvetica
# 22     2016-04-01T22:33:00Z  POSITIVE  Confoederatio Helvetica
# 23     2016-04-01T10:08:54Z   NEUTRAL                Poschiavo
# 24     2016-04-01T08:06:50Z   NEUTRAL                Poschiavo
# 25     2016-04-01T22:35:41Z  POSITIVE  Confoederatio Helvetica
# 26     2016-04-01T10:21:04Z   NEUTRAL               Einsiedeln
# 27     2016-04-01T01:57:47Z  NEGATIVE                    Suica
# 28     2016-04-01T21:57:52Z   NEUTRAL                  Ginevra
# 29     2016-04-01T19:23:46Z  NEGATIVE  Confoederatio Helvetica
# ...                     ...       ...                      ...
# 43737  2016-04-05T17:18:30Z  POSITIVE              Switzerland
# 43738  2016-04-05T16:04:39Z   NEUTRAL              Switzerland
# 43739  2016-04-05T20:48:37Z  POSITIVE              Switzerland
# 43740  2016-04-05T16:01:18Z   NEUTRAL              Switzerland
# 43741  2016-04-05T19:28:52Z  POSITIVE              Switzerland
# 43742  2016-04-05T22:26:01Z  POSITIVE              Switzerland
# 43743  2016-04-05T18:53:22Z   NEUTRAL              Switzerland
# 43744  2016-04-05T21:21:14Z  NEGATIVE              Switzerland
# 43745  2016-04-05T01:05:06Z   NEUTRAL              Switzerland
# 43746  2016-04-05T10:45:37Z   NEUTRAL              Switzerland
# 43747  2016-04-05T21:01:52Z   NEUTRAL              Switzerland
# 43748  2016-04-05T16:07:01Z   NEUTRAL              Switzerland
# 43749  2016-04-05T20:35:59Z  POSITIVE              Switzerland
# 43750  2016-04-05T13:29:03Z   NEUTRAL              Switzerland
# 43751  2016-04-05T17:34:42Z  POSITIVE              Switzerland
# 43752  2016-04-05T17:54:58Z   NEUTRAL              Switzerland
# 43753  2016-04-05T03:11:53Z   NEUTRAL              Switzerland
# 43754  2016-04-05T10:45:40Z  NEGATIVE              Switzerland
# 43755  2016-04-05T14:19:10Z  POSITIVE              Switzerland
# 43756  2016-04-05T21:38:21Z   NEUTRAL              Switzerland
# 43757  2016-04-05T16:10:25Z  POSITIVE              Switzerland
# 43758  2016-04-05T17:00:23Z  POSITIVE              Switzerland
# 43759  2016-04-05T14:22:10Z   NEUTRAL              Switzerland
# 43760  2016-04-05T02:01:37Z   NEUTRAL              Switzerland
# 43761  2016-04-05T07:34:35Z  NEGATIVE              Switzerland
# 43762  2016-04-05T00:17:53Z   NEUTRAL              Switzerland
# 43763  2016-04-05T20:38:29Z   NEUTRAL              Switzerland
# 43764  2016-04-05T09:27:46Z  POSITIVE              Switzerland
# 43765  2016-04-05T15:59:12Z  POSITIVE              Switzerland
# 43766  2016-04-05T07:09:28Z  POSITIVE              Switzerland
#
#                                                  main_tk  \
# 0      ['https://youtu.be/UxQmxIm4q1s', 'Rest', 'in',...
# 1      ['Come', 'and', 'join', 'me', 'at', 'our', 'te...
# 2      ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 3      ['Number', 'crunching', 'for', 'the', 'past', ...
# 4      ['Just', 'posted', 'a', 'photo', '@', 'Langnau...
# 5      ["Europe's", 'New', 'Mars', 'Mission', 'Bringi...
# 6      ['I', 'liked', 'a', 'video', 'http://youtu.be/...
# 7      ["NASA's", 'Spitzer', 'Maps', 'Climate', 'Patt...
# 8      ['Microsoft', '’', 's', 'HoloLens', 'now', 'av...
# 9      ['"', 'i', 'will', 'leave', "tomorrow's", 'pro...
# 10     ['#Agritech', '#startup', 'provides', 'a', 've...
# 11     ['.', '@v_ita1880', 'sur', '#Periscope', ':', ...
# 12     ['3', 'Followed', ',', '4', 'Unfollowed', 'me'...
# 13     ['Forget', 'Tolkien', ',', 'the', 'scientific'...
# 14     ['Adrenalin', 'junkie', 'ski', '’', 's', 'down...
# 15     ['I', 'just', 'earned', 'the', "'", 'Bar', 'Ex...
# 16     ['Might', 'this', 'confirm', 'the', 'prophecy'...
# 17     ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 18     ['Did', 'some', '#GreenDay', '#acoustic', '.',...
# 19     ['Swiss', 'Interim', 'Management', '-', 'Jobs'...
# 20     ['http://imgur.com/yX89HVR', '...', 'why', '?'...
# 21                      ['@7UP', 'Happy', 'New', 'Year']
# 22     ['Today', 'I', 'became', 'cool', 'pic.twitter....
# 23     ['Tesla', '’', 's', 'Model', '3', 'is', 'here'...
# 24     ['Bitcoin', 'could', 'soon', 'use', 'more', 'p...
# 25     ['Cool', '=', 'Goodlife', '.', ';)', 'pic.twit...
# 26     ['Nicolaas', 'Hertzsch', ',', 'Head', 'IBM', '...
# 27     ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 28     ['EN', 'DIRECT', 'sur', '#Periscope', ':', 'aw...
# 29     ['@7UP', 'You', "don't", 'even', 'follow', 'yo...
# ...                                                  ...
# 43737  ['►', 'WilliamHill', 'Sports', 'Bet', '£', '10...
# 43738        ['Ndlozi', 'is', 'such', 'a', 'troll', '.']
# 43739                               ['la', 'perfection']
# 43740  ['How', 'to', 'Fix', 'the', 'Android', 'Play',...
# 43741  ['That', 'was', 'all', 'thanks', 'to', 'my', '...
# 43742  ['Wondering', 'how', 'to', 'grow', 'on', 'twit...
# 43743  ['#snapchat', 'is', 'great', '.', 'I', 'can', ...
# 43744  ['About', 'Those', 'Mystery', 'Droids', 'In', ...
# 43745  ['getting', 'heated', 'in', 'here', 'ngl', '#R...
# 43746  ['I', 'think', 'I', 'was', 'just', 'bitten', '...
# 43747  ['nope', 'http://www.webcamsdemexico.com/webca...
# 43748  ['yesss', "there's", 'even', 'my', 'name', 'in...
# 43749  ['After', 'experimenting', 'with', 'a', 'curli...
# 43750  ['New', 'Smaller', 'Roku', 'Stick', 'Makes', '...
# 43751  ['I', 'wonder', 'if', 'moderation', 'is', 'a',...
# 43752     ['I', 'thought', "I'd", 'find', 'you', 'here']
# 43753  ['‘', 'Panama', 'Papers', '’', 'bombshell', 'r...
# 43754  ['Have', 'you', 'ever', 'felt', 'stuck', '?', ...
# 43755  ['#nowplaying', 'Kaleo', '-', '(', 'REP', ')',...
# 43756  ['Valve', 'will', 'let', 'you', 'watch', 'Dota...
# 43757  ['We', 'need', 'to', 'develop', 'IT', 'securit...
# 43758  ['Panel', 'discussion', 'with', 'the', 'crew',...
# 43759               ['Math', ',', 'not', 'even', 'once']
# 43760  ['Fund', 'run', 'by', 'David', 'Cameron', '’',...
# 43761  ['lots', 'of', '#prolife', 'r', '#progun', ','...
# 43762  ['dont', 'even', 'know', 'if', 'tgat', 'exists...
# 43763  ['Why', "doesn't", 'anyone', 'cover', 'Dani', ...
# 43764                              ['hein', 'dis', ':)']
# 43765  ['"', 'I', 'am', 'here', 'to', 'tell', 'you', ...
# 43766  ['Perps', 'of', '“', 'far-right', '”', 'hit-an...
#
#                                          meaningful_main  clean_main_polarity  \
# 0      ['https://youtu.be/uxqmxim4q1s', 'rest', 'peac...             0.071428
# 1      ['com', 'join', 'test', 'roadshow', 'april', '...             0.071428
# 2      ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 3      ['numb', 'crunch', 'past', 'week', '-', '1', '...            -0.090908
# 4      ['just', 'post', 'photo', '@', 'langnau', 'im'...             0.000000
# 5      ["europe's", 'new', 'mar', 'miss', 'bring', 'n...            -0.181817
# 6      ['i', 'lik', 'video', 'http://youtu.be/le1wgmr...             0.099999
# 7      ["nasa's", 'spitz', 'map', 'clim', 'pattern', ...             0.000000
# 8      ['microsoft', '’', 'holol', 'avail', 'develop'...             0.000000
# 9      ['"', 'leav', "tomorrow's", 'problem', "tomorr...            -0.111110
# 10     ['#agritech', '#startup', 'provid', 'us', '#we...             0.045454
# 11     ['@v_ita1880', 'sur', '#periscope', ':', 'bef'...             0.000000
# 12     ['3', 'follow', ',', 'unfollow', '(', 'monit',...             0.000000
# 13     ['forget', 'tolky', ',', 'sci', 'tal', 'real-l...            -0.076922
# 14     ['adrenalin', 'junky', 'ski', '’', 'peak', '#m...            -0.142855
# 15     ['i', 'earn', "'", 'bar', 'expl', '(', 'level'...             0.000000
# 16     ['might', 'confirm', 'prophecy', '?', 'pic.twi...             0.000000
# 17     ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 18     ['did', '#greenday', '#acoustic', '21', 'gun',...             0.000000
# 19     ['swiss', 'interim', 'man', '-', 'job', '-', '...             0.050000
# 20     ['http://imgur.com/yx89hvr', '...', '?', 'yo',...            -0.142855
# 21                      ['@7up', 'happy', 'new', 'year']             0.249994
# 22     ['today', 'i', 'becam', 'cool', 'pic.twitter.c...             0.199996
# 23     ['tesl', '’', 'model', '3', '—', '215', 'mil',...             0.000000
# 24     ['bitcoin', 'soon', 'us', 'pow', 'denmark', ',...             0.000000
# 25     ['cool', '=', 'goodl', ';)', 'pic.twitter.com/...             0.199996
# 26     ['nicolaa', 'hertzsch', ',', 'head', 'ibm', 's...             0.000000
# 27     ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 28     ['en', 'direct', 'sur', '#periscope', ':', 'aw...             0.000000
# 29     ['@7up', 'you', 'ev', 'follow', 'no', '1', 'fa...            -0.099999
# ...                                                  ...                  ...
# 43737  ['►', 'williamhil', 'sport', 'bet', '£', '10',...             0.000000
# 43738                                 ['ndlozi', 'trol']             0.000000
# 43739                                  ['la', 'perfect']             0.499975
# 43740  ['how', 'fix', 'android', 'play', 'stor', 'whe...             0.000000
# 43741  ['that', 'thank', 'smal', 'sist', 'opin', 'but...             0.111110
# 43742  ['wond', 'grow', 'twit', '?', 'i', 'gain', '10...             0.071428
# 43743  ['#snapchat', 'gre', 'i', 'ev', 'try', 'cal', ...             0.000000
# 43744  ['about', 'thos', 'mystery', 'droid', 'in', 's...            -0.076922
# 43745           ['get', 'heat', 'ngl', '#rawaftermania']             0.000000
# 43746  ['i', 'think', 'i', 'bit', 'tick', 'tak', 'sho...             0.000000
# 43747  ['nop', 'http://www.webcamsdemexico.com/webcam...             0.000000
# 43748                                ['ye', 'ev', 'nam']             0.000000
# 43749  ['aft', 'expery', 'curl', 'wand', 'look', 'exa...             0.000000
# 43750  ['new', 'smal', 'roku', 'stick', 'mak', 'it', ...             0.000000
# 43751           ['i', 'wond', 'mod', 'thing', 'miitomo']             0.000000
# 43752                    ['i', 'thought', "i'd", 'find']             0.000000
# 43753  ['‘', 'panam', 'pap', '’', 'bombshel', 'rev', ...             0.000000
# 43754  ['hav', 'ev', 'felt', 'stuck', '?', 'would', '...            -0.062500
# 43755  ['#nowplaying', 'kaleo', '-', '(', 'rep', ')',...             0.090908
# 43756  ['valv', 'let', 'watch', 'dot', 'gam', 'virt',...             0.000000
# 43757  ['we', 'nee', 'develop', 'it', 'sec', 'tal', '...             0.083333
# 43758  ['panel', 'discuss', 'crew', '"', 'batm', 'v',...             0.055555
# 43759                                ['math', ',', 'ev']             0.000000
# 43760  ['fund', 'run', 'david', 'cameron', '’', 'fath...             0.000000
# 43761  ['lot', '#prolife', 'r', '#progun', ',', 'supp...             0.071428
# 43762        ['dont', 'ev', 'know', 'tgat', 'ex', 'ffs']             0.000000
# 43763       ['why', 'anyon', 'cov', 'dan', 'alv', 'ffs']             0.000000
# 43764                              ['hein', 'dis', ':)']             0.000000
# 43765  ['"', 'i', 'tel', 'i', 'us', 'every', 'pow', '...             0.038461
# 43766  ['perp', '“', 'far-right', '”', 'hit-and-run',...             0.000000
#
#        vader_polarity canton
# 0              0.8856     LU
# 1              0.7644     NW
# 2             -0.5848    NaN
# 3              0.0772     SZ
# 4              0.0000     BE
# 5              0.0000     GR
# 6              0.6249     BL
# 7              0.0000     GR
# 8              0.0000     GR
# 9             -0.4404     SZ
# 10             0.6115     AR
# 11             0.0000     GE
# 12             0.0000     ZH
# 13            -0.2263     GR
# 14             0.0000     VS
# 15             0.0000     SZ
# 16             0.0000    NaN
# 17            -0.5848    NaN
# 18             0.0000    NaN
# 19             0.2023     AR
# 20            -0.4939    NaN
# 21             0.5719    NaN
# 22             0.3182    NaN
# 23             0.0000     GR
# 24             0.5499     GR
# 25             0.4939    NaN
# 26             0.0000     SZ
# 27            -0.5848    NaN
# 28             0.0000     GE
# 29            -0.4588    NaN
# ...               ...    ...
# 43737          0.5106    NaN
# 43738          0.0000    NaN
# 43739          0.5719    NaN
# 43740          0.3400    NaN
# 43741          0.7964    NaN
# 43742          0.4515    NaN
# 43743          0.6249    NaN
# 43744         -0.5574    NaN
# 43745          0.0000    NaN
# 43746         -0.3400    NaN
# 43747          0.0000    NaN
# 43748          0.0000    NaN
# 43749          0.6597    NaN
# 43750          0.0258    NaN
# 43751          0.0000    NaN
# 43752          0.0000    NaN
# 43753          0.0000    NaN
# 43754          0.5514    NaN
# 43755          0.1779    NaN
# 43756          0.0000    NaN
# 43757          0.6369    NaN
# 43758          0.6597    NaN
# 43759          0.0000    NaN
# 43760         -0.3400    NaN
# 43761         -0.8074    NaN
# 43762         -0.5859    NaN
# 43763         -0.5859    NaN
# 43764          0.4588    NaN
# 43765         -0.3400    NaN
# 43766          0.0000    NaN
#
# [43767 rows x 10 columns]

# %%
not_mapped_data = data_new[(data_new.canton).isnull()]
percentage_not_mapped = not_mapped_data.shape[0] / data_new.shape[0]
print(not_mapped_data.shape[0])
print(percentage_not_mapped)
not_mapped_data.head()
# Out:
# 29134
# 0.6656613430209976
#    lang                                               main  \
# 2    en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 16   en  @detravoir Might this confirm the prophecy? pi...
# 17   en              Bad Apple! pic.twitter.com/Xad2aVOHFd
# 18   en  Did some #GreenDay #acoustic. 21 Guns. #rock #...
# 20   en  @BlizzHeroes @DustinBrowder http://imgur.com/y...
#
#                published sentiment          source_location  \
# 2   2016-04-01T21:50:50Z  NEGATIVE                    Suica
# 16  2016-04-01T17:49:36Z   NEUTRAL  Confoederatio Helvetica
# 17  2016-04-01T20:51:10Z  NEGATIVE                    Suica
# 18  2016-04-01T20:27:24Z  POSITIVE  Confoederatio Helvetica
# 20  2016-04-01T00:23:23Z  NEGATIVE  Confoederatio Helvetica
#
#                                               main_tk  \
# 2   ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 16  ['Might', 'this', 'confirm', 'the', 'prophecy'...
# 17  ['Bad', 'Apple', '!', 'pic.twitter.com/Xad2aVO...
# 18  ['Did', 'some', '#GreenDay', '#acoustic', '.',...
# 20  ['http://imgur.com/yX89HVR', '...', 'why', '?'...
#
#                                       meaningful_main  clean_main_polarity  \
# 2   ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 16  ['might', 'confirm', 'prophecy', '?', 'pic.twi...             0.000000
# 17  ['bad', 'appl', '!', 'pic.twitter.com/xad2avoh...            -0.249994
# 18  ['did', '#greenday', '#acoustic', '21', 'gun',...             0.000000
# 20  ['http://imgur.com/yx89hvr', '...', '?', 'yo',...            -0.142855
#
#     vader_polarity canton
# 2          -0.5848    NaN
# 16          0.0000    NaN
# 17         -0.5848    NaN
# 18          0.0000    NaN
# 20         -0.4939    NaN

# %%
mapped_data = data_new.dropna(subset= ['canton'], how='all')
data_sent_canton = mapped_data[['canton','sentiment','clean_main_polarity','vader_polarity','published']]
print(data_sent_canton.shape[0])
data_sent_canton.head()
# Out:
# 14633
#   canton sentiment  clean_main_polarity  vader_polarity             published
# 0     LU  POSITIVE             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW  POSITIVE             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ   NEUTRAL            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE   NEUTRAL             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR   NEUTRAL            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
data_sent_canton.head()
# Out:
#   canton sentiment  clean_main_polarity  vader_polarity             published
# 0     LU  POSITIVE             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW  POSITIVE             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ   NEUTRAL            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE   NEUTRAL             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR   NEUTRAL            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
def sentiment_value(name):
    if name == 'NEUTRAL':
        val = 0
    elif name == 'POSITIVE':
        val = 1
    elif name == 'NEGATIVE':
        val = -1
    else :
        val = np.NaN
    return val

# %%
data_sent_canton['sentiment'] = [sentiment_value(a) for a in data_sent_canton['sentiment']]
# Out:
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_sent_canton = data_sent_canton.dropna()

# %%
print(data_sent_canton.shape[0])
data_sent_canton.head()
# Out:
# 14633
#   canton  sentiment  clean_main_polarity  vader_polarity             published
# 0     LU          1             0.071428          0.8856  2016-04-01T02:35:56Z
# 1     NW          1             0.071428          0.7644  2016-04-01T14:42:21Z
# 3     SZ          0            -0.090908          0.0772  2016-04-01T11:43:27Z
# 4     BE          0             0.000000          0.0000  2016-04-01T06:31:13Z
# 5     GR          0            -0.181817          0.0000  2016-04-01T13:42:13Z

# %%
data_sent_canton['published'] = [a.split('T')[0] for a in data_sent_canton['published']]

# %%
data_sent_canton=data_sent_canton.rename(columns = {'published':'day'})
data_sent_canton.head()
# Out:
#   canton  sentiment  clean_main_polarity  vader_polarity         day
# 0     LU          1             0.071428          0.8856  2016-04-01
# 1     NW          1             0.071428          0.7644  2016-04-01
# 3     SZ          0            -0.090908          0.0772  2016-04-01
# 4     BE          0             0.000000          0.0000  2016-04-01
# 5     GR          0            -0.181817          0.0000  2016-04-01

# %%
data_day = data_sent_canton.groupby(['day'])
data_day.describe()
# Out:
#                   clean_main_polarity    sentiment  vader_polarity
# day
# 2016-04-01 count          3484.000000  3484.000000     3484.000000
#            mean              0.008210     0.185132        0.137028
#            std               0.097494     0.698135        0.380699
#            min              -0.999900    -1.000000       -0.953100
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999950     1.000000        0.967000
# 2016-04-02 count          2401.000000  2401.000000     2401.000000
#            mean              0.005083     0.197418        0.134885
#            std               0.102137     0.713099        0.386179
#            min              -0.999900    -1.000000       -0.957800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999950     1.000000        0.967800
# 2016-04-03 count          2433.000000  2433.000000     2433.000000
#            mean              0.013343     0.233046        0.154358
#            std               0.107105     0.705029        0.378086
#            min              -0.999950    -1.000000       -0.938200
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.458800
#            max               0.999900     1.000000        0.956700
# 2016-04-04 count          3098.000000  3098.000000     3098.000000
#            mean              0.009424     0.178502        0.129564
#            std               0.091055     0.683371        0.371818
#            min              -0.999900    -1.000000       -0.943800
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.440400
#            max               0.999900     1.000000        0.996000
# 2016-04-05 count          3217.000000  3217.000000     3217.000000
#            mean              0.008709     0.156668        0.112817
#            std               0.094934     0.696705        0.383792
#            min              -0.666644    -1.000000       -0.959000
#            25%               0.000000     0.000000        0.000000
#            50%               0.000000     0.000000        0.000000
#            75%               0.000000     1.000000        0.421500
#            max               0.999967     1.000000        0.964800

# %%
for name, group in data_day:
        print(name)
        #print(group)
# Out:
# 2016-04-01
# 2016-04-02
# 2016-04-03
# 2016-04-04
# 2016-04-05

# %%
data_single_day = data_day.get_group('2016-04-01')
data_single_day_gp = data_single_day.groupby('canton')
data_single_day_mean = data_single_day_gp.mean()
data_single_day_mean.columns = ['main_mean','sentiment_mean','vader_mean']
data_single_day_std = data_single_day_gp.std()
data_single_day_std.columns = ['main_std','sentiment_std','vader_std']
data_single_day_count = pd.DataFrame(data_single_day_gp.count()['sentiment'])
data_single_day_count.columns = ['count']

data_single_day = pd.concat([data_single_day_mean, data_single_day_std, data_single_day_count], axis = 1, join = 'inner')
data_single_day
# Out:
#         main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# canton
# AG      -0.026587        0.000000    0.071470  0.164956       0.794719
# AR       0.148861        0.250000    0.490125  0.235173       0.957427
# BE       0.010975        0.158416    0.122261  0.113088       0.634539
# BL       0.099999        1.000000    0.624900       NaN            NaN
# BS       0.012385        0.197080    0.141170  0.084776       0.673440
# FR       0.025523        0.240000    0.111044  0.096528       0.597216
# GE      -0.001906        0.069523    0.067172  0.097805       0.726309
# GR      -0.032342        0.125000    0.040450  0.066123       0.640870
# JU       0.000000        0.000000    0.000000       NaN            NaN
# LU       0.017455        0.277778    0.282889  0.119415       0.741085
# NE       0.016783        0.600000    0.255290  0.035535       0.516398
# NW       0.071428        1.000000    0.764400       NaN            NaN
# SG      -0.000404        0.500000    0.257986  0.070234       0.518875
# SH       0.000000        0.200000    0.100900  0.000000       0.447214
# SZ      -0.050505       -0.250000   -0.090800  0.058898       0.500000
# TG      -0.142855        0.000000    0.000000       NaN            NaN
# TI      -0.021277       -0.042254    0.058837  0.088381       0.619599
# VD      -0.001714        0.164062    0.124496  0.081044       0.696191
# VS       0.036415        0.375000    0.300394  0.267161       0.718795
# ZH       0.017360        0.283429    0.192572  0.092048       0.674884
#
#         vader_std  count
# canton
# AG       0.406203     20
# AR       0.248201      4
# BE       0.368261    202
# BL            NaN      1
# BS       0.383024    137
# FR       0.353070     25
# GE       0.392874   1237
# GR       0.220555      8
# JU            NaN      1
# LU       0.366652     36
# NE       0.281344     10
# NW            NaN      1
# SG       0.360035     14
# SH       0.475233      5
# SZ       0.235891      4
# TG            NaN      1
# TI       0.326736     71
# VD       0.397402    128
# VS       0.337603     16
# ZH       0.365167   1563

# %%
data_single_day = data_single_day.reset_index()
data_single_day
# Out:
#    canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0      AG  -0.026587        0.000000    0.071470  0.164956       0.794719
# 1      AR   0.148861        0.250000    0.490125  0.235173       0.957427
# 2      BE   0.010975        0.158416    0.122261  0.113088       0.634539
# 3      BL   0.099999        1.000000    0.624900       NaN            NaN
# 4      BS   0.012385        0.197080    0.141170  0.084776       0.673440
# 5      FR   0.025523        0.240000    0.111044  0.096528       0.597216
# 6      GE  -0.001906        0.069523    0.067172  0.097805       0.726309
# 7      GR  -0.032342        0.125000    0.040450  0.066123       0.640870
# 8      JU   0.000000        0.000000    0.000000       NaN            NaN
# 9      LU   0.017455        0.277778    0.282889  0.119415       0.741085
# 10     NE   0.016783        0.600000    0.255290  0.035535       0.516398
# 11     NW   0.071428        1.000000    0.764400       NaN            NaN
# 12     SG  -0.000404        0.500000    0.257986  0.070234       0.518875
# 13     SH   0.000000        0.200000    0.100900  0.000000       0.447214
# 14     SZ  -0.050505       -0.250000   -0.090800  0.058898       0.500000
# 15     TG  -0.142855        0.000000    0.000000       NaN            NaN
# 16     TI  -0.021277       -0.042254    0.058837  0.088381       0.619599
# 17     VD  -0.001714        0.164062    0.124496  0.081044       0.696191
# 18     VS   0.036415        0.375000    0.300394  0.267161       0.718795
# 19     ZH   0.017360        0.283429    0.192572  0.092048       0.674884
#
#     vader_std  count
# 0    0.406203     20
# 1    0.248201      4
# 2    0.368261    202
# 3         NaN      1
# 4    0.383024    137
# 5    0.353070     25
# 6    0.392874   1237
# 7    0.220555      8
# 8         NaN      1
# 9    0.366652     36
# 10   0.281344     10
# 11        NaN      1
# 12   0.360035     14
# 13   0.475233      5
# 14   0.235891      4
# 15        NaN      1
# 16   0.326736     71
# 17   0.397402    128
# 18   0.337603     16
# 19   0.365167   1563

# %%
def day_preprocess(day):
    data_single_day = data_day.get_group(day)
    data_single_day_gp = data_single_day.groupby('canton')
    data_single_day_mean = data_single_day_gp.mean()
    data_single_day_mean.columns = ['main_mean','sentiment_mean','vader_mean']
    data_single_day_std = data_single_day_gp.std()
    data_single_day_std.columns = ['main_std','sentiment_std','vader_std']
    data_single_day_count = pd.DataFrame(data_single_day_gp.count()['sentiment'])
    data_single_day_count.columns = ['count']
    data_single_day = pd.concat([data_single_day_mean, data_single_day_std, data_single_day_count], axis = 1, join = 'inner')
    return data_single_day.reset_index()

# %%
prefix="viz-data/__harvest3r_twitter_data_0"
postfix = "-04_0.json"
for i in np.arange(5):
    day = '2016-04-0' + str(i+1)
    print("Pre-processing " + day + "\n");
    data_sd = day_preprocess(day)
    print(data_sd.head())
    print("write json file " + day + "\n");
    file_name = prefix + str(i+1) + postfix
    data_sd.to_json(file_name)
# Out:
# Pre-processing 2016-04-01
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     AG  -0.026587        0.000000    0.071470  0.164956       0.794719
# 1     AR   0.148861        0.250000    0.490125  0.235173       0.957427
# 2     BE   0.010975        0.158416    0.122261  0.113088       0.634539
# 3     BL   0.099999        1.000000    0.624900       NaN            NaN
# 4     BS   0.012385        0.197080    0.141170  0.084776       0.673440
#
#    vader_std  count
# 0   0.406203     20
# 1   0.248201      4
# 2   0.368261    202
# 3        NaN      1
# 4   0.383024    137
# write json file 2016-04-01
#
# Pre-processing 2016-04-02
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     AG   0.005917        0.461538    0.245038  0.021334       0.660225
# 1     BE   0.010145        0.225434    0.173821  0.098628       0.682881
# 2     BL   0.000000        1.000000    0.000000       NaN            NaN
# 3     BS  -0.016808        0.020408    0.134133  0.084383       0.786216
# 4     FR  -0.029090        0.100000    0.110670  0.066500       0.567646
#
#    vader_std  count
# 0   0.410802     13
# 1   0.374669    173
# 2        NaN      1
# 3   0.405889     98
# 4   0.243050     10
# write json file 2016-04-02
#
# Pre-processing 2016-04-03
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     AG   0.029497        0.266667    0.087880  0.075242       0.593617
# 1     BE   0.016166        0.182353    0.121654  0.110242       0.667713
# 2     BS  -0.013693        0.207207    0.086751  0.070200       0.675777
# 3     FR  -0.002057        0.185185    0.096204  0.226391       0.786278
# 4     GE   0.021816        0.179671    0.152202  0.099876       0.720823
#
#    vader_std  count
# 0   0.270341     15
# 1   0.351822    170
# 2   0.369252    111
# 3   0.360778     27
# 4   0.390350    974
# write json file 2016-04-03
#
# Pre-processing 2016-04-04
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     AG   0.018269        0.153846    0.132146  0.064269       0.554700
# 1     BE   0.010252        0.153846    0.137911  0.099023       0.670557
# 2     BL  -0.066665       -0.333333   -0.329267  0.115468       0.577350
# 3     BS   0.001847        0.027027    0.081220  0.141301       0.719336
# 4     FR  -0.020306        0.052632    0.035711  0.099993       0.705036
#
#    vader_std  count
# 0   0.368570     13
# 1   0.352683    208
# 2   0.299627      3
# 3   0.338236    111
# 4   0.394967     19
# write json file 2016-04-04
#
# Pre-processing 2016-04-05
#
#   canton  main_mean  sentiment_mean  vader_mean  main_std  sentiment_std  \
# 0     AG   0.000570        0.222222    0.128152  0.070195       0.697982
# 1     BE   0.012141        0.056769    0.081271  0.097643       0.593318
# 2     BL   0.000000        0.000000    0.000000       NaN            NaN
# 3     BS   0.013438        0.144828    0.130407  0.097424       0.676791
# 4     FR  -0.010873       -0.074074   -0.022007  0.116206       0.549540
#
#    vader_std  count
# 0   0.427562     27
# 1   0.343299    229
# 2        NaN      1
# 3   0.399411    145
# 4   0.327106     27
# write json file 2016-04-05

# %%
#statistical significance

import scipy.stats as stats

# day 
data_day1 = data_day[data_day.day == '2016-04-01']
print(data_day1)
data_day2 = data_day[data_day.day == '2016-04-02']
print(data_day2)
data_day3 = data_day[data_day.day == '2016-04-03']
print(data_day3)
data_day4 = data_day[data_day.day == '2016-04-04']
print(data_day4)
data_day5 = data_day[data_day.day == '2016-04-05']
print(data_day5)

stats.friedmanchisquare(data_day1,data_day2,data_day3,data_day4,data_day5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-a2b396cf5c48> in <module>()
#       4
#       5 # day
# ----> 6 data_day1 = data_day[data_day.day == '2016-04-01']
#       7 print(data_day1)
#       8 data_day2 = data_day[data_day.day == '2016-04-02']
#
# /Users/asmaetounsi/anaconda3/lib/python3.5/site-packages/pandas/core/base.py in __getitem__(self, key)
#     341         else:
#     342             if key not in self.obj:
# --> 343                 raise KeyError("Column not found: %s" % key)
#     344             return self._gotitem(key, ndim=1)
#     345
#
# KeyError: 'Column not found: False'

# %%
# canton
