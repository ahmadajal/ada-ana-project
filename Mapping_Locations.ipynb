# %% [markdown]
# # Mapping locations

# %%
# Basic imports
import pandas as pd
import numpy as np
import requests
import json
import pycountry 
# Reading the file
file_name = "../data/locations.txt"
with open(file_name,encoding="utf8") as f:
    locations = f.readlines()
locations = pd.Series([x.strip() for x in locations])
print('number of unique locations : ',len(locations))
# Out:
# number of unique locations :  21815

# %%
# Read the already mapped locations
location_to_canton = pd.read_csv('../data/location_to_canton.csv')
del location_to_canton['Unnamed: 0']
location_to_canton.head()
# Out:
#    ID                        Location
# 0  ZH         CH 8545 Rickenbach Sulz
# 1  ZH                  Ruschlikon, CH
# 2  ZH  CH-8700- Kusnacht, Switzerland
# 3  ZH      hombrechtikon, switzerland
# 4  ZH      Basel, Brugg/Windisch (CH)

# %%
# Remove the already mapped locations from the data
idx_loc = [not any(location_to_canton['Location'].isin([loc])) for loc in locations]
locations = locations[idx_loc]
print('number of remaining locations : ',len(locations))
# Out:
# number of remaining locations :  21605

# %%
countries = {}

for country in pycountry.countries:
    if country.name!='Switzerland':
        countries[country.name] = [country.name.lower(), country.alpha_2]
    
countries
# Out:
# {'Afghanistan': ['afghanistan', 'AF'],
#  'Albania': ['albania', 'AL'],
#  'Algeria': ['algeria', 'DZ'],
#  'American Samoa': ['american samoa', 'AS'],
#  'Andorra': ['andorra', 'AD'],
#  'Angola': ['angola', 'AO'],
#  'Anguilla': ['anguilla', 'AI'],
#  'Antarctica': ['antarctica', 'AQ'],
#  'Antigua and Barbuda': ['antigua and barbuda', 'AG'],
#  'Argentina': ['argentina', 'AR'],
#  'Armenia': ['armenia', 'AM'],
#  'Aruba': ['aruba', 'AW'],
#  'Australia': ['australia', 'AU'],
#  'Austria': ['austria', 'AT'],
#  'Azerbaijan': ['azerbaijan', 'AZ'],
#  'Bahamas': ['bahamas', 'BS'],
#  'Bahrain': ['bahrain', 'BH'],
#  'Bangladesh': ['bangladesh', 'BD'],
#  'Barbados': ['barbados', 'BB'],
#  'Belarus': ['belarus', 'BY'],
#  'Belgium': ['belgium', 'BE'],
#  'Belize': ['belize', 'BZ'],
#  'Benin': ['benin', 'BJ'],
#  'Bermuda': ['bermuda', 'BM'],
#  'Bhutan': ['bhutan', 'BT'],
#  'Bolivia, Plurinational State of': ['bolivia, plurinational state of', 'BO'],
#  'Bonaire, Sint Eustatius and Saba': ['bonaire, sint eustatius and saba',
#   'BQ'],
#  'Bosnia and Herzegovina': ['bosnia and herzegovina', 'BA'],
#  'Botswana': ['botswana', 'BW'],
#  'Bouvet Island': ['bouvet island', 'BV'],
#  'Brazil': ['brazil', 'BR'],
#  'British Indian Ocean Territory': ['british indian ocean territory', 'IO'],
#  'Brunei Darussalam': ['brunei darussalam', 'BN'],
#  'Bulgaria': ['bulgaria', 'BG'],
#  'Burkina Faso': ['burkina faso', 'BF'],
#  'Burundi': ['burundi', 'BI'],
#  'Cabo Verde': ['cabo verde', 'CV'],
#  'Cambodia': ['cambodia', 'KH'],
#  'Cameroon': ['cameroon', 'CM'],
#  'Canada': ['canada', 'CA'],
#  'Cayman Islands': ['cayman islands', 'KY'],
#  'Central African Republic': ['central african republic', 'CF'],
#  'Chad': ['chad', 'TD'],
#  'Chile': ['chile', 'CL'],
#  'China': ['china', 'CN'],
#  'Christmas Island': ['christmas island', 'CX'],
#  'Cocos (Keeling) Islands': ['cocos (keeling) islands', 'CC'],
#  'Colombia': ['colombia', 'CO'],
#  'Comoros': ['comoros', 'KM'],
#  'Congo': ['congo', 'CG'],
#  'Congo, The Democratic Republic of the': ['congo, the democratic republic of the',
#   'CD'],
#  'Cook Islands': ['cook islands', 'CK'],
#  'Costa Rica': ['costa rica', 'CR'],
#  'Croatia': ['croatia', 'HR'],
#  'Cuba': ['cuba', 'CU'],
#  'Curaçao': ['curaçao', 'CW'],
#  'Cyprus': ['cyprus', 'CY'],
#  'Czechia': ['czechia', 'CZ'],
#  "Côte d'Ivoire": ["côte d'ivoire", 'CI'],
#  'Denmark': ['denmark', 'DK'],
#  'Djibouti': ['djibouti', 'DJ'],
#  'Dominica': ['dominica', 'DM'],
#  'Dominican Republic': ['dominican republic', 'DO'],
#  'Ecuador': ['ecuador', 'EC'],
#  'Egypt': ['egypt', 'EG'],
#  'El Salvador': ['el salvador', 'SV'],
#  'Equatorial Guinea': ['equatorial guinea', 'GQ'],
#  'Eritrea': ['eritrea', 'ER'],
#  'Estonia': ['estonia', 'EE'],
#  'Ethiopia': ['ethiopia', 'ET'],
#  'Falkland Islands (Malvinas)': ['falkland islands (malvinas)', 'FK'],
#  'Faroe Islands': ['faroe islands', 'FO'],
#  'Fiji': ['fiji', 'FJ'],
#  'Finland': ['finland', 'FI'],
#  'France': ['france', 'FR'],
#  'French Guiana': ['french guiana', 'GF'],
#  'French Polynesia': ['french polynesia', 'PF'],
#  'French Southern Territories': ['french southern territories', 'TF'],
#  'Gabon': ['gabon', 'GA'],
#  'Gambia': ['gambia', 'GM'],
#  'Georgia': ['georgia', 'GE'],
#  'Germany': ['germany', 'DE'],
#  'Ghana': ['ghana', 'GH'],
#  'Gibraltar': ['gibraltar', 'GI'],
#  'Greece': ['greece', 'GR'],
#  'Greenland': ['greenland', 'GL'],
#  'Grenada': ['grenada', 'GD'],
#  'Guadeloupe': ['guadeloupe', 'GP'],
#  'Guam': ['guam', 'GU'],
#  'Guatemala': ['guatemala', 'GT'],
#  'Guernsey': ['guernsey', 'GG'],
#  'Guinea': ['guinea', 'GN'],
#  'Guinea-Bissau': ['guinea-bissau', 'GW'],
#  'Guyana': ['guyana', 'GY'],
#  'Haiti': ['haiti', 'HT'],
#  'Heard Island and McDonald Islands': ['heard island and mcdonald islands',
#   'HM'],
#  'Holy See (Vatican City State)': ['holy see (vatican city state)', 'VA'],
#  'Honduras': ['honduras', 'HN'],
#  'Hong Kong': ['hong kong', 'HK'],
#  'Hungary': ['hungary', 'HU'],
#  'Iceland': ['iceland', 'IS'],
#  'India': ['india', 'IN'],
#  'Indonesia': ['indonesia', 'ID'],
#  'Iran, Islamic Republic of': ['iran, islamic republic of', 'IR'],
#  'Iraq': ['iraq', 'IQ'],
#  'Ireland': ['ireland', 'IE'],
#  'Isle of Man': ['isle of man', 'IM'],
#  'Israel': ['israel', 'IL'],
#  'Italy': ['italy', 'IT'],
#  'Jamaica': ['jamaica', 'JM'],
#  'Japan': ['japan', 'JP'],
#  'Jersey': ['jersey', 'JE'],
#  'Jordan': ['jordan', 'JO'],
#  'Kazakhstan': ['kazakhstan', 'KZ'],
#  'Kenya': ['kenya', 'KE'],
#  'Kiribati': ['kiribati', 'KI'],
#  "Korea, Democratic People's Republic of": ["korea, democratic people's republic of",
#   'KP'],
#  'Korea, Republic of': ['korea, republic of', 'KR'],
#  'Kuwait': ['kuwait', 'KW'],
#  'Kyrgyzstan': ['kyrgyzstan', 'KG'],
#  "Lao People's Democratic Republic": ["lao people's democratic republic",
#   'LA'],
#  'Latvia': ['latvia', 'LV'],
#  'Lebanon': ['lebanon', 'LB'],
#  'Lesotho': ['lesotho', 'LS'],
#  'Liberia': ['liberia', 'LR'],
#  'Libya': ['libya', 'LY'],
#  'Liechtenstein': ['liechtenstein', 'LI'],
#  'Lithuania': ['lithuania', 'LT'],
#  'Luxembourg': ['luxembourg', 'LU'],
#  'Macao': ['macao', 'MO'],
#  'Macedonia, Republic of': ['macedonia, republic of', 'MK'],
#  'Madagascar': ['madagascar', 'MG'],
#  'Malawi': ['malawi', 'MW'],
#  'Malaysia': ['malaysia', 'MY'],
#  'Maldives': ['maldives', 'MV'],
#  'Mali': ['mali', 'ML'],
#  'Malta': ['malta', 'MT'],
#  'Marshall Islands': ['marshall islands', 'MH'],
#  'Martinique': ['martinique', 'MQ'],
#  'Mauritania': ['mauritania', 'MR'],
#  'Mauritius': ['mauritius', 'MU'],
#  'Mayotte': ['mayotte', 'YT'],
#  'Mexico': ['mexico', 'MX'],
#  'Micronesia, Federated States of': ['micronesia, federated states of', 'FM'],
#  'Moldova, Republic of': ['moldova, republic of', 'MD'],
#  'Monaco': ['monaco', 'MC'],
#  'Mongolia': ['mongolia', 'MN'],
#  'Montenegro': ['montenegro', 'ME'],
#  'Montserrat': ['montserrat', 'MS'],
#  'Morocco': ['morocco', 'MA'],
#  'Mozambique': ['mozambique', 'MZ'],
#  'Myanmar': ['myanmar', 'MM'],
#  'Namibia': ['namibia', 'NA'],
#  'Nauru': ['nauru', 'NR'],
#  'Nepal': ['nepal', 'NP'],
#  'Netherlands': ['netherlands', 'NL'],
#  'New Caledonia': ['new caledonia', 'NC'],
#  'New Zealand': ['new zealand', 'NZ'],
#  'Nicaragua': ['nicaragua', 'NI'],
#  'Niger': ['niger', 'NE'],
#  'Nigeria': ['nigeria', 'NG'],
#  'Niue': ['niue', 'NU'],
#  'Norfolk Island': ['norfolk island', 'NF'],
#  'Northern Mariana Islands': ['northern mariana islands', 'MP'],
#  'Norway': ['norway', 'NO'],
#  'Oman': ['oman', 'OM'],
#  'Pakistan': ['pakistan', 'PK'],
#  'Palau': ['palau', 'PW'],
#  'Palestine, State of': ['palestine, state of', 'PS'],
#  'Panama': ['panama', 'PA'],
#  'Papua New Guinea': ['papua new guinea', 'PG'],
#  'Paraguay': ['paraguay', 'PY'],
#  'Peru': ['peru', 'PE'],
#  'Philippines': ['philippines', 'PH'],
#  'Pitcairn': ['pitcairn', 'PN'],
#  'Poland': ['poland', 'PL'],
#  'Portugal': ['portugal', 'PT'],
#  'Puerto Rico': ['puerto rico', 'PR'],
#  'Qatar': ['qatar', 'QA'],
#  'Romania': ['romania', 'RO'],
#  'Russian Federation': ['russian federation', 'RU'],
#  'Rwanda': ['rwanda', 'RW'],
#  'Réunion': ['réunion', 'RE'],
#  'Saint Barthélemy': ['saint barthélemy', 'BL'],
#  'Saint Helena, Ascension and Tristan da Cunha': ['saint helena, ascension and tristan da cunha',
#   'SH'],
#  'Saint Kitts and Nevis': ['saint kitts and nevis', 'KN'],
#  'Saint Lucia': ['saint lucia', 'LC'],
#  'Saint Martin (French part)': ['saint martin (french part)', 'MF'],
#  'Saint Pierre and Miquelon': ['saint pierre and miquelon', 'PM'],
#  'Saint Vincent and the Grenadines': ['saint vincent and the grenadines',
#   'VC'],
#  'Samoa': ['samoa', 'WS'],
#  'San Marino': ['san marino', 'SM'],
#  'Sao Tome and Principe': ['sao tome and principe', 'ST'],
#  'Saudi Arabia': ['saudi arabia', 'SA'],
#  'Senegal': ['senegal', 'SN'],
#  'Serbia': ['serbia', 'RS'],
#  'Seychelles': ['seychelles', 'SC'],
#  'Sierra Leone': ['sierra leone', 'SL'],
#  'Singapore': ['singapore', 'SG'],
#  'Sint Maarten (Dutch part)': ['sint maarten (dutch part)', 'SX'],
#  'Slovakia': ['slovakia', 'SK'],
#  'Slovenia': ['slovenia', 'SI'],
#  'Solomon Islands': ['solomon islands', 'SB'],
#  'Somalia': ['somalia', 'SO'],
#  'South Africa': ['south africa', 'ZA'],
#  'South Georgia and the South Sandwich Islands': ['south georgia and the south sandwich islands',
#   'GS'],
#  'South Sudan': ['south sudan', 'SS'],
#  'Spain': ['spain', 'ES'],
#  'Sri Lanka': ['sri lanka', 'LK'],
#  'Sudan': ['sudan', 'SD'],
#  'Suriname': ['suriname', 'SR'],
#  'Svalbard and Jan Mayen': ['svalbard and jan mayen', 'SJ'],
#  'Swaziland': ['swaziland', 'SZ'],
#  'Sweden': ['sweden', 'SE'],
#  'Syrian Arab Republic': ['syrian arab republic', 'SY'],
#  'Taiwan, Province of China': ['taiwan, province of china', 'TW'],
#  'Tajikistan': ['tajikistan', 'TJ'],
#  'Tanzania, United Republic of': ['tanzania, united republic of', 'TZ'],
#  'Thailand': ['thailand', 'TH'],
#  'Timor-Leste': ['timor-leste', 'TL'],
#  'Togo': ['togo', 'TG'],
#  'Tokelau': ['tokelau', 'TK'],
#  'Tonga': ['tonga', 'TO'],
#  'Trinidad and Tobago': ['trinidad and tobago', 'TT'],
#  'Tunisia': ['tunisia', 'TN'],
#  'Turkey': ['turkey', 'TR'],
#  'Turkmenistan': ['turkmenistan', 'TM'],
#  'Turks and Caicos Islands': ['turks and caicos islands', 'TC'],
#  'Tuvalu': ['tuvalu', 'TV'],
#  'Uganda': ['uganda', 'UG'],
#  'Ukraine': ['ukraine', 'UA'],
#  'United Arab Emirates': ['united arab emirates', 'AE'],
#  'United Kingdom': ['united kingdom', 'GB'],
#  'United States': ['united states', 'US'],
#  'United States Minor Outlying Islands': ['united states minor outlying islands',
#   'UM'],
#  'Uruguay': ['uruguay', 'UY'],
#  'Uzbekistan': ['uzbekistan', 'UZ'],
#  'Vanuatu': ['vanuatu', 'VU'],
#  'Venezuela, Bolivarian Republic of': ['venezuela, bolivarian republic of',
#   'VE'],
#  'Viet Nam': ['viet nam', 'VN'],
#  'Virgin Islands, British': ['virgin islands, british', 'VG'],
#  'Virgin Islands, U.S.': ['virgin islands, u.s.', 'VI'],
#  'Wallis and Futuna': ['wallis and futuna', 'WF'],
#  'Western Sahara': ['western sahara', 'EH'],
#  'Yemen': ['yemen', 'YE'],
#  'Zambia': ['zambia', 'ZM'],
#  'Zimbabwe': ['zimbabwe', 'ZW'],
#  'Åland Islands': ['åland islands', 'AX']}

# %%
# other countries locations 
idx_out_sw = [any(countries[ct][0] in loc.lower() for ct in countries) for loc in locations]
# drop other countries locations
locations1 = locations[[not(idx) for idx in idx_out_sw]]
print(len(locations1))
# Out:
# 18933

# %%
# other countries ID's locations 
idx_out_sw = [any(countries[ct][1] in loc for ct in countries) for loc in locations1]
# drop other countries locations
locations1 = locations1[[not(idx) for idx in idx_out_sw]]
print(len(locations1))
# Out:
# 16689

# %%
import unicodedata as ud

latin_letters= {}

def is_latin(uchr):
    try: return latin_letters[uchr]
    except KeyError:
         return latin_letters.setdefault(uchr, 'LATIN' in ud.name(uchr))

def only_roman_chars(unistr):
    return all(is_latin(uchr)
           for uchr in unistr
           if uchr.isalpha())

# drop non latin 

idx_non_latin = [only_roman_chars(loc) for loc in locations1]
locations2 = locations1[idx_non_latin]
len(locations2)
# Out:
# 16102

# %%
# take swiss cantons locations
ch_sub = pycountry.subdivisions.get(country_code='CH')
cantons = {}

for canton in ch_sub:
    cantons[canton.code.split('-')[1]] = [canton.code.split('-')[1],canton.name.lower()]
    
cantons
# Out:
# {'AG': ['AG', 'aargau'],
#  'AI': ['AI', 'appenzell innerrhoden'],
#  'AR': ['AR', 'appenzell ausserrhoden'],
#  'BE': ['BE', 'bern'],
#  'BL': ['BL', 'basel-landschaft'],
#  'BS': ['BS', 'basel-stadt'],
#  'FR': ['FR', 'fribourg'],
#  'GE': ['GE', 'genève'],
#  'GL': ['GL', 'glarus'],
#  'GR': ['GR', 'graubünden'],
#  'JU': ['JU', 'jura'],
#  'LU': ['LU', 'luzern'],
#  'NE': ['NE', 'neuchâtel'],
#  'NW': ['NW', 'nidwalden'],
#  'OW': ['OW', 'obwalden'],
#  'SG': ['SG', 'sankt gallen'],
#  'SH': ['SH', 'schaffhausen'],
#  'SO': ['SO', 'solothurn'],
#  'SZ': ['SZ', 'schwyz'],
#  'TG': ['TG', 'thurgau'],
#  'TI': ['TI', 'ticino'],
#  'UR': ['UR', 'uri'],
#  'VD': ['VD', 'vaud'],
#  'VS': ['VS', 'valais'],
#  'ZG': ['ZG', 'zug'],
#  'ZH': ['ZH', 'zürich']}

# %%
# locations containing the canton information
idx_with_ct = [any([cantons[ct][1] in loc.lower() for ct in cantons]) for loc in locations2]
loc_with_canton = locations2[idx_with_ct]
len(loc_with_canton)
# Out:
# 2299

# %%
# remaining locations
locations3 = locations2[[not(idx) for idx in idx_with_ct]]
len(locations3)
# Out:
# 13803

# %%
# adding locations containing canton ID's
idx_with_ct = [any([cantons[ct][0] in loc for ct in cantons]) for loc in locations3]
loc_with_canton = loc_with_canton.append(locations3[idx_with_ct])
len(loc_with_canton)
# Out:
# 2553

# %%
# remaining locations
locations3 = locations3[[not(idx) for idx in idx_with_ct]]
len(locations3)
# Out:
# 13549

# %%
locations3
# Out:
# 0                                  nan
# 1                             Chiemgau
# 3                     #standrewsestate
# 4         iPhone: 42.198639,-71.278198
# 5                          Guadalajara
# 7                            Bucuresti
# 8                      From Everywhere
# 9                   Unterseen, Schweiz
# 10           Ü T: 31.319998,-85.861966
# 13               Chavannes-près-Renens
# 17       Holmfirth, West Yorkshire, UK
# 19                           Morgane ♡
# 20                  Powhatan, Virginia
# 22                   swiss cheese land
# 24        Usually at 38,000ft / London
# 25                            Bebo's ❤
# 27                  Gland, Switzerland
# 28                              Coruña
# 31                  Muntelier, Schweiz
# 32              Hertfordshire, England
# 34              Rouen, Haute-Normandie
# 35                      rue du paradis
# 37                               Breda
# 38             Most of the time on set
# 39                      Jengkalifornia
# 42           Mont-sur-Lausanne, Suisse
# 43                      London & Paris
# 44              Halaskargazi, İstanbul
# 46                 Southern California
# 47              ♫All the World a stage
#                      ...
# 21757             38.899458,-77.116119
# 21760              Matang Glumpang Dua
# 21761             Dättwil, Switzerland
# 21762              Coslada, Madrid. NY
# 21763                      southampton
# 21766                       Winterfell
# 21769                          chiasso
# 21772                         Damascus
# 21774           North Rhine-Westphalia
# 21776                Mannheim / Zabrze
# 21777                   Ubrique, Cádiz
# 21779       Biel / Bienne, Switzerland
# 21780                            Cazis
# 21782              Switzerland, Hawaii
# 21783                        dübendorf
# 21784             Zurzach, Switzerland
# 21785                           Bangor
# 21789               Geneve / Annemasse
# 21790                           Lisbon
# 21792                 Glasgow Scotland
# 21793         Instagram: rachelkenyonn
# 21797                  Oxford, England
# 21799                     Luton/London
# 21800                      To the top!
# 21802                      Asia-Europe
# 21804                         poitiers
# 21806            Gruyères, Switzerland
# 21807            Tonbridge, South East
# 21810                    Brooklyn, NYC
# 21814            Avenches, Switzerland
# dtype: object

# %%
# take only switzerland locations
ch_names = ['switzerland','suisse','schweiz']
idx_in_ch = [(any([s in loc for s in ch_names]) or 'CH' in loc) for loc in locations3]
loc_in_ch = locations3[idx_in_ch]
print(len(loc_in_ch))
# Out:
# 247

# %%
# remone unsignificant (only refering to switzerland)
ch_names = ['switzerland','switzerland.','suisse.','suisse','schweiz','schweiz.','CH','CHE','CH.','CHE.']
idx_eq_ch = [any([s.lower() == loc.lower() for s in ch_names]) for loc in loc_in_ch]
loc_in_ch = loc_in_ch[[not(idx) for idx in idx_eq_ch]]
print(len(loc_in_ch))
# Out:
# 241

# %%
# more cleaning
vis_unclean = ['paris','lille',]
idx_unclean = [any([s in loc.lower() for s in vis_unclean]) for loc in loc_in_ch]

loc_in_ch = loc_in_ch[[not(idx) for idx in idx_unclean]]
print(len(loc_in_ch))
# Out:
# 238

# %%
loc_in_ch = loc_in_ch.reset_index()
loc_in_ch
# Out:
#      index                               0
# 0      378         los angeles/switzerland
# 1      577     im schönen freiamt, schweiz
# 2     1217           la suisse de la merde
# 3     2379       switzerland, planet earth
# 4     2541                         PCHS'17
# 5     2567    Rapperswil-Jona / Basel, CHE
# 6     2731       Sommewhere in switzerland
# 7     2886  CH, Earth, Milky Way, Laniakea
# 8     4047                    R-34// 305CH
# 9     4528  St.Petersburg, FL Oberburg, CH
# 10    5006     www.lenews.ch - Bassins, CH
# 11    5828             #3052 (switzerland)
# 12    5840              Cloud Hopping , CH
# 13    5953                    CH, Bodensee
# 14    6046             switzerland/toronto
# 15    6742        switzerland; planet jeds
# 16    7487                         The CHI
# 17    7548                        LONDWICH
# 18    7611                       Basel, CH
# 19    7633            zuerich, switzerland
# 20    7646                        Biel, CH
# 21    7658          Zentralschweiz / Basel
# 22    7681               vevey,switzerland
# 23    7682     Manchester, UK / Geneva, CH
# 24    7819              * Anime World * CH
# 25    7830                    Montreux, CH
# 26    7836                    lausanne, CH
# 27    7950                     lausanne,CH
# 28    8219                         CH-6170
# 29    8232                    Opfikon (CH)
# ..     ...                             ...
# 208  19416                  spiez, schweiz
# 209  19445          plaffeien, switzerland
# 210  19534                   sierre suisse
# 211  19556                        Stgo, CH
# 212  19563         Muratum Friburgensis/CH
# 213  19629  Yellow brick road, today in CH
# 214  19656            Paradiso, Lugano, CH
# 215  19675       suisse, La chaux-de-fonds
# 216  19706             geneva, switzerland
# 217  19811             Plan-les-Ouates, CH
# 218  19844                   suisse,geneve
# 219  20025          oberwil-lieli, schweiz
# 220  20041         winterthur, switzerland
# 221  20175                sargans, schweiz
# 222  20238        47.50142 N 7.71020 E, CH
# 223  20310             zermatt switzerland
# 224  20332                    Wetzikon, CH
# 225  20717                       Davos, CH
# 226  20746                     Lugano (CH)
# 227  20763                   Lausanne (CH)
# 228  21009    Stahlrain 13, 5200 Brugg, CH
# 229  21052                  Volketswil, CH
# 230  21066                     Geneva - CH
# 231  21202     Ginebra, Suiza - Geneva, CH
# 232  21208                        Nyon, CH
# 233  21218    rapperswil-jona, switzerland
# 234  21329                    Wollerau, CH
# 235  21499           Yverdon-les-Bains, CH
# 236  21501                Saint Gallen, CH
# 237  21699               Oberentfelden, CH
#
# [238 rows x 2 columns]

# %%
del loc_in_ch['index']

# %%
loc_in_ch[0:3]
# Out:
#                              0
# 0      los angeles/switzerland
# 1  im schönen freiamt, schweiz
# 2        la suisse de la merde

# %%
loc_in_ch1 = loc_in_ch[0:109]
loc_in_ch2 = loc_in_ch[109:218]
loc_in_ch3 = loc_in_ch[218:]

# %%
# mapping location -> canton using google api
# function taking the name of the place and returning the long address of it
def getAddress(name,gkey):
  glink="https://maps.googleapis.com/maps/api/place/textsearch/json?query={}&key={}".format(name + " Switzerland", gkey)
  r = requests.get(glink)
  dic = json.loads(r.text)
  try:
    return dic['results'][0]['formatted_address']
  except:
    return ''

geocodeLink = "https://maps.googleapis.com/maps/api/geocode/json?sensor=true"
from time import sleep

# Get the resulting Json file from the request, and put it in a json dictionary
def getGeocodeJsonDictionary(name,gkey):
    link =  u"{}&address=[{}]".format(geocodeLink, name, gkey)
    sleep(0.2) # a workaround for the rate-limit of Google geocode API
    r = requests.get(link)
    dic = json.loads(r.text)
    return dic

# Get the canton from the administrative_area_level_1 field in the dictionary
def getCantonFromGeocodeDictionary(dic):
    canton = ''
    if dic['results']:
        a = dic['results'][0]['address_components']
        for x in a:
            if x['types'][0]=='administrative_area_level_1':
                canton = x['short_name']    
    return canton

# Get the canton by composing the two previous functions
def getCanton(name):
    return getCantonFromGeocodeDictionary(getGeocodeJsonDictionary(name,gkey))

# %%
#part 1
addresses1 = [[a, getAddress(a,gkey)] for a in loc_in_ch1[0]]
addresses1
# Out:
# [['los angeles/switzerland',
#   '5721 W Imperial Hwy, Los Angeles, CA 90045, United States'],
#  ['im schönen freiamt, schweiz', ''],
#  ['la suisse de la merde', ''],
#  ['switzerland, planet earth', ''],
#  ["PCHS'17", ''],
#  ['Rapperswil-Jona / Basel, CHE', ''],
#  ['Sommewhere in switzerland', ''],
#  ['CH, Earth, Milky Way, Laniakea', ''],
#  ['R-34// 305CH', ''],
#  ['St.Petersburg, FL Oberburg, CH', ''],
#  ['www.lenews.ch - Bassins, CH', ''],
#  ['#3052 (switzerland)', ''],
#  ['Cloud Hopping , CH', ''],
#  ['CH, Bodensee', 'Lake Constance'],
#  ['switzerland/toronto', '3230 Yonge St, Toronto, ON M4N 3P6, Canada'],
#  ['switzerland; planet jeds', ''],
#  ['The CHI', 'Chi, 3982, Switzerland'],
#  ['LONDWICH', ''],
#  ['Basel, CH', 'Basel, Switzerland'],
#  ['zuerich, switzerland', 'Zürich, Switzerland'],
#  ['Biel, CH', 'Biel/Bienne, Switzerland'],
#  ['Zentralschweiz / Basel', 'Alpenstrasse 1, 6002 Luzern, Switzerland'],
#  ['vevey,switzerland', 'Vevey, Switzerland'],
#  ['Manchester, UK / Geneva, CH',
#   "Route de l'Aéroport 21, 1215 Le Grand-Saconnex, Switzerland"],
#  ['* Anime World * CH', ''],
#  ['Montreux, CH', 'Montreux, Switzerland'],
#  ['lausanne, CH', 'Lausanne, Switzerland'],
#  ['lausanne,CH', 'Lausanne, Switzerland'],
#  ['CH-6170', '6170 Schüpfheim, Switzerland'],
#  ['Opfikon (CH)', 'Opfikon, Switzerland'],
#  ['Cholerweg 9, 5212 Hausen, CH', 'Cholerweg 9, 5212 Hausen, Switzerland'],
#  ['meilen, switzerland', 'Meilen, Switzerland'],
#  ['CH-8132 Egg', '8132 Hinteregg, Switzerland'],
#  ['CHI ~ NYC', '245 W 29th St # 6, New York, NY 10001, United States'],
#  ['sion, switzerland', 'Sion, Switzerland'],
#  ['switzerland, basel', 'Basel, Switzerland'],
#  ['interlaken,switzerland', 'Interlaken, Switzerland'],
#  ['Steffisburg, CH', 'Steffisburg, Switzerland'],
#  ['Chating CH', 'Chemin du Chat, 2025 Gorgier, Switzerland'],
#  ['Davos-Platz, CH', 'Davos, Switzerland'],
#  ['suisse/geneve', 'Geneva, Switzerland'],
#  ['basel, switzerland', 'Basel, Switzerland'],
#  ['switzerland, Geneva', 'Geneva, Switzerland'],
#  ['suisse, switzerland', 'Switzerland'],
#  ['Basel, switzerland', 'Basel, Switzerland'],
#  ['CH - 3439 Ranflueh, Ramisberg', 'Ramisberg, 3439 Lützelflüh, Switzerland'],
#  ['wikon, switzerland, earth', ''],
#  ['schweiz 0041768160697', ''],
#  ['CHHS', ''],
#  ['martigny - suisse', 'Martigny, Switzerland'],
#  ['St. Gallen (CH)', 'St Gallen, Switzerland'],
#  ['CH, Giornale del Popolo: Sport', ''],
#  ['davos, switzerland', 'Davos, Switzerland'],
#  ['thun switzerland', 'Thun, Switzerland'],
#  ['baden, schweiz', 'Baden, Switzerland'],
#  ['schweiz/zh - schalkermarkt', ''],
#  ['Renens, switzerland', 'Renens, Switzerland'],
#  ['Münsingen CH', 'Münsingen, Switzerland'],
#  ['zuerich switzerland', 'Zürich, Switzerland'],
#  ['Giubiasco (CH)', 'Giubiasco, Switzerland'],
#  ['switzerland/preshevë/prishtinë', ''],
#  ['interlaken, switzerland', 'Interlaken, Switzerland'],
#  ['Geneve, CH', 'Geneva, Switzerland'],
#  ['suisse,Rio de Janeiro, Brasil',
#   'R. Cândido Mendes, 157 - Glória, Rio de Janeiro - RJ, 20241-220, Brazil'],
#  ['saxon , suisse', '1907 Saxon, Switzerland'],
#  ['herisau, ostschweiz, schweiz', 'Herisau, Switzerland'],
#  ['Préverenges, suisse', 'Préverenges, Switzerland'],
#  ['courgevaux, CH', 'Courgevaux, Switzerland'],
#  ['verschiedene Standorte in CH', ''],
#  ['jona, switzerland', 'Rapperswil-Jona, Switzerland'],
#  ['London UK / Lausanne CH', 'Swiss Tavern, Lausanne Rd, London SE15 2HU, UK'],
#  ['CH-Wädenswil', 'Wädenswil, Switzerland'],
#  ['Wiiiiiiidnes, CH', ''],
#  ['Bellach CH', 'Bellach, Switzerland'],
#  ['Hombrechtikon , switzerland', 'Hombrechtikon, Switzerland'],
#  ['rapperswil, switzerland', 'Rapperswil-Jona, Switzerland'],
#  ['olten, switzerland', 'Olten, Switzerland'],
#  ['Lausanne,suisse', 'Lausanne, Switzerland'],
#  ['switzerland/worldwide/paddock', ''],
#  ['CH - Gnv', ''],
#  ['Greater Geneva Area, CH', 'Hôtel de ville 11, 1204 Genève, Switzerland'],
#  ['CH-St. Gallen', 'St Gallen, Switzerland'],
#  ['Morges, CH', 'Morges, Switzerland'],
#  ['lausanne, suisse', 'Lausanne, Switzerland'],
#  ['Cham, CH, Europe', 'Cham, Switzerland'],
#  ['Schweiz, switzerland', 'Switzerland'],
#  ['suisse, neuchatel', 'Neuchâtel, Switzerland'],
#  ['chur, switzerland (east part)', 'Chur, Switzerland'],
#  ['CHItown', ''],
#  ['CH-8730 Uznach Schweiz', '8730 Uznach, Switzerland'],
#  ['Basel, CHE', 'Münchensteinerstrasse 38, 4052 Basel, Switzerland'],
#  ['St Gallen, CH', 'St Gallen, Switzerland'],
#  ['Othmarsingen, CH', '5504 Othmarsingen, Switzerland'],
#  ['Hettlingen CH / SanJose Ca', ''],
#  ['Mettmenstetten (CH)', '8932 Mettmenstetten, Switzerland'],
#  ['Biel/Bienne, CH', 'Biel/Bienne, Switzerland'],
#  ['Chiasso, CH #Borderlinenx', ''],
#  ['Saint Moritz, CH', 'St Moritz, Switzerland'],
#  ['New York / Lugano, CH', 'Corso Elvezia 24, 6900 Lugano, Switzerland'],
#  ['Lausanne, suisse', 'Lausanne, Switzerland'],
#  ['Liebistorf CH', '3213 Liebistorf, Switzerland'],
#  ['Playas De Catazaja, CH', ''],
#  ['Pyke, Westeros (CH)', ''],
#  ['Vesturbær, Baden, CH', ''],
#  ['Tschuggen, Belalp-Blatten, CH',
#   'Tschuggen 102, 3914 Blatten-Belalp, Switzerland'],
#  ['suisse, Lausanne', ''],
#  ['Mollis, CH', 'Mollis, Switzerland'],
#  ['geneve - suisse', ''],
#  ['Canton of GenevaCH, Geneva', '']]

# %%
for a in addresses1:
    if a[1]=='':
        a[1]=a[0]
    else:
        if not(a[1].endswith('Switzerland')):
            a[1]=''

addresses1 = [a for a in addresses1 if a[1] != '']
len(addresses1)
# Out:
# 103

# %%
cantons1 = [[a[0], getCanton(a[1])] for a in addresses1]

# %%
cantons1
# Out:
# [['im schönen freiamt, schweiz', ''],
#  ['la suisse de la merde', ''],
#  ['switzerland, planet earth', ''],
#  ["PCHS'17", ''],
#  ['Rapperswil-Jona / Basel, CHE', ''],
#  ['Sommewhere in switzerland', ''],
#  ['CH, Earth, Milky Way, Laniakea', ''],
#  ['R-34// 305CH', 'NY'],
#  ['St.Petersburg, FL Oberburg, CH', ''],
#  ['www.lenews.ch - Bassins, CH', ''],
#  ['#3052 (switzerland)', ''],
#  ['Cloud Hopping , CH', ''],
#  ['switzerland; planet jeds', ''],
#  ['The CHI', 'VS'],
#  ['LONDWICH', ''],
#  ['Basel, CH', 'BS'],
#  ['zuerich, switzerland', 'ZH'],
#  ['Biel, CH', 'BE'],
#  ['Zentralschweiz / Basel', 'LU'],
#  ['vevey,switzerland', 'VD'],
#  ['Manchester, UK / Geneva, CH', 'GE'],
#  ['* Anime World * CH', ''],
#  ['Montreux, CH', 'VD'],
#  ['lausanne, CH', 'VD'],
#  ['lausanne,CH', 'VD'],
#  ['CH-6170', 'LU'],
#  ['Opfikon (CH)', 'ZH'],
#  ['Cholerweg 9, 5212 Hausen, CH', 'AG'],
#  ['meilen, switzerland', 'ZH'],
#  ['CH-8132 Egg', 'ZH'],
#  ['sion, switzerland', 'VS'],
#  ['switzerland, basel', 'BS'],
#  ['interlaken,switzerland', 'BE'],
#  ['Steffisburg, CH', 'BE'],
#  ['Chating CH', 'NE'],
#  ['Davos-Platz, CH', 'GR'],
#  ['suisse/geneve', 'GE'],
#  ['basel, switzerland', 'BS'],
#  ['switzerland, Geneva', 'GE'],
#  ['suisse, switzerland', ''],
#  ['Basel, switzerland', 'BS'],
#  ['CH - 3439 Ranflueh, Ramisberg', 'BE'],
#  ['wikon, switzerland, earth', ''],
#  ['schweiz 0041768160697', ''],
#  ['CHHS', 'TX'],
#  ['martigny - suisse', 'VS'],
#  ['St. Gallen (CH)', 'SG'],
#  ['CH, Giornale del Popolo: Sport', ''],
#  ['davos, switzerland', 'GR'],
#  ['thun switzerland', 'BE'],
#  ['baden, schweiz', 'AG'],
#  ['schweiz/zh - schalkermarkt', ''],
#  ['Renens, switzerland', 'VD'],
#  ['Münsingen CH', 'BE'],
#  ['zuerich switzerland', 'ZH'],
#  ['Giubiasco (CH)', 'TI'],
#  ['switzerland/preshevë/prishtinë', ''],
#  ['interlaken, switzerland', 'BE'],
#  ['Geneve, CH', 'GE'],
#  ['saxon , suisse', 'VS'],
#  ['herisau, ostschweiz, schweiz', 'AR'],
#  ['Préverenges, suisse', 'VD'],
#  ['courgevaux, CH', 'FR'],
#  ['verschiedene Standorte in CH', ''],
#  ['jona, switzerland', 'SG'],
#  ['CH-Wädenswil', 'ZH'],
#  ['Wiiiiiiidnes, CH', ''],
#  ['Bellach CH', 'SO'],
#  ['Hombrechtikon , switzerland', 'ZH'],
#  ['rapperswil, switzerland', 'SG'],
#  ['olten, switzerland', 'SO'],
#  ['Lausanne,suisse', 'VD'],
#  ['switzerland/worldwide/paddock', ''],
#  ['CH - Gnv', 'VD'],
#  ['Greater Geneva Area, CH', 'GE'],
#  ['CH-St. Gallen', 'SG'],
#  ['Morges, CH', 'VD'],
#  ['lausanne, suisse', 'VD'],
#  ['Cham, CH, Europe', 'ZG'],
#  ['Schweiz, switzerland', ''],
#  ['suisse, neuchatel', 'NE'],
#  ['chur, switzerland (east part)', 'GR'],
#  ['CHItown', 'IL'],
#  ['CH-8730 Uznach Schweiz', 'SG'],
#  ['Basel, CHE', 'BS'],
#  ['St Gallen, CH', 'SG'],
#  ['Othmarsingen, CH', 'AG'],
#  ['Hettlingen CH / SanJose Ca', ''],
#  ['Mettmenstetten (CH)', 'ZH'],
#  ['Biel/Bienne, CH', 'BE'],
#  ['Chiasso, CH #Borderlinenx', 'TI'],
#  ['Saint Moritz, CH', 'GR'],
#  ['New York / Lugano, CH', 'TI'],
#  ['Lausanne, suisse', 'VD'],
#  ['Liebistorf CH', 'FR'],
#  ['Playas De Catazaja, CH', 'Chis.'],
#  ['Pyke, Westeros (CH)', ''],
#  ['Vesturbær, Baden, CH', ''],
#  ['Tschuggen, Belalp-Blatten, CH', 'VS'],
#  ['suisse, Lausanne', 'VD'],
#  ['Mollis, CH', 'GL'],
#  ['geneve - suisse', 'GE'],
#  ['Canton of GenevaCH, Geneva', 'GE']]

# %%
loc_in_ch_left = loc_in_ch[0][[not (any([(loc in c[0]) for c in cantons1])) for loc in loc_in_ch[0]]]

# %%
len(loc_in_ch_left)
# Out:
# 132

# %%
df_cantons = pd.DataFrame(cantons1)
df_cantons
# Out:
#                                   0      1
# 0       im schönen freiamt, schweiz
# 1             la suisse de la merde
# 2         switzerland, planet earth
# 3                           PCHS'17
# 4      Rapperswil-Jona / Basel, CHE
# 5         Sommewhere in switzerland
# 6    CH, Earth, Milky Way, Laniakea
# 7                      R-34// 305CH     NY
# 8    St.Petersburg, FL Oberburg, CH
# 9       www.lenews.ch - Bassins, CH
# 10              #3052 (switzerland)
# 11               Cloud Hopping , CH
# 12         switzerland; planet jeds
# 13                          The CHI     VS
# 14                         LONDWICH
# 15                        Basel, CH     BS
# 16             zuerich, switzerland     ZH
# 17                         Biel, CH     BE
# 18           Zentralschweiz / Basel     LU
# 19                vevey,switzerland     VD
# 20      Manchester, UK / Geneva, CH     GE
# 21               * Anime World * CH
# 22                     Montreux, CH     VD
# 23                     lausanne, CH     VD
# 24                      lausanne,CH     VD
# 25                          CH-6170     LU
# 26                     Opfikon (CH)     ZH
# 27     Cholerweg 9, 5212 Hausen, CH     AG
# 28              meilen, switzerland     ZH
# 29                      CH-8132 Egg     ZH
# ..                              ...    ...
# 73                         CH - Gnv     VD
# 74          Greater Geneva Area, CH     GE
# 75                    CH-St. Gallen     SG
# 76                       Morges, CH     VD
# 77                 lausanne, suisse     VD
# 78                 Cham, CH, Europe     ZG
# 79             Schweiz, switzerland
# 80                suisse, neuchatel     NE
# 81    chur, switzerland (east part)     GR
# 82                          CHItown     IL
# 83           CH-8730 Uznach Schweiz     SG
# 84                       Basel, CHE     BS
# 85                    St Gallen, CH     SG
# 86                 Othmarsingen, CH     AG
# 87       Hettlingen CH / SanJose Ca
# 88              Mettmenstetten (CH)     ZH
# 89                  Biel/Bienne, CH     BE
# 90        Chiasso, CH #Borderlinenx     TI
# 91                 Saint Moritz, CH     GR
# 92            New York / Lugano, CH     TI
# 93                 Lausanne, suisse     VD
# 94                    Liebistorf CH     FR
# 95           Playas De Catazaja, CH  Chis.
# 96              Pyke, Westeros (CH)
# 97             Vesturbær, Baden, CH
# 98    Tschuggen, Belalp-Blatten, CH     VS
# 99                 suisse, Lausanne     VD
# 100                      Mollis, CH     GL
# 101                 geneve - suisse     GE
# 102      Canton of GenevaCH, Geneva     GE
#
# [103 rows x 2 columns]

# %%
df_cantons.columns = [['Location','ID']]
df_cantons
# Out:
#                            Location     ID
# 0       im schönen freiamt, schweiz
# 1             la suisse de la merde
# 2         switzerland, planet earth
# 3                           PCHS'17
# 4      Rapperswil-Jona / Basel, CHE
# 5         Sommewhere in switzerland
# 6    CH, Earth, Milky Way, Laniakea
# 7                      R-34// 305CH     NY
# 8    St.Petersburg, FL Oberburg, CH
# 9       www.lenews.ch - Bassins, CH
# 10              #3052 (switzerland)
# 11               Cloud Hopping , CH
# 12         switzerland; planet jeds
# 13                          The CHI     VS
# 14                         LONDWICH
# 15                        Basel, CH     BS
# 16             zuerich, switzerland     ZH
# 17                         Biel, CH     BE
# 18           Zentralschweiz / Basel     LU
# 19                vevey,switzerland     VD
# 20      Manchester, UK / Geneva, CH     GE
# 21               * Anime World * CH
# 22                     Montreux, CH     VD
# 23                     lausanne, CH     VD
# 24                      lausanne,CH     VD
# 25                          CH-6170     LU
# 26                     Opfikon (CH)     ZH
# 27     Cholerweg 9, 5212 Hausen, CH     AG
# 28              meilen, switzerland     ZH
# 29                      CH-8132 Egg     ZH
# ..                              ...    ...
# 73                         CH - Gnv     VD
# 74          Greater Geneva Area, CH     GE
# 75                    CH-St. Gallen     SG
# 76                       Morges, CH     VD
# 77                 lausanne, suisse     VD
# 78                 Cham, CH, Europe     ZG
# 79             Schweiz, switzerland
# 80                suisse, neuchatel     NE
# 81    chur, switzerland (east part)     GR
# 82                          CHItown     IL
# 83           CH-8730 Uznach Schweiz     SG
# 84                       Basel, CHE     BS
# 85                    St Gallen, CH     SG
# 86                 Othmarsingen, CH     AG
# 87       Hettlingen CH / SanJose Ca
# 88              Mettmenstetten (CH)     ZH
# 89                  Biel/Bienne, CH     BE
# 90        Chiasso, CH #Borderlinenx     TI
# 91                 Saint Moritz, CH     GR
# 92            New York / Lugano, CH     TI
# 93                 Lausanne, suisse     VD
# 94                    Liebistorf CH     FR
# 95           Playas De Catazaja, CH  Chis.
# 96              Pyke, Westeros (CH)
# 97             Vesturbær, Baden, CH
# 98    Tschuggen, Belalp-Blatten, CH     VS
# 99                 suisse, Lausanne     VD
# 100                      Mollis, CH     GL
# 101                 geneve - suisse     GE
# 102      Canton of GenevaCH, Geneva     GE
#
# [103 rows x 2 columns]

# %%
df_cantons = pd.concat([df_cantons,location_to_canton]).reset_index()
del df_cantons['index']
df_cantons
# Out:
#       ID                        Location
# 0            im schönen freiamt, schweiz
# 1                  la suisse de la merde
# 2              switzerland, planet earth
# 3                                PCHS'17
# 4           Rapperswil-Jona / Basel, CHE
# 5              Sommewhere in switzerland
# 6         CH, Earth, Milky Way, Laniakea
# 7     NY                    R-34// 305CH
# 8         St.Petersburg, FL Oberburg, CH
# 9            www.lenews.ch - Bassins, CH
# 10                   #3052 (switzerland)
# 11                    Cloud Hopping , CH
# 12              switzerland; planet jeds
# 13    VS                         The CHI
# 14                              LONDWICH
# 15    BS                       Basel, CH
# 16    ZH            zuerich, switzerland
# 17    BE                        Biel, CH
# 18    LU          Zentralschweiz / Basel
# 19    VD               vevey,switzerland
# 20    GE     Manchester, UK / Geneva, CH
# 21                    * Anime World * CH
# 22    VD                    Montreux, CH
# 23    VD                    lausanne, CH
# 24    VD                     lausanne,CH
# 25    LU                         CH-6170
# 26    ZH                    Opfikon (CH)
# 27    AG    Cholerweg 9, 5212 Hausen, CH
# 28    ZH             meilen, switzerland
# 29    ZH                     CH-8132 Egg
# ..   ...                             ...
# 285   VS                         Zermatt
# 286   VS                         Monthey
# 287   VS                            Brig
# 288   VS                         Conthey
# 289   NE  La Chaux-de-Fonds, switzerland
# 290   NE                       Neuchatel
# 291   NE                       Neuchâtel
# 292   NE                        Le Locle
# 293   GE              geneva,switzerland
# 294   GE                  Geneve, suisse
# 295   GE             Grand-Lancy, suisse
# 296   GE                   Geneve,suisse
# 297   GE                   genf, schweiz
# 298   GE             Geneva, switzerland
# 299   GE     1237 Avully, geneve, suisse
# 300   GE      United Nations, Geneva, CH
# 301   GE                         Ginevra
# 302   GE                            Genf
# 303   GE                          Geneve
# 304   GE                          Genève
# 305   GE                          Geneva
# 306   JU                delsberg schweiz
# 307   JU                        Delémont
# 308   JU                      Porrentruy
# 309  NaN                   p,switzerland
# 310  NaN                  Zentralschweiz
# 311  NaN             switzerland/isvicre
# 312  NaN                    @switzerland
# 313  NaN                Lake Zuerich, CH
# 314  NaN                        CH, D, A
#
# [315 rows x 2 columns]

# %%
df_canton_name = pd.read_csv('../data/canton_name.csv')
df_canton_name
# Out:
#     ID
# 0   ZH
# 1   BE
# 2   LU
# 3   UR
# 4   SZ
# 5   OW
# 6   NW
# 7   GL
# 8   ZG
# 9   FR
# 10  SO
# 11  BS
# 12  BL
# 13  SH
# 14  AR
# 15  AI
# 16  SG
# 17  GR
# 18  AG
# 19  TG
# 20  TI
# 21  VD
# 22  VS
# 23  NE
# 24  GE
# 25  JU

# %%
df = pd.merge(df_canton_name, df_cantons,on = ['ID'], how='outer') # merge the two datasets to have all the cantons

# %%
loc_with_canton
# Out:
# 11             Zurich, Dortmund, Barcelona
# 12                         luzern, schweiz
# 15                   Recherswil, Solothurn
# 16                                    Vaud
# 18                     Schaffhausen, Swiss
# 33                       (Saudi tourists )
# 36               Zurich, London, Paris, SF
# 40                   Zurich, Dinerolandia.
# 58          Basel - Bern - Zürich, Schweiz
# 66                             Péry, Berne
# 79                             Lake Zurich
# 91                          Bülach, Zürich
# 97                                 Berneck
# 107            Lucerne, Zurich or anywhere
# 130                        Verbier, Valais
# 146               Freiamt, Aargau, Schweiz
# 155                  Tenero-Contra, Ticino
# 164                              Bern 3000
# 194                     Sion, Valais-Suiça
# 209          Saint Gallen, Bern und Zürich
# 212             Zug, London, Dubai, Joburg
# 214            Suisse , Neuchâtel , Bevaix
# 238         Herzogenbuchsee, Bern, Schweiz
# 241                    Locarno, Ticino, CH
# 242                            Vaud, Suiza
# 246                     Bern (Switzerland)
# 247                             Belp, Bern
# 251                    Valais, Suisse #250
# 263                             Bern, Bern
# 269                       Zollikon, Zürich
#                        ...
# 19077                    19 Eye Street, NW
# 19079           Saint-Sulpice (VD), Suisse
# 19155                             Sion, VS
# 19275                              NW, Ga.
# 19361    Chemin du Closel 5, Renens VD, CH
# 19395                    Schweiz, Rikon ZH
# 19695               Orbe, VD, Switzerland.
# 19795                     NW,Washington DC
# 19829            Birmensdorf (ZH), Schweiz
# 19830                          UR, Izhevsk
# 19876            Pfäffikon ZH, Switzerland
# 19906       Suisse, Région lausannoise, VD
# 20045         1156 15th St., NW, Suite 600
# 20085                           NW, London
# 20087                Pfäffikon ZH, Schweiz
# 20102                                   NW
# 20108                               NW, UK
# 20398                                   JU
# 20476                   Baar (ZG), Schweiz
# 20485           Switzerland, Chexbres (VD)
# 20607                     Looking Hill, ZH
# 20701                          X Vagas, VS
# 20708       NW,Wales,Midlands,Yorks,Humber
# 20804            2700 Cathedral Avenue, NW
# 21029              Savièse/VS, Switzerland
# 21129                        ZH/St. Moritz
# 21238                          Küsnacht ZH
# 21619                Ecublens (VD), Suisse
# 21665                              TI, UTY
# 21677                Orkney/Klerksdorp, NW
# dtype: object

# %%
import unicodedata

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return u"".join([c for c in nfkd_form if not unicodedata.combining(c)])

# %%
import re


# take swiss cantons locations
ch_sub = pycountry.subdivisions.get(country_code='CH')
cantons_ = {}

for canton in ch_sub:
    cantons_[canton.code.split('-')[1]] = [canton.code.split('-')[1],remove_accents(canton.name.lower())]
    
def add_canton(loc):
    l_parts = re.sub(r'[^\w\s]','',remove_accents(loc.lower())).split()
    cant = ''
    for ct in cantons_:
        for l in l_parts:
            if (cantons_[ct][1] == l) or (cantons_[ct][0].lower() == l):
                cant = cantons_[ct][0]
    return cant

cantons_extra = [[loc, add_canton(loc)] for loc in loc_with_canton]

# %%
cantons_extra
# Out:
# [['Zurich, Dortmund, Barcelona', 'ZH'],
#  ['luzern, schweiz', 'LU'],
#  ['Recherswil, Solothurn', 'SO'],
#  ['Vaud', 'VD'],
#  ['Schaffhausen, Swiss', 'SH'],
#  ['(Saudi tourists )', ''],
#  ['Zurich, London, Paris, SF', 'ZH'],
#  ['Zurich, Dinerolandia.', 'ZH'],
#  ['Basel - Bern - Zürich, Schweiz', 'BE'],
#  ['Péry, Berne', ''],
#  ['Lake Zurich', 'ZH'],
#  ['Bülach, Zürich', 'ZH'],
#  ['Berneck', ''],
#  ['Lucerne, Zurich or anywhere', 'ZH'],
#  ['Verbier, Valais', 'VS'],
#  ['Freiamt, Aargau, Schweiz', 'AG'],
#  ['Tenero-Contra, Ticino', 'TI'],
#  ['Bern 3000', 'BE'],
#  ['Sion, Valais-Suiça', ''],
#  ['Saint Gallen, Bern und Zürich', 'BE'],
#  ['Zug, London, Dubai, Joburg', 'ZG'],
#  ['Suisse , Neuchâtel , Bevaix', 'NE'],
#  ['Herzogenbuchsee, Bern, Schweiz', 'BE'],
#  ['Locarno, Ticino, CH', 'TI'],
#  ['Vaud, Suiza', 'VD'],
#  ['Bern (Switzerland)', 'BE'],
#  ['Belp, Bern', 'BE'],
#  ['Valais, Suisse #250', 'VS'],
#  ['Bern, Bern', 'BE'],
#  ['Zollikon, Zürich', 'ZH'],
#  ['Ballwil, Luzern', 'LU'],
#  ['Bulle, Fribourg - Switzerland', 'FR'],
#  ['new bern', 'BE'],
#  ['Ticino, Switzerland', 'TI'],
#  ['Malans, Zürich, Alvaneu Dorf', 'ZH'],
#  ['Zurich, Buenos Aires', 'ZH'],
#  ['Bern/Fribourg, Switzerland', ''],
#  ['Canton de Neuchâtel, Suisse', 'NE'],
#  ['Luzern, CH.', 'LU'],
#  ['Entre Genève et le nord Isère', 'GE'],
#  ['Bernex, Switzerland', ''],
#  ['Rüschegg, Bern', 'BE'],
#  ['#Paris #Philadelphia #Zürich', 'ZH'],
#  ['Villigen, Aargau', 'AG'],
#  ['La Tour-de-Peilz, Vaud', 'VD'],
#  ['Switzerland Aargau', 'AG'],
#  ['Zurich, Munich, Dubai', 'ZH'],
#  ['es glauben oder nicht, zürich', 'ZH'],
#  ['Genève, Onex', 'GE'],
#  ['Zürich,Wien, Beograd, Novi Sad', ''],
#  ['Zurich, London, New York', 'ZH'],
#  ['Zurich, Berlin, Ohio', 'ZH'],
#  ['Zurich-ish, Switzerland', ''],
#  ['Muhen, Aargau', 'AG'],
#  ['Aarau, Aargau, Schweiz', 'AG'],
#  ['Zürich, Schaffhausen', 'SH'],
#  ['Luzern, fuerteventura', 'LU'],
#  ['Martigny - Valais - Suisse', 'VS'],
#  ['Lucerne / Luzern, Switzerland', 'LU'],
#  ['Vétroz, Valais, Suisse', 'VS'],
#  ['Grolley / Fribourg', 'FR'],
#  ['Stans, Nidwalden, Switzerland', 'NW'],
#  ['Aargau,Gränichen', ''],
#  ['Cadro, Ticino', 'TI'],
#  ['Oberdiessbach, Bern; Schweiz', 'BE'],
#  ['Bönigen; Bernese Oberland', ''],
#  ['bern,Switzerland', ''],
#  ['Swizerland, Neuchâtel', 'NE'],
#  ['Lons le Saunier, Jura', 'JU'],
#  ['Schaffhausen, Zürich, Schweiz', 'SH'],
#  ['Bevaix, Neuchâtel', 'NE'],
#  ['Geneva, Valais, Ticino', 'VS'],
#  ['Curitiba-Pr-Brasil', ''],
#  ['Zurich, Moscow & The World', 'ZH'],
#  ['Marly, Fribourg', 'FR'],
#  ['W̶e̶i̶m̶a̶r̶ ̶ Zürich', 'ZH'],
#  ['Schaffhausen, London, Anywhere', 'SH'],
#  ['Arau, Terengganurian', ''],
#  ['Curitiba', ''],
#  ['Switzerland, Vaud', 'VD'],
#  ['Thun, Bern CH', 'BE'],
#  ['near Zurich', 'ZH'],
#  ['Zürich & Basel', 'ZH'],
#  ['Anniviers, Valais', 'VS'],
#  ['neerach, zürich', 'ZH'],
#  ['Hasle bei Burgdorf, Bern', 'BE'],
#  ['Switzerland: Bern', 'BE'],
#  ['Neuchâtel,Suisse', ''],
#  ['Luzern, Switzerland .', 'LU'],
#  ['Genthod, Genève', 'GE'],
#  ['Villeneuve (VD), Vaud', 'VD'],
#  ['De Cartagena a Neuchâtel.', 'NE'],
#  ['Maggia, Ticino', 'TI'],
#  ['Zürich; Switzerland', 'ZH'],
#  ['Ticino, Cordoba', 'TI'],
#  ['Martigny, Valais, Suisse', 'VS'],
#  ['Glarus, Switzerland', 'GL'],
#  ['Zurich, Milano', 'ZH'],
#  ['Engelberg, Obwalden', 'OW'],
#  ['Zurich and London', 'ZH'],
#  ['Genève,Suisse/Roussô', ''],
#  ['Zug, London, Bonnie Scotland', 'ZG'],
#  ['Gera, Sonthofen, Zürich', 'ZH'],
#  ['Genève, Switzerland/Suisse', 'GE'],
#  ['Zurich, Switzerland.', 'ZH'],
#  ['Bellinzona, Ticino', 'TI'],
#  ['Crans-près-Céligny, Vaud', 'VD'],
#  ['Emmetten, Nidwalden', 'NW'],
#  ['zurich 8003', 'ZH'],
#  ['Wädenswil, Zürich', 'ZH'],
#  ['Suiza, Zurich, Winthertur', 'ZH'],
#  ['jura, paris, lyon, strasbourg', 'JU'],
#  ['San Diego • Zurich Switzerland', 'ZH'],
#  ['Giubiasco, Ticino', 'TI'],
#  ['Kriegstetten, Solothurn', 'SO'],
#  ['Svizzera zurigo', ''],
#  ['Silvaplana, Graubünden', 'GR'],
#  ['Berne', ''],
#  ['Möhlin, Aargau', 'AG'],
#  ['Hochschulstrasse 6, 3012 Bern', 'BE'],
#  ['Paris, Genève', 'GE'],
#  ['existential insecurity', ''],
#  ['Luzern/Cavigliano TI', 'TI'],
#  ['Zetzwil, Aargau', 'AG'],
#  ['New York, Paris and Zurich', 'ZH'],
#  ['Jura, Basel-Süd, Zürich-West', 'JU'],
#  ['genève, suisse', 'GE'],
#  ['Stäfa, Zürich, Brig', 'ZH'],
#  ['URI, Kingston, RI', 'UR'],
#  ['Genève, Suisse 19eme', 'GE'],
#  ['Bern, Fribourg, Lausanne', 'BE'],
#  ['Puidoux, Vaud', 'VD'],
#  ['Peseux, Neuchâtel, Switzerland', 'NE'],
#  ['Bern/ Switzerland', 'BE'],
#  ['Lausanne, Genève, Sion', 'GE'],
#  ['Zürich , Switzerland', 'ZH'],
#  ['Switzerland, Bern', 'BE'],
#  ['Oberweningen, Zürich', 'ZH'],
#  ['Zurich, Noosa Heads, London', 'ZH'],
#  ['Andermatt, Uri', 'UR'],
#  ['Switzerland, Region Zurich', 'ZH'],
#  ['Zug & Zürich, Switzerland', 'ZG'],
#  ['Morbio Inferiore, Ticino CH', 'TI'],
#  ['Beaune--&--Bern', ''],
#  ['Uttwil, Thurgau', 'TG'],
#  ['lake zurich', 'ZH'],
#  ['Neuchâtel suisse', 'NE'],
#  ['Zürich Höngg', 'ZH'],
#  ['Zurich, Zurich', 'ZH'],
#  ['Hünenberg, Zug', 'ZG'],
#  ['Wabern. Switzerland', ''],
#  ['Svizzera - Ticino', 'TI'],
#  ['Stadt Bern', 'BE'],
#  ['Josefstrasse 142, Zurich', 'ZH'],
#  ['Zürich, Bern/Burgdorf', 'ZH'],
#  ['Lufingen, Zürich', 'ZH'],
#  ['Bern/CH, Hermagor/A', ''],
#  ['Zürich, Baskenland', 'ZH'],
#  ['Näfels, Glarus', 'GL'],
#  ['Meyrin, Genève', 'GE'],
#  ['Zurigo, Ginevra', ''],
#  ['Raum Winterthur & Zürich, CH', 'ZH'],
#  ['Doppleschwand, Luzern', 'LU'],
#  ['Switzerland Zürich', 'ZH'],
#  ['Alpthal, Schwyz', 'SZ'],
#  ['Zürich, Basel', 'ZH'],
#  ['Bern-Länggasse, Schweiz', ''],
#  ['Chiasso - Ticino - Svizzera', 'TI'],
#  ['Aargau', 'AG'],
#  ['Jura, aveyron', 'JU'],
#  ['Dietlikon, Zürich', 'ZH'],
#  ['Genève - Sicilia', 'GE'],
#  ['Switherland, Zürich', 'ZH'],
#  ['St.Gallen, Zürich', 'ZH'],
#  ['Singen (Hohentwiel) / Zürich', 'ZH'],
#  ['Vancouver/Toronto/Genève', ''],
#  ['Kreuzlingen, Thurgau', 'TG'],
#  ['fribourg, switzerland', 'FR'],
#  ['Genève 1⃣7⃣', 'GE'],
#  ['Zürich, ZH', 'ZH'],
#  ['Genève (Geneva - Switzerland)', 'GE'],
#  ['Zurich, Down Town Switzerland', 'ZH'],
#  ['Zumikon/Zurich/Switzerland', ''],
#  ['Berne/Geneva', ''],
#  ['Zug, Switzerland', 'ZG'],
#  ['Zurich - Suiza', 'ZH'],
#  ['Genève, Paris, Nantes', 'GE'],
#  ['Bern, Sweet-zerland', 'BE'],
#  ['Préverenges, Vaud', 'VD'],
#  ['Zurich-Kloten - Pune - Davos', ''],
#  ['Genève , Thonex', 'GE'],
#  ['Switzerland, Zurich', 'ZH'],
#  ['Murgenthal, Aargau', 'AG'],
#  ['Zürich, Wien', 'ZH'],
#  ['Uri', 'UR'],
#  ['Kramgasse 8, Bern', 'BE'],
#  ['Suisse,Neuchâtel', ''],
#  ['3001 Bern', 'BE'],
#  ['Bern, Zürich, Basel', 'BE'],
#  ['3098 Koniz Berna Svizzera', ''],
#  ['Zürich, Zürich CH', 'ZH'],
#  ['Technopark Luzern, Switzerland', 'LU'],
#  ['Schweiz, Bern + Gontenschwil', 'BE'],
#  ['Bern-Bruennen', ''],
#  ['Cham/Zug, Switzerland', ''],
#  ['Eawag, Zurich, Switzerland', 'ZH'],
#  ['Luzern, Schweiz', 'LU'],
#  ['Olten, Solothurn, Switzerland', 'SO'],
#  ['Bern, CH', 'BE'],
#  ['Egg, Zürich', 'ZH'],
#  ['Rautistrasse 83, Zürich', 'ZH'],
#  ['Jura, Suisse', 'JU'],
#  ['Kerns, Obwalden', 'OW'],
#  ['Büron, Luzern', 'LU'],
#  ['Herceg Novi... Zürich..', 'ZH'],
#  ['Wabern, Schweiz', ''],
#  ['Oberwil-Lieli, Aargau', 'AG'],
#  ['Vaumarcus, Neuchâtel', 'NE'],
#  ['Zurich - Dublin', 'ZH'],
#  ['Switzerland, Neuchâtel', 'NE'],
#  ['Broye, Vaud, Suisse', 'VD'],
#  ['Niederhasli, Zürich', 'ZH'],
#  ['Domdidier, Fribourg', 'FR'],
#  ['Zug, CH', 'ZG'],
#  ['genève', 'GE'],
#  ['Baar, Zug, Switzerland', 'ZG'],
#  ['CH, Bern', 'BE'],
#  ['Olten/Neuchâtel/Lausanne, CH', ''],
#  ['Bernese Oberland, Switzerland', ''],
#  ['St-Luc, Valais, Suisse', 'VS'],
#  ['Zürich , Schweiz', 'ZH'],
#  ['Bern, Schweiz', 'BE'],
#  ['Platform 9 ¾ | vicinity Zurich', 'ZH'],
#  ['Berlin/Zürich', ''],
#  ['Port-Valais, Suisse', ''],
#  ['Zurich, Schwitzerland', 'ZH'],
#  ['Valais, CH', 'VS'],
#  ['Vaud, Suisse', 'VD'],
#  ['Rüttenen, Solothurn', 'SO'],
#  ['Stabio, Ticino', 'TI'],
#  ['Zurich (Switzerland)', 'ZH'],
#  ['Zürich, Barcelona, Berlin', 'ZH'],
#  ['Zürich, NYC', 'ZH'],
#  ['bern', 'BE'],
#  ['Glattpark - Zürich', 'ZH'],
#  ['zurigo', ''],
#  ['Switzerland, Fribourg area', 'FR'],
#  ['Tamins, Graubünden Schweiz', 'GR'],
#  ['Zurich, Portland, Austin', 'ZH'],
#  ['Bern - Switzerland', 'BE'],
#  ['Landquart / Zürich', 'ZH'],
#  ['uri', 'UR'],
#  ['#Online #TouringAroundtheWorld', ''],
#  ['Aurillac', ''],
#  ['Trimbach, Solothurn', 'SO'],
#  ['Epalinges, Vaud Suisse', 'VD'],
#  ['Valais, Magnot 6.3', 'VS'],
#  ['collombey valais , suisse', 'VS'],
#  ['Bern, Schweiz | Gdl,Jalisco', 'BE'],
#  ['Luzern,Switzerland', ''],
#  ['Landquart, Graubünden, Schweiz', 'GR'],
#  ['Brigels, Graubünden', 'GR'],
#  ['Thurgau, Switzerland', 'TG'],
#  ['Fribourg/Freiburg, Suisse', ''],
#  ['Bern, Zürich, Lausanne', 'BE'],
#  ['Rueschlikon, Zurich, Schweiz', 'ZH'],
#  ['Zürich, Winterthur', 'ZH'],
#  ['Ollon, Vaud, Aigle, Suisse, CH', 'VD'],
#  ['Genève , Thônex', 'GE'],
#  ['Genève/Suisse', ''],
#  ['Quellenstrasse 27, 8005 Zürich', 'ZH'],
#  ['Zug, Schweiz', 'ZG'],
#  ['fribourg', 'FR'],
#  ['Zurich, Huron County, Ontario', 'ZH'],
#  ['Zürich, World', 'ZH'],
#  ['Nebikon, Luzern', 'LU'],
#  ['Dübendorf, Zürich', 'ZH'],
#  ['Contone, Ticino, CH', 'TI'],
#  ['Zürich, Swtzerland', 'ZH'],
#  ['Schwyz - CH', 'SZ'],
#  ['Chardonne, Vaud', 'VD'],
#  ['vorallem Fribourg und Zäziwil', 'FR'],
#  ['Suisse, Canton de Vaud', 'VD'],
#  ['Bern, 20 Meter ü. Aare', 'BE'],
#  ['☠☠Genève, Suisse☠☠', 'GE'],
#  ['Champéry, Valais', 'VS'],
#  ['Zürich, switzerland', 'ZH'],
#  ['Uster, Zürich Schweiz', 'ZH'],
#  ['Lausanne, Genève.', 'GE'],
#  ['Fribourg Switzerland', 'FR'],
#  ['Fribourg, Lausanne', 'FR'],
#  ['Kriens-Luzern, Switzerland', ''],
#  ['Ticino, Switzerland.', 'TI'],
#  ['8008 Zurich, Switzerland', 'ZH'],
#  ['Winterthur, Zürich, Wädenswil', 'ZH'],
#  ['Basel, Zürich, Reinach', 'ZH'],
#  ['Bern, Genève, Züri, Stockholm', 'GE'],
#  ['Charmey, Fribourg', 'FR'],
#  ['zurich,lacing my copa mundials', ''],
#  ['Zürich - Chiasso, Svizzera', 'ZH'],
#  ['Zurich, Berne, Basel', 'ZH'],
#  ['Ticino, Córdoba', 'TI'],
#  ['Luzern, Luzern, Schweiz', 'LU'],
#  ['Muri bei Bern, Schweiz', 'BE'],
#  ['Zurich, Hamburg, the world', 'ZH'],
#  ['Thurgau', 'TG'],
#  ['Flums, Sankt Gallen', ''],
#  ['Solothurn, Switzerland', 'SO'],
#  ['Kanton Bern, Schweiz', 'BE'],
#  ['Versoix,Genève', ''],
#  ['Le Locle, Neuchâtel', 'NE'],
#  ['Arouca - Zürich', 'ZH'],
#  ['Zurich / Bern', 'BE'],
#  ['Berne, Suisse', ''],
#  ['Seeland, Bern, Freiburg', 'BE'],
#  ['Meisterschwanden, Aargau', 'AG'],
#  ['Giubiasco, Ticino, Switzerland', 'TI'],
#  ['Saillon, Valais', 'VS'],
#  ['Bönigen, Bern', 'BE'],
#  ['luzern , switzerland', 'LU'],
#  ['Suisse,Valais,Martigny', ''],
#  ['Bern,Schweiz', ''],
#  ['Berne ;)', ''],
#  ['Aarau, Aargau, Switzerland', 'AG'],
#  ['Fehraltorf, Zürich', 'ZH'],
#  ['Neuchâtel (Switzerland)', 'NE'],
#  ['Zurich, Switzerland, CH', 'ZH'],
#  ['irgendwo in Graubünden, CH', 'GR'],
#  ['Zürich, Switzerland, Schweiz', 'ZH'],
#  ['Schweiz, Schaffhausen', 'SH'],
#  ['Zurich,Switzerland.', ''],
#  ['Münchwilen, Thurgau', 'TG'],
#  ['Switzerland/Ticino', ''],
#  ['Arosa, Graubünden, CH', 'GR'],
#  ['Oberlunkhofen, Aargau', 'AG'],
#  ['Schaffhausen, CH', 'SH'],
#  ['Karachi/Geneva/Zurich/Istanbul', ''],
#  ['Zürich, Lagos, on the road ...', 'ZH'],
#  ['The Bern', 'BE'],
#  ['world number 1, area of zurich', 'ZH'],
#  ['switzerland, fribourg', 'FR'],
#  ['Switzerland,Fribourg', ''],
#  ['Genève / Suisse', 'GE'],
#  ['Trelex, Vaud', 'VD'],
#  ['Einsiedeln, Schwyz,', 'SZ'],
#  ['Gijón - Asturias', ''],
#  ['Zurich, Paris, Tokyo', 'ZH'],
#  ['Montreux, Vaud/Fribourg Suisse', ''],
#  ['Oberdiessbach, Bern', 'BE'],
#  ['Bern & Zürich', 'BE'],
#  ['Cheseaux-sur-Lausanne, Vaud', 'VD'],
#  ['Lausanne, St-Prex, Genève', 'GE'],
#  ['Avilés, Principado de Asturias', ''],
#  ['Spiez, Bern', 'BE'],
#  ['Zürich and near Malaga', 'ZH'],
#  ['Suisse Neuchâtel', 'NE'],
#  ['Uetikon am See, Zürich', 'ZH'],
#  ['Gurbrü, Bern', 'BE'],
#  ['Bern, Zermatt & San Francisco', 'BE'],
#  ['Locarno (Ticino), Svizzera', 'TI'],
#  ['Bern. World.', 'BE'],
#  ['aargau', 'AG'],
#  ['Bern, Ryffligässchen 5', 'BE'],
#  ['Fribourg / Lausanne, Suisse', 'FR'],
#  ['Genève (Suisse)', 'GE'],
#  ['Interlaken - Bern, Switzerland', 'BE'],
#  ['Valais, Suisse.', 'VS'],
#  ['Zurich, Ontario', 'ZH'],
#  ['Ringier, Zürich', 'ZH'],
#  ['Genève, Genève, Suisse', 'GE'],
#  ['aus bern, schweiz', 'BE'],
#  ['#Annecy #Genève Franche-Comté', 'GE'],
#  ['Epalinges, Vaud, Suisse', 'VD'],
#  ['bern, schweiz', 'BE'],
#  ['Risch Zug Switzerland', 'ZG'],
#  ['Jura, Franche-Comté', 'JU'],
#  ['Zurich, Suisse', 'ZH'],
#  ['Neuchâtel Suisse', 'NE'],
#  ['Thun, Bern/ St.Gallen, Schweiz', 'BE'],
#  ['Canton Ticino - Svizzera', 'TI'],
#  ['Kallnach, Bern', 'BE'],
#  ['Place de la Madeleine, Genève', 'GE'],
#  ['Berne, NY', ''],
#  ['Les Ponts-de-Martel, Neuchâtel', 'NE'],
#  ['St. Gallen / Zurich', 'ZH'],
#  ['Zurich, Bombay', 'ZH'],
#  ['Emmen (Luzern)', 'LU'],
#  ['Bremgarten, Aargau', 'AG'],
#  ['zürich', 'ZH'],
#  ['Berne Funkee Town', ''],
#  ['Valais, Suisse / Porto', 'VS'],
#  ['Seengen, Aargau', 'AG'],
#  ['Veyrier, Genève', 'GE'],
#  ['Villars-sur-Glâne, Fribourg, S', 'FR'],
#  ['Fribourg, de toutes nos forces', 'FR'],
#  ['Bern | Switzerland', 'BE'],
#  ['Vinzel, Vaud', 'VD'],
#  ['Sonceboz-Sombeval, Berne', ''],
#  ['Bern / Salzburg', 'BE'],
#  ['#glp Bezirk Baden, Aargau, CH', 'AG'],
#  ['Genève - Charmilles', 'GE'],
#  ['curieuse dynamique geek Suisse', ''],
#  ['Genève - Lausanne', 'GE'],
#  ['Haut-Vully, Fribourg', 'FR'],
#  ['Wettingen, Aargau, Switzerland', 'AG'],
#  ['Genève Lausanne Bâle Lyon', 'GE'],
#  ['berne, switzerland', ''],
#  ['Fribourg - Suisse', 'FR'],
#  ['Nord Vaudois, Suisse', ''],
#  ['Fribourg/Freiburg, Schweiz', ''],
#  ['Canton Zug, Switzerland', 'ZG'],
#  ['Vallamand, Vaud', 'VD'],
#  ['Boston, Zurich', 'ZH'],
#  ['Valais Suisse', 'VS'],
#  ['Zug (Switzerland)', 'ZG'],
#  ['Buchrain bei Luzern, Schweiz', 'LU'],
#  ['Luzern, Luzern', 'LU'],
#  ['Zürich, Budapest', 'ZH'],
#  ['Fribourg ⚓️', 'FR'],
#  ['Paris, Genève & Lausanne', 'GE'],
#  ['Neuchâtel, Berne...ou ailleurs', 'NE'],
#  ['Luzern Switzerland', 'LU'],
#  ['Genève, Carouge', 'GE'],
#  ['Fribourg (Suisse)', 'FR'],
#  ['Basel,Bern,Genf,Luzern,Zürich', ''],
#  ['Genève - Lausanne - Zürich', 'GE'],
#  ['Denizli / Zürich', 'ZH'],
#  ['Lyss, Bern', 'BE'],
#  ['Zürich, Thalwil, Davos', 'ZH'],
#  ['Zürich, Schwiez', 'ZH'],
#  ['Savosa, Ticino', 'TI'],
#  ['Berne / Switzerland / London', ''],
#  ['Réclère, Haute-Ajoie / Jura,CH', ''],
#  ['Zürich-Oerlikon, Schweiz', ''],
#  ['Jona, Zürich, Jakarta', 'ZH'],
#  ['Luzern / Lugano', 'LU'],
#  ['Eschlikon, Thurgau - Schweiz', 'TG'],
#  ['Wohlen bei Bern, Bern', 'BE'],
#  ['Luzern, Zentralschweiz', 'LU'],
#  ['Plan-les-Ouates, Genève', 'GE'],
#  ['Neuchâtel,CH', ''],
#  ['Zurich & Berlin', 'ZH'],
#  ['8004 Zürich, Schweiz', 'ZH'],
#  ['Zurich / Basel, Switzerland', 'ZH'],
#  ['Ehrendingen, Aargau', 'AG'],
#  ['Bern und Zürich, Switzerland', 'BE'],
#  ['Turin - NorthEurope - Montréal', ''],
#  ['Andeer, Graubünden, Schweiz', 'GR'],
#  ['Zurich - Paris - Hamburg', 'ZH'],
#  ['Schweiz | Zürich', 'ZH'],
#  ['Sonogno, Ticino', 'TI'],
#  ['Limoges / Genève', 'GE'],
#  ['Lourinhã', ''],
#  ['Nidwalden, Schweiz', 'NW'],
#  ['Lully (VD), Vaud', 'VD'],
#  ['Mendrisio, Ticino', 'TI'],
#  ['Zug, Zug', 'ZG'],
#  ['Genève, Lausanne, Fribourg', 'GE'],
#  ['Zurique', ''],
#  ['Crassier, Vaud', 'VD'],
#  ['Viseu / Genève', 'GE'],
#  ['Rothenthurm, Schwyz', 'SZ'],
#  ['Eiken, Aargau, Schweiz', 'AG'],
#  ['Losanna, Vaud', 'VD'],
#  ['Uni Dufour, Genève', 'GE'],
#  ['Bern & Luzern, Switzerland', 'LU'],
#  ['Fribourg, Swizerland', 'FR'],
#  ['Mörigen, Bern', 'BE'],
#  ['Lausanne, Genève', 'GE'],
#  ['Malvaglia Ticino Svizzera', 'TI'],
#  ['Zürich, Jacksonville', 'ZH'],
#  ['Fleurier, Switzerland', ''],
#  ['Texas & Zurich, Switzerland', 'ZH'],
#  ['Suisse- Genève', 'GE'],
#  ['Fribourg - Rte de Villars 37', 'FR'],
#  ['Zurich CH', 'ZH'],
#  ['Châtel-Saint-Denis, Fribourg', 'FR'],
#  ['Leysin, Vaud', 'VD'],
#  ['solothurn- schweiz', 'SO'],
#  ['Kanton Luzern :)', 'LU'],
#  ['Bern, Zollikofen', 'BE'],
#  ['Zurich, Paris, Jakarta', 'ZH'],
#  ['Meilen, Zürich', 'ZH'],
#  ['Genève et Montréal', 'GE'],
#  ['Münchenbuchsee, Bern', 'BE'],
#  ['Subingen, Solothurn', 'SO'],
#  ['Glatttalstrasse 104e, Zürich', 'ZH'],
#  ['Bern, schweiz', 'BE'],
#  ['Zürich, Sweiz', 'ZH'],
#  ['Sierre, Valais, Suisse', 'VS'],
#  ['Genève - Lisboa', 'GE'],
#  ['Bellevue, Zurich', 'ZH'],
#  ['Regensdorf, Zürich', 'ZH'],
#  ['Basel, Zürich, Berlin, Köln', 'ZH'],
#  ['Einsiedeln, Schwyz', 'SZ'],
#  ['Neuchâtel-Suisse', ''],
#  ['Säckingen, Bern, Berlin, BXL', 'BE'],
#  ['Nidwalden', 'NW'],
#  ['Bern, Genève, New York', 'GE'],
#  ['Port-Valais, Valais', 'VS'],
#  ['Zürich | Boston | Newcastle', 'ZH'],
#  ['Zurich | London | SanFrancisco', 'ZH'],
#  ['Genève, Suisse | Bahia, Brasil', 'GE'],
#  ['Hägendorf, Solothurn', 'SO'],
#  ['Zurich - Switzerland', 'ZH'],
#  ['Zürich, Schweiz 8805 R wil', 'ZH'],
#  ['Hermenches, Vaud', 'VD'],
#  ['Wald, Zurich', 'ZH'],
#  ['Winterthur, Zürich,CH', ''],
#  ['Le Landeron, Neuchâtel', 'NE'],
#  ['Zürich (CH)', 'ZH'],
#  ['Adliswil, Zürich', 'ZH'],
#  ['Richterswil, Zürich', 'ZH'],
#  ['Cartigny, Genève', 'GE'],
#  ['Appenzell Innerrhoden', ''],
#  ['Luzern St. Niklausen', 'LU'],
#  ['berne', ''],
#  ['meistens in Graubünden', 'GR'],
#  ['Letzigrund,Zurich', ''],
#  ['Massagno, Ticino', 'TI'],
#  ['zurich suiça', 'ZH'],
#  ['Basel-Landschaft', ''],
#  ['Vallorbe, Vaud', 'VD'],
#  ['Zurich + Ocean Falls B.C.', 'ZH'],
#  ['Zurich, Basel, Switzerland', 'ZH'],
#  ['Noville, Vaud, Switzerland', 'VD'],
#  ['Zürich/Genf', ''],
#  ['Genève, Suisse / sismondi', 'GE'],
#  ['Klosterstrasse, Schaffhausen', 'SH'],
#  ['Brussels / Bern', 'BE'],
#  ['Zurich, Rio, Barcelona, Miami', 'ZH'],
#  ['Seewen, Schwyz', 'SZ'],
#  ['Kanton Aargau, Switzerland', 'AG'],
#  ['Nendaz, Valais', 'VS'],
#  ['Köniz, Bern', 'BE'],
#  ['Oensingen, Solothurn', 'SO'],
#  ['Berlin/Bern/Zürich', ''],
#  ['Zug (CH)', 'ZG'],
#  ['CH, Berne', ''],
#  ['Maienfeld, Graubünden, Schweiz', 'GR'],
#  ['Lenzerheide, Graubünden', 'GR'],
#  ['Bougy-Villars, Vaud', 'VD'],
#  ['Morges,Vaud,Suisse,Switzerland', ''],
#  ['Switzerland Fribourg', 'FR'],
#  ['Rue de Berne 9, Genève, 1201', 'GE'],
#  ['Fribourg, Estavayer-le-Lac', 'FR'],
#  ['Horw (Luzern), Schweiz', 'LU'],
#  ['Zurich, Zug, Amsterdam, London', 'ZG'],
#  ['Uster, Zürich', 'ZH'],
#  ['Zürich, Basel, Nimmerland', 'ZH'],
#  ['Genebra,Suiça- Genève, Suisse.', 'GE'],
#  ['Jura, Switzerland', 'JU'],
#  ['4500 Solothurn, Switzerland', 'SO'],
#  ['Frick, Aargau', 'AG'],
#  ['Tessin/ Ticino, Switzerland', 'TI'],
#  ['Bern - Schweiz - Welt', 'BE'],
#  ['Zürich/Zug, Switzerland', ''],
#  ['Langendorf, Solothurn', 'SO'],
#  ['Zürich, Bern, Stuttgart', 'BE'],
#  ['Europe, Switzerland, Zurich', 'ZH'],
#  ['Minusio, Ticino, Switzerland', 'TI'],
#  ['Kallnach (Bern), Switzerland', 'BE'],
#  ['Im Zug', 'ZG'],
#  ['Geuensee, Luzern', 'LU'],
#  ['Berne, Genève', 'GE'],
#  ['Oberentfelden, Aargau', 'AG'],
#  ['Beckenried, Nidwalden, Schweiz', 'NW'],
#  ['Pully, canton de Vaud, Suisse', 'VD'],
#  ['Zurich, Istanbul', 'ZH'],
#  ['Nidwalden, Switzerland', 'NW'],
#  ['Zürich, CHE', 'ZH'],
#  ['Zürich, Schweiz (still german)', 'ZH'],
#  ['Florin Büchel, Zurich', 'ZH'],
#  ['Switzerland, Thurgau', 'TG'],
#  ['Suisse,berne', ''],
#  ['Zurich,Athens', ''],
#  ['Thusis, Graubünden', 'GR'],
#  ['zurich switzerland', 'ZH'],
#  ['Tellstrasse 31, Zürich', 'ZH'],
#  ['Zürich, Switzerland/Schweiz', 'ZH'],
#  ['Fribourg - Milano - Napoli', 'FR'],
#  ['Bulle, Fribourg, Suisse', 'FR'],
#  ['Berna, Suíça', ''],
#  ['Coldrerio, Ticino, Svizzera', 'TI'],
#  ['Buochs, Nidwalden', 'NW'],
#  ['Forel (Lavaux), Vaud', 'VD'],
#  ['Sementina, Ticino, Svizzera', 'TI'],
#  ['Hettlingen, Zürich', 'ZH'],
#  ['Zurich/Trabzon', ''],
#  ['Zurich, Foggia', 'ZH'],
#  ['Bern und Stadel', 'BE'],
#  ['Forst-Längenbühl, Bern', 'BE'],
#  ['Zurich, Olten, Munich, Nice', 'ZH'],
#  ['Lutry, Vaud', 'VD'],
#  ['Luzern,', 'LU'],
#  ['Chur, Graubünden, Schweiz', 'GR'],
#  ['Zurich,', 'ZH'],
#  ['Bern (Schweiz/Switzerland)', 'BE'],
#  ['Schmiedengasse 13, Solothurn', 'SO'],
#  ['Cully, Vaud', 'VD'],
#  ['Switzerland; Auric Stud Farm', ''],
#  ['Uri, Switzerland', 'UR'],
#  ['Wald (ZH), Zürich', 'ZH'],
#  ['Zurich • Suisse', 'ZH'],
#  ['Zurich, Suiza// A Coruña', 'ZH'],
#  ['Les Crozets (Jura)', 'JU'],
#  ['bern/swiss', ''],
#  ['Zurich, New York', 'ZH'],
#  ['Bern / Orkney', 'BE'],
#  ['Suisse , Genève', 'GE'],
#  ['Ollon, Vaud - Switzerland', 'VD'],
#  ['Unterseen, Bern', 'BE'],
#  ['Bern, Switzerland.', 'BE'],
#  ['Solothurn City', 'SO'],
#  ['Genève - Suisse', 'GE'],
#  ['Zürich-Basel, Switzerland', ''],
#  ['Bonstetten, Zürich', 'ZH'],
#  ['Bern,Zurich,Basel,Freiburg (D)', ''],
#  ['Aadorf, Thurgau, Schweiz', 'TG'],
#  ['Belfaux, Fribourg', 'FR'],
#  ['- Genève', 'GE'],
#  ['Zurich / Alicante', 'ZH'],
#  ['Zurich, ON', 'ZH'],
#  ['Vevey, Vaud, Schweiz', 'VD'],
#  ['Zurich, Heidelberg', 'ZH'],
#  ['Anzere,Valais,Suisse', ''],
#  ['Quartino, Ticino, Switzerland', 'TI'],
#  ['Riehen, Basel-Stadt', ''],
#  ['Wohlensee Bern, Switzerland', 'BE'],
#  ['Bern - ursprünglich Altstätten', 'BE'],
#  ['Zurich,Swiss', ''],
#  ['Le Flon, Fribourg', 'FR'],
#  ['Gebenstorf, Aargau', 'AG'],
#  ['Yvonand, Vaud', 'VD'],
#  ['Saint-Aubin-Sauges, Neuchâtel', 'NE'],
#  ['Genève,Suisse/Switzerland', ''],
#  ['Concise, Vaud', 'VD'],
#  ['Cape Town,London,Zurich,Geneva', ''],
#  ['Aarau, Aargau', 'AG'],
#  ['In Zurich, Italian', 'ZH'],
#  ['Kilchberg/Zürich (Switzerland)', ''],
#  ['Ibach, Schwyz', 'SZ'],
#  ['Kloten, Zürich', 'ZH'],
#  ['Hochdorf, Luzern', 'LU'],
#  ['Muri b. Bern, Schweiz', 'BE'],
#  ['Zürich, Switerland', 'ZH'],
#  ['Thalwil, Zürich', 'ZH'],
#  ['Kreuzlingen, Thurgau, Schweiz', 'TG'],
#  ['Yverdon/Vaud/Suisse', ''],
#  ['Cevio, Ticino', 'TI'],
#  ['Bern / Tschappina', 'BE'],
#  ['Zürich,Switzerland', ''],
#  ['Conthey , Valais , Suisse', 'VS'],
#  ['suisse véto curieux', ''],
#  ['Gossau (ZH), Zürich', 'ZH'],
#  ['@ Neuchâtel', 'NE'],
#  ['Delémont, Jura', 'JU'],
#  ['Genève, Zurich', 'GE'],
#  ['Switzerland,Aargau', ''],
#  ['Küsnacht (ZH), Zürich', 'ZH'],
#  ['Rümlang, Zürich', 'ZH'],
#  ['Zurich, Berne', 'ZH'],
#  ['Bosco Gurin, Ticino, Svizzera', 'TI'],
#  ['Quinten / Zürich, Switzerland', 'ZH'],
#  ['La Chaux-de-Fonds, Neuchâtel', 'NE'],
#  ['Bonaduz, Graubünden', 'GR'],
#  ['Genève, lausanne, Annecy, Gex', 'GE'],
#  ['Switzerland, Luzern', 'LU'],
#  ['genève meyrina 17', 'GE'],
#  ['Genève.', 'GE'],
#  ['Berna, Svizzera', ''],
#  ['Rothrist, Aargau', 'AG'],
#  ['Zurich, Switzerland', 'ZH'],
#  ['Vevey, Vaud', 'VD'],
#  ['Sankt Gallen // Swiss', ''],
#  ['München / Zürich', 'ZH'],
#  ['Genève, Geneva, Gland, Suisse', 'GE'],
#  ['Zurich, Mallorca and Arosa', 'ZH'],
#  ['Seebach, Zürich, Svizzera', 'ZH'],
#  ['Zürich, Swiss', 'ZH'],
#  ['Lugano & Zürich, Switzerland', 'ZH'],
#  ['JURA', 'JU'],
#  ['Zurich / Warsaw', 'ZH'],
#  ['Bern,switzerland', ''],
#  ['zurich,switzerland', ''],
#  ['Bern, Bern CH', 'BE'],
#  ['Zürich | Basel', 'ZH'],
#  ['Kestenholz - Jurasüdfuss', ''],
#  ['Bollwerk, Bern', 'BE'],
#  ['Suisse, Jura', 'JU'],
#  ['Zuger Oberland, Switzerland', ''],
#  ['Melano, Ticino, Svizzera', 'TI'],
#  ['Langnau, Emmental, Kanton Bern', 'BE'],
#  ['Zürich, Bäckeranlage', 'ZH'],
#  ['Interlaken, Bern', 'BE'],
#  ['Santiago bernabéu', ''],
#  ['Los Angeles and Zürich', 'ZH'],
#  ['Lohn-Ammannsegg, Solothurn', 'SO'],
#  ['Aubonne, Vaud', 'VD'],
#  ['Morges, Vaud, Schweiz', 'VD'],
#  ['Watt, Zürich, Schweiz', 'ZH'],
#  ['Kloten, Zurich', 'ZH'],
#  ['Zurich, sveitsi', 'ZH'],
#  ['Zürich, Berlin', 'ZH'],
#  ['Volketswil, Zürich', 'ZH'],
#  ['Glasgow/Zürich', ''],
#  ['Back in awesome Zurich!', 'ZH'],
#  ['Wallis Schweiz / Valais Suiza', 'VS'],
#  ['Bad Ragaz, Sankt Gallen', ''],
#  ['St-Maurice, VS, Suisse', 'VS'],
#  ['Seelisberg, 850 M.ü.M., Uri', 'UR'],
#  ['Ebikon, Luzern', 'LU'],
#  ['Disentis/Mustér, Graubünden', 'GR'],
#  ['Neuchâtel, Suisse', 'NE'],
#  ['Turmstrasse 18, Zug, Schweiz', 'ZG'],
#  ['Xixón, Asturies', ''],
#  ['Bunker, Berne', ''],
#  ['Les Hauts-Geneveys, Neuchâtel', 'NE'],
#  ['Switzerland, Baden Aargau', 'AG'],
#  ['Salmsach, Thurgau, Switzerland', 'TG'],
#  ['Solothurn,Schweiz', ''],
#  ['Zurich /Zagreb /Moscow', 'ZH'],
#  ['Courtételle / Jura', 'JU'],
#  ['la ville de zurich', 'ZH'],
#  ['Genève, Plan-les-Ouates', 'GE'],
#  ['rue de berne, Genève', 'GE'],
#  ['Solothurn, Schweiz', 'SO'],
#  ['Neugasse 10, Zürich, CH', 'ZH'],
#  ['Wetzikon&8005 und 8006 Zürich', 'ZH'],
#  ['Zürich, Rüti (ZH)', 'ZH'],
#  ['Zürich, Salzburg, Beograd', 'ZH'],
#  ['6 rue du Pré Jérôme, Genève', 'GE'],
#  ['Biasca, Ticino', 'TI'],
#  ['Root, Luzern', 'LU'],
#  ['Bienne, Bern, Switzerland', 'BE'],
#  ['Nord-Vaudois, Suisse', ''],
#  ['Bellecombe, Jura', 'JU'],
#  ['Echandens, Vaud', 'VD'],
#  ['Niederdorfstrasse 77, Zürich', 'ZH'],
#  ['Genève - Paris - London', 'GE'],
#  ['suisse,Neuchâtel', ''],
#  ['Winterthur, Zurich', 'ZH'],
#  ['Ticino, Agno', 'TI'],
#  ['Delémont, Jura, Suisse, Europe', 'JU'],
#  ['Arc Jurassien, Switzerland', ''],
#  ['Zürich, Kreis 5', 'ZH'],
#  ['Les Geneveys-sur-Coffrane, Neuchâtel', 'NE'],
#  ['Region Zürich', 'ZH'],
#  ['CH (Fribourg)', 'FR'],
#  ['Geroldswil, Zürich', 'ZH'],
#  ['Bern/Schweiz', ''],
#  ['Lommiswil, Solothurn', 'SO'],
#  ['Ursy, Fribourg', 'FR'],
#  ['zurich/ticino', ''],
#  ['Luzern CH', 'LU'],
#  ['Switzerland, Bern 3072', 'BE'],
#  ['Schweiz -Bern', 'BE'],
#  ['Talkessel Schwyz, Switzerland', 'SZ'],
#  ['Les Enfers, Jura', 'JU'],
#  ['Bern / Switzerland', 'BE'],
#  ['Zug, Scuol', 'ZG'],
#  ['Courtepin, Fribourg', 'FR'],
#  ['Ticino, Cordoba, Arentina', 'TI'],
#  ['Hamburg | Luzern', 'LU'],
#  ['Kriens,Luzern,Schweiz', ''],
#  ['Welt Europa. Schweiz Aargau', 'AG'],
#  ['Palo Alto / Zurich', 'ZH'],
#  ['Zürich, Kreis 1 und 2', 'ZH'],
#  ['Sisseln, Aargau', 'AG'],
#  ['haute savoie, genève', 'GE'],
#  ['Bagnes, Valais', 'VS'],
#  ['Suisse-Genève', ''],
#  ['Crissier, Vaud', 'VD'],
#  ['Genève - Marseille', 'GE'],
#  ['Montreux, Vaud, Suisse', 'VD'],
#  ['Orsières, Valais', 'VS'],
#  ['Lancy, Genève', 'GE'],
#  ['Kandersteg, Bern', 'BE'],
#  ['Schaffhausen,Barcelona', ''],
#  ['Zurich, New York, Pittsburgh', 'ZH'],
#  ['Bern/Zurich, Switzerland', ''],
#  ['Biberist, Solothurn', 'SO'],
#  ['Suisse,Genève', ''],
#  ['Ticino, Suiza', 'TI'],
#  ['Rafz, Zürich', 'ZH'],
#  ['Zurich/Switzerland', ''],
#  ['Thun–Zürich-Switzerland', ''],
#  ['Givisiez, Fribourg, Suisse', 'FR'],
#  ['switzerland, bern', 'BE'],
#  ['Zugerstr. 77,6340 Baar,Schweiz', ''],
#  ['Bern / Schweiz', 'BE'],
#  ['Merenschwand, Aargau', 'AG'],
#  ['Fribourg, CH', 'FR'],
#  ['neuchâtel, CH', 'NE'],
#  ['Hitzkirch, Luzern', 'LU'],
#  ['Genève, Suisse☁️', 'GE'],
#  ['Montana, Valais', 'VS'],
#  ['Bolligen, Berne Switzerland', ''],
#  ['Zurich, switzerland', 'ZH'],
#  ['lausanne zurich paris provence', 'ZH'],
#  ['Zurich, mostly', 'ZH'],
#  ['Baar, Kanton Zug, Switzerland', 'ZG'],
#  ['Bremgarten bei Bern, Schweiz', 'BE'],
#  ['Valais, Switzerland', 'VS'],
#  ['Genève - Algerie', 'GE'],
#  ['Bern - Liebefeld', 'BE'],
#  ['Beckenhofstrasse 16, Zürich', 'ZH'],
#  ['Locarno, Ticino', 'TI'],
#  ['Zürich, Badenerstrase 623', 'ZH'],
#  ['Bahnhofplatz 11, 3001 Bern', 'BE'],
#  ['Zürich, Hamburg', 'ZH'],
#  ['University of Zurich', 'ZH'],
#  ['W. Alton Jones Campus, URI', 'UR'],
#  ['Zürich, Basel, London', 'ZH'],
#  ['Zurich ( Oxford is my home )', 'ZH'],
#  ['Gutenbergstrasse 31, Bern', 'BE'],
#  ['Berne, CH', ''],
#  ['Zurich & Arosa, Switzerland', 'ZH'],
#  ['Paris & Zurich', 'ZH'],
#  ['Chalais, Valais, Suisse', 'VS'],
#  ['3014 Bern Suisse', 'BE'],
#  ['Romainmôtier, Vaud, Suisse', 'VD'],
#  ['Berne, Bienne', ''],
#  ['Avry, Fribourg', 'FR'],
#  ['Ascona, Ticino Svizzera', 'TI'],
#  ['Appenzell Ausserrhoden, Switze', ''],
#  ['Wahlern, Bern', 'BE'],
#  ['Turgi, Aargau', 'AG'],
#  ['Luzern, Basel, Zürich, Bern', 'LU'],
#  ['Lives Zurich - thinks Geneva', 'ZH'],
#  ['Langnau am Albis, Zürich', 'ZH'],
#  ['Kriens, Luzern, Schweiz', 'LU'],
#  ['Zurich. Sarajevo. Worldwide.', 'ZH'],
#  ['Zürich, Niederglatt', 'ZH'],
#  ['Zug Zürich Schweiz', 'ZG'],
#  ['Zollikofen, Bern', 'BE'],
#  ['Zurich, CH', 'ZH'],
#  ['Etagnières, Vaud, Switzerland', 'VD'],
#  ['Buochs, Nidwalden, Suisse', 'NW'],
#  ['Balsthal, Solothurn', 'SO'],
#  ['4503 Solothurn, Switzerland', 'SO'],
#  ['swiss cheese, zurich', 'ZH'],
#  ['¤ Münsingen, Bern, Schweiz ¤', 'BE'],
#  ['Suisse, Neuchâtel', 'NE'],
#  ['Genève / Gjilan', 'GE'],
#  ['Zurich | Switzerland', 'ZH'],
#  ['Zurich Region, Switzerland', 'ZH'],
#  ['Vacallo, Ticino', 'TI'],
#  ['ZURICH', 'ZH'],
#  ['Genève et Haute Savoie', 'GE'],
#  ['Luzern / Emmenbrücke', 'LU'],
#  ['Asturias', ''],
#  ['Daillens, Vaud', 'VD'],
#  ['Langnau, Bern', 'BE'],
#  ['Pfauen und Schiffbau, Zürich', 'ZH'],
#  ['Suisse,vaud', ''],
#  ['Genève/Geneva', ''],
#  ['Zurich & Chur, Switzerland', 'ZH'],
#  ['Berne - Switzerland', ''],
#  ['Freienbach, Schwyz', 'SZ'],
#  ['New Bern', 'BE'],
#  ['Zürich, Chur, Schweiz', 'ZH'],
#  ['Sierre, Valais, Suiza', 'VS'],
#  ['Zürich, Schweiz, Switzerland', 'ZH'],
#  ['Wangen bei Olten, Solothurn', 'SO'],
#  ['en Gruyère, Fribourg, Suisse', 'FR'],
#  ['Zurich, Suisse.', 'ZH'],
#  ['Zürich,switzerland', ''],
#  ['Bern, Solothurn, Thun, Schweiz', 'SO'],
#  ['Zürich/İstanbul', ''],
#  ['Genève, Nyon et Aubonne', 'GE'],
#  ['New Bern, N.C.', 'BE'],
#  ['Gardiol, Genève', 'GE'],
#  ['Jura, Franche-Comté.', 'JU'],
#  ['Balm bei Günsberg, Solothurn', 'SO'],
#  ['Currently planted in Zürich CH', 'ZH'],
#  ['Zürich, Praha, Lednice', 'ZH'],
#  ['Balerna, Canton Ticino - CH', 'TI'],
#  ['Genève , Swizertland', 'GE'],
#  ['Zürich | Baden', 'ZH'],
#  ['Berne | Lausanne', ''],
#  ['Zurique, Suiça', ''],
#  ['Zürichs', ''],
#  ['Fribourg et Lausanne', 'FR'],
#  ['London, Oxford, Zurich', 'ZH'],
#  ['zug', 'ZG'],
#  ['Zürich, Mumbai, Palo Alto', 'ZH'],
#  ['Zurich, Suiza', 'ZH'],
#  ['Sion, Valais', 'VS'],
#  ['Dietikon, Zurigo', ''],
#  ['Zurich, New York City and Doha', 'ZH'],
#  ['switzerland Bern', 'BE'],
#  ['schaffhausen', 'SH'],
#  ['Chalais, Valais', 'VS'],
#  ['Habsburg, Aargau', 'AG'],
#  ['Berne; Switzerland', ''],
#  ['zürich,switzerland', ''],
#  ['Lyon/Genève', ''],
#  ['Zürich / Johannesburg', 'ZH'],
#  ['Port, Bern', 'BE'],
#  ['Lausanne, Vaud, Switzerland', 'VD'],
#  ['Genève, Tunisie', 'GE'],
#  ['Genève, tunis', 'GE'],
#  ['Saanen, Bern', 'BE'],
#  ['Peseux, Neuchâtel', 'NE'],
#  ['Genève, Lignon', 'GE'],
#  ['Bern, Fribourg, Jerusalem', 'BE'],
#  ['Oberrieden, Zürich', 'ZH'],
#  ['schaffhausen, Schweiz', 'SH'],
#  ['Oviedo, Asturias', ''],
#  ['Suisse, Valais, Sion', 'VS'],
#  ['Degersheim, Sankt Gallen', ''],
#  ['Banhofstrasse 44,8001 Zurich', 'ZH'],
#  ['Halifax, Berne, Duesseldorf', ''],
#  ['Ticino, Svizzera, Ascona', 'TI'],
#  ['Stäfa, Zürich', 'ZH'],
#  ['Kandor - Zürich, Switzerland', 'ZH'],
#  ['Zürich, Rapperswil', 'ZH'],
#  ['Zürich/Schaffhausen/Uster', ''],
#  ['Zurich; Amsterdam', 'ZH'],
#  ['Freiburg - Fribourg', 'FR'],
#  ['||Zürich, Schweiz||', 'ZH'],
#  ['Canton Bern(e), Switzerland', ''],
#  ['Genève, Marseille', 'GE'],
#  ['Weinfelden, Thurgau, Schweiz', 'TG'],
#  ['Hünenberg, Zug, Switzerland', 'ZG'],
#  ['Orsières - Valais', 'VS'],
#  ['Genève, Thonex', 'GE'],
#  ['Im Zug Richtung HH und zurück.', 'ZG'],
#  ['Fribourg, Switzerland', 'FR'],
#  ['Blonay, Vaud', 'VD'],
#  ['Porrentruy, Europe/Zurich', ''],
#  ['Langstrass Zurich,Switzerland', ''],
#  ['Switzerland, Jura, Vicques', 'JU'],
#  ['Galicia/Berna/Zürich', ''],
#  ['Graubünden (Switzerland)', 'GR'],
#  ['Kasernenplatz 3, Luzern', 'LU'],
#  ['Switzerland / Jura /Bassecourt', 'JU'],
#  ['Morges / Fribourg, Suisse', 'FR'],
#  ['Genève , Suisse', 'GE'],
#  ['Zürich, Schweiz❤', 'ZH'],
#  ['Zurich-Switzerland', ''],
#  ['Zurich, Earth', 'ZH'],
#  ['Glarus Nord, Niederurnen, CH', 'GL'],
#  ['Genève, Suisse, Evian', 'GE'],
#  ['Genève, CH', 'GE'],
#  ['Basel & Zurich, Switzerland', 'ZH'],
#  ['Zurich & Scotland', 'ZH'],
#  ['Switzerland, Zürich/Rapperswil', ''],
#  ['Zürich, Tokyo', 'ZH'],
#  ['Zürich, Schweiz, .ch', 'ZH'],
#  ['Zürich, fucking Switzerland', 'ZH'],
#  ['Langstrasse, Zürich', 'ZH'],
#  ['Genève | Haute Savoie', 'GE'],
#  ['Jura', 'JU'],
#  ['Estavayer-le-Lac, Fribourg', 'FR'],
#  ['Zurich, Suiza / Leon, Gto.', 'ZH'],
#  ['Solothurn, Schweiz/Switzerland', 'SO'],
#  ['Fleurier', ''],
#  ['Genève, Ch', 'GE'],
#  ['Lausanne, Vaud, Suise, Europe', 'VD'],
#  ['Chur, Graubünden', 'GR'],
#  ['Sion-Valais/Lausanne Suisse', ''],
#  ['Weinbergstr. 15, 8001 Zürich', 'ZH'],
#  ['Sempach, Luzern', 'LU'],
#  ['Corgémont, Berne', ''],
#  ['Fribourg,Switzerland', ''],
#  ['Zurich, Beograd, San Francisco', 'ZH'],
#  ['Basel | Zürich, Schweiz', 'ZH'],
#  ['Ticino - Svizzera italiana', 'TI'],
#  ['neuchâtel', 'NE'],
#  ['Matzingen, Thurgau', 'TG'],
#  ['Zürich/Switzerland', ''],
#  ['Genève, Lecce', 'GE'],
#  ["Collina d'Oro, Ticino", 'TI'],
#  ['Jura, Scotland', 'JU'],
#  ['Boussens, Vaud', 'VD'],
#  ['Address: Bern, Switzerland', 'BE'],
#  ['Bern, Schweiz, Stade de Suisse', 'BE'],
#  ['Onda - Valencia - Zürich', 'ZH'],
#  ['Nyon, Genève, Suisse', 'GE'],
#  ['Switzerland, Aargau', 'AG'],
#  ['Letzigrund, Zürich', 'ZH'],
#  ['Helvetiaplatz, Bern', 'BE'],
#  ['Eigerplatz, Bern', 'BE'],
#  ['Falkenstrasse 11, Zürich', 'ZH'],
#  ['Zürich,Berlin,Wien,Salzburg', ''],
#  ['Bourg-Saint-Maurice, Rhône-Alpes', ''],
#  ['CH Bern', 'BE'],
#  ['bern;;ch', ''],
#  ['Weststr. 41, Zürich', 'ZH'],
#  ['bern & zurich, switzerland', 'BE'],
#  ['Biel, Bern, CH', 'BE'],
#  ['Zurigo, Svizzera', ''],
#  ['bern isvicre', 'BE'],
#  ['Rapperswil-Jona, Sankt Gallen', ''],
#  ['Switzerland, Jura', 'JU'],
#  ['Nesslau, Sankt Gallen', ''],
#  ['Zurich-Waedenswil, Switzerland', ''],
#  ['bourg saint maurice # alpes #', ''],
#  ...]

# %%
df_cantons_e = pd.DataFrame(cantons_extra)
df_cantons_e.columns = [['Location','ID']]
df_cantons_e
# Out:
#                                Location  ID
# 0           Zurich, Dortmund, Barcelona  ZH
# 1                       luzern, schweiz  LU
# 2                 Recherswil, Solothurn  SO
# 3                                  Vaud  VD
# 4                   Schaffhausen, Swiss  SH
# 5                     (Saudi tourists )
# 6             Zurich, London, Paris, SF  ZH
# 7                 Zurich, Dinerolandia.  ZH
# 8        Basel - Bern - Zürich, Schweiz  BE
# 9                           Péry, Berne
# 10                          Lake Zurich  ZH
# 11                       Bülach, Zürich  ZH
# 12                              Berneck
# 13          Lucerne, Zurich or anywhere  ZH
# 14                      Verbier, Valais  VS
# 15             Freiamt, Aargau, Schweiz  AG
# 16                Tenero-Contra, Ticino  TI
# 17                            Bern 3000  BE
# 18                   Sion, Valais-Suiça
# 19        Saint Gallen, Bern und Zürich  BE
# 20           Zug, London, Dubai, Joburg  ZG
# 21          Suisse , Neuchâtel , Bevaix  NE
# 22       Herzogenbuchsee, Bern, Schweiz  BE
# 23                  Locarno, Ticino, CH  TI
# 24                          Vaud, Suiza  VD
# 25                   Bern (Switzerland)  BE
# 26                           Belp, Bern  BE
# 27                  Valais, Suisse #250  VS
# 28                           Bern, Bern  BE
# 29                     Zollikon, Zürich  ZH
# ...                                 ...  ..
# 2523                  19 Eye Street, NW  NW
# 2524         Saint-Sulpice (VD), Suisse  VD
# 2525                           Sion, VS  VS
# 2526                            NW, Ga.  NW
# 2527  Chemin du Closel 5, Renens VD, CH  VD
# 2528                  Schweiz, Rikon ZH  ZH
# 2529             Orbe, VD, Switzerland.  VD
# 2530                   NW,Washington DC
# 2531          Birmensdorf (ZH), Schweiz  ZH
# 2532                        UR, Izhevsk  UR
# 2533          Pfäffikon ZH, Switzerland  ZH
# 2534     Suisse, Région lausannoise, VD  VD
# 2535       1156 15th St., NW, Suite 600  NW
# 2536                         NW, London  NW
# 2537              Pfäffikon ZH, Schweiz  ZH
# 2538                                 NW  NW
# 2539                             NW, UK  NW
# 2540                                 JU  JU
# 2541                 Baar (ZG), Schweiz  ZG
# 2542         Switzerland, Chexbres (VD)  VD
# 2543                   Looking Hill, ZH  ZH
# 2544                        X Vagas, VS  VS
# 2545     NW,Wales,Midlands,Yorks,Humber
# 2546          2700 Cathedral Avenue, NW  NW
# 2547            Savièse/VS, Switzerland
# 2548                      ZH/St. Moritz
# 2549                        Küsnacht ZH  ZH
# 2550              Ecublens (VD), Suisse  VD
# 2551                            TI, UTY  TI
# 2552              Orkney/Klerksdorp, NW  NW
#
# [2553 rows x 2 columns]

# %%
df_cantons = pd.concat([df_cantons,df_cantons_e]).reset_index()
del df_cantons['index']

# %%
df_cantons = df_cantons.dropna()

# %%
df_cantons = df_cantons[df_cantons['ID']!=''].reset_index()
del df_cantons['index']

# %%
df_cantons
# Out:
#       ID                           Location
# 0     NY                       R-34// 305CH
# 1     VS                            The CHI
# 2     BS                          Basel, CH
# 3     ZH               zuerich, switzerland
# 4     BE                           Biel, CH
# 5     LU             Zentralschweiz / Basel
# 6     VD                  vevey,switzerland
# 7     GE        Manchester, UK / Geneva, CH
# 8     VD                       Montreux, CH
# 9     VD                       lausanne, CH
# 10    VD                        lausanne,CH
# 11    LU                            CH-6170
# 12    ZH                       Opfikon (CH)
# 13    AG       Cholerweg 9, 5212 Hausen, CH
# 14    ZH                meilen, switzerland
# 15    ZH                        CH-8132 Egg
# 16    VS                  sion, switzerland
# 17    BS                 switzerland, basel
# 18    BE             interlaken,switzerland
# 19    BE                    Steffisburg, CH
# 20    NE                         Chating CH
# 21    GR                    Davos-Platz, CH
# 22    GE                      suisse/geneve
# 23    BS                 basel, switzerland
# 24    GE                switzerland, Geneva
# 25    BS                 Basel, switzerland
# 26    BE      CH - 3439 Ranflueh, Ramisberg
# 27    TX                               CHHS
# 28    VS                  martigny - suisse
# 29    SG                    St. Gallen (CH)
# ...   ..                                ...
# 2382  NW                701 21st Street, NW
# 2383  NW       2120 L Street, NW, Suite 850
# 2384  VS                    VS, Switzerland
# 2385  TI                      Mendrisio, TI
# 2386  NW                  19 Eye Street, NW
# 2387  VD         Saint-Sulpice (VD), Suisse
# 2388  VS                           Sion, VS
# 2389  NW                            NW, Ga.
# 2390  VD  Chemin du Closel 5, Renens VD, CH
# 2391  ZH                  Schweiz, Rikon ZH
# 2392  VD             Orbe, VD, Switzerland.
# 2393  ZH          Birmensdorf (ZH), Schweiz
# 2394  UR                        UR, Izhevsk
# 2395  ZH          Pfäffikon ZH, Switzerland
# 2396  VD     Suisse, Région lausannoise, VD
# 2397  NW       1156 15th St., NW, Suite 600
# 2398  NW                         NW, London
# 2399  ZH              Pfäffikon ZH, Schweiz
# 2400  NW                                 NW
# 2401  NW                             NW, UK
# 2402  JU                                 JU
# 2403  ZG                 Baar (ZG), Schweiz
# 2404  VD         Switzerland, Chexbres (VD)
# 2405  ZH                   Looking Hill, ZH
# 2406  VS                        X Vagas, VS
# 2407  NW          2700 Cathedral Avenue, NW
# 2408  ZH                        Küsnacht ZH
# 2409  VD              Ecublens (VD), Suisse
# 2410  TI                            TI, UTY
# 2411  NW              Orkney/Klerksdorp, NW
#
# [2412 rows x 2 columns]

# %%
df.to_csv('../data/location_to_canton.csv')
